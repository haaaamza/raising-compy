# %% [markdown]
# # Imports

# %%
import numpy as np
import pickle as pkl
import time
import torch
import torchvision
import torchvision.transforms as transforms
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
from google.colab import files
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# # Load Sample Data

# %%
transformer = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]) #Here we take in a PIL Image 
                                                        #from CIFAR and transform the data to CIFAR
roots= '/content/drive/My\ Drive/COMP_551/mini_3/data' #possible root

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transformer)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2) #Train Set

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transformer)  #Test Set
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# # MLP Implementation

# %%
class MLP():
    '''MLP Implementation'''
    
    
    def __init__(self, layer_dims, n_epochs, batch_size, alpha, 
                 hidden_layer_activation='relu', output_activation='softmax', 
                 dropout_ratio=0):
        '''MLP Construction
    
        Input Arguments: 

        layer_dims ([int]): number of nodes in each layer including input/output layers
        hidden_layer_activation (String): ('sigmoid', 'relu', 'leaky_relu') corresponding to activatoin in all hidden layers
        output_activation (String): ('sigmoid', 'softmax')
        dropout_prob (float): number between 0 (includsive) and 1 (exclusive) representing probability of dropout
        '''
            
        self.layer_dims = []
        for dim in layer_dims:
            dim_int = int(dim)
            
            if dim_int <= 0:
                raise ValueError("Layer dimensions must be greater than zero")
            else:
                self.layer_dims.append(dim_int)
                
        self.n_layers = len(self.layer_dims)
        
        self.batch_size = int(batch_size)
        self.n_epochs = int(n_epochs)
        self.alpha = float(alpha)
        
        if self.batch_size <= 0:
            raise ValueError("batch_size must be greater than 0")
        if self.n_epochs <= 0:
            raise ValueError("n_epochs must be greater than zero")
        if self.alpha <= 0:
            raise ValueError("learning rate must be greater than zero")
                
            
        self.hidden_layer_activation = hidden_layer_activation
        self.output_activation = output_activation
        if self.hidden_layer_activation not in ['sigmoid', 'relu', 'leaky_relu']:
            raise ValueError("Invalid hidden layer activation. Must be 'sigmoid', 'relu', or 'leaky_relu'")
        if self.output_activation not in ['sigmoid', 'softmax']:
            raise ValueError("Invalid output layer activation. Must be 'sigmoid' or 'softmax'")
            
        self.dropout_ratio = float(dropout_ratio)
        if self.dropout_ratio < 0 or self.dropout_ratio >= 1:
            raise ValueError("dropout_ratio must be between 0 (inclusive) and 1 (exclusive)")
         
        self.layers = []
        self.n_weights = 0
        for i, dim in enumerate(self.layer_dims):
            if i == 0: #input layer
                layer = MLP_Layer(dim, dim_prev=None, activation=None, dropout_ratio=0, 
                                  prev_layer=None, next_layer=None)
            elif i == self.n_layers - 1: #output layer
                layer = MLP_Layer(dim, dim_prev=last_layer_added.dim, activation = self.output_activation, 
                                  dropout_ratio = 0, prev_layer = last_layer_added, next_layer = None)
                last_layer_added.next_layer = layer
                self.n_weights += layer.dim * (layer.dim_prev + 1)
            else: 
                layer = MLP_Layer(dim, dim_prev=last_layer_added.dim, activation = self.hidden_layer_activation, 
                                  dropout_ratio = self.dropout_ratio, prev_layer = last_layer_added, next_layer = None)
                last_layer_added.next_layer = layer
                self.n_weights += layer.dim * (layer.dim_prev + 1)
                
                
            last_layer_added = layer
            self.layers.append(layer)
        
        
    def fit(self, X, y):
        assert X.shape[0] == y.shape[0], "Input and labels must have matching first dimension."
        X_batches, y_batches = self.batch(X, y)
        cost_list = []

        y_z, y_hat = self.forward(X, y, test=True)
        J = self.cost(y, y_z)
        print(f"EPOCH {0} | COST {J}")
        cost_list.append(J)

        for epoch in range(self.n_epochs):
            for X_batch, y_batch in zip(X_batches, y_batches):
                
            
                
                y_z, y_hat = self.forward(X_batch, y_batch) # y_z is before applying sigmoid or softmax
                
                J = self.cost(y_batch, y_z)
                
                self.output_grad(y_batch, y_hat)
                
                for layer in self.layers[-2:0:-1]: #all hidden layers
                    layer.backward_pass()
                    
                for layer in self.layers[-1:0:-1]: #output and all hidden layers
                    layer.update(self.alpha)
                
            
            
            if (epoch+1) % 5 == 0:  
                y_z, y_hat = self.forward(X, y, test=True)
                J = self.cost(y, y_z)
                print(f"EPOCH {epoch + 1} | COST {J}")
                cost_list.append(J)
            
        return cost_list

    
    def cost(self, y, y_z):
                
        if self.output_activation == 'softmax':    
            return self.softmax_cost(y, y_z)
        elif self.output_activation == 'sigmoid':
            return self.sigmoid_cost(y, y_z)
    
        
    
    def fit_document_acc(self, X, y, X_val, y_val):
        assert X.shape[0] == y.shape[0], "Input and labels must have matching first dimension."
        assert X_val.shape[0] == y_val.shape[0]
        X_batches, y_batches = self.batch(X, y)
        acc_list_train = []
        acc_list_val = []

        acc_train = self.predict_return_acc(X, y)
        acc_val = self.predict_return_acc(X_val, y_val)
        print(f"EPOCH {0}| TRAIN ACCURACY: {acc_train} | VAL ACCURACY: {acc_val}")
        acc_list_train.append(acc_train)
        acc_list_val.append(acc_val)


        for epoch in range(self.n_epochs):
            for X_batch, y_batch in zip(X_batches, y_batches):
                
               
                y_z, y_hat = self.forward(X_batch, y_batch) # y_z is before applying sigmoid or softmax
                
                J = self.cost(y_batch, y_z)
                
                self.output_grad(y_batch, y_hat)
                
                for layer in self.layers[-2:0:-1]: #all hidden layers
                    layer.backward_pass()
                    
                for layer in self.layers[-1:0:-1]: #output and all hidden layers
                    layer.update(self.alpha)
                    
                
            
            if (epoch + 1) % 5 == 0:    
                acc_train = self.predict_return_acc(X, y)
                acc_val = self.predict_return_acc(X_val, y_val)
                print(f"EPOCH {epoch + 1} | TRAIN ACCURACY: {acc_train} | VAL ACCURACY: {acc_val}")
                acc_list_train.append(acc_train)
                acc_list_val.append(acc_val)
            
        
        return acc_list_train, acc_list_val
        
            
        
                    
                
    def forward(self, X, y, test=False):
        self.layers[0].A = X.T
                
        for layer in self.layers[1::]:
            layer.forward_pass(test = test)

        return self.layers[-1].Z, self.layers[-1].A
        


    def batch(self, X, y):
        X, y = self.shuffle(X, y)
        X_batches = []
        y_batches = []

        m = X.shape[0]

        for i in range(0, m, self.batch_size):
            if i + self.batch_size <= m:
                X_batch = X[i:i + self.batch_size, :]
                y_batch = y[i:i + self.batch_size, :]

            else:
                X_batch = X[i:, :]
                y_batch = y[i:, :]
                
            X_batches.append(X_batch)
            y_batches.append(y_batch)

        return X_batches, y_batches


    def shuffle(self, X, y):
        p = np.random.permutation(X.shape[0])
        X = X[p, :]
        y = y[p, :]
        return X, y

    def softmax_cost(self, y, y_z):
        '''
        y: N x C
        y_z: C x N
        '''
        N = y.shape[0]
        return (1 / N) * (- np.sum(np.diagonal(np.dot(y, y_z))) - self.logsumexp(y_z))
    
    def sigmoid_cost(self, y, y_z):
        '''
        y: N x 1
        y_z: 1 x N
        '''
        return np.mean( y.T * np.log1p(np.exp(-y_z)) + (1-y.T) * np.log1p(np.exp(y_z)) )
    
    def logsumexp(self, Z):
        Zmax = np.max(Z, 0)[None, :] # 1 x n_examples
        return np.sum(Zmax + np.log(np.sum(np.exp(Z  - Zmax), axis=0))) #float

    def output_grad(self, y, y_hat):
        '''
        y: N X C (one hot encoded labels)
        y_hat: C x N (after applying softmax/sigmoid)
        '''
        N = y.shape[0]
        self.layers[-1].dZ = (1 / N) * (y_hat - y.T) # dim x n_examples
        #for both softmax and sigmoid!
        self.layers[-1].dW = np.dot(self.layers[-1].prev_layer.A, self.layers[-1].dZ.T) # dim_prev x dim
        self.layers[-1].db = np.sum(self.layers[-1].dZ, axis=1).reshape(-1, 1) # dim x 1

    def predict(self, X, y):
        _, y_hat = self.forward(X, y, test=True)
        y_pred = np.argmax(y_hat, axis=0).reshape(-1, 1)
        y_true = np.argmax(y, axis=1).reshape(-1, 1)
        return y_pred, y_true
    
    def predict_return_acc(self, X, y):
        y_pred, y_true = self.predict(X, y)
        return np.mean(y_pred == y_true)


 
        
        
        
        
        
        


class MLP_Layer():
    '''Layer of an MLP'''
    
    def __init__(self, dim, dim_prev=None, activation=None, dropout_ratio=0, next_layer=None, prev_layer=None, zeta=0.1):
        '''Constructing layer of MLP
    
        Input Arguments:

        dim (int): number of nodes in this layer
        dim_prev (int or None): number of nodes in the previous layer. None if input layer.
        activation (String or None): 'sigmoid', 'softmax', 'relu', or 'leaky_relu' indicating non-linearity to apply. None if input layer
        dropout_ratio (float): number between 0 (includsive) and 1 (exclusive) representing probability of dropout
        next_layer (MLP_Layer or None): the next layer in the MLP; if this is the output layer, set to None 
        prev_layer (MLP_Layer or None): the previous layer in the MLP; if this is the input layer, set to None 
        zeta(float): parameter for leaky relu activation
        '''
    
            
        self.dim = int(dim)
        if dim_prev != None:
            self.dim_prev = int(dim_prev)
            if self.dim_prev <= 0:
                raise ValueError("Layer dimensions must be positive integers")

        if self.dim <= 0:
            raise ValueError("Dimensions of layer are non-positive integers")
            
        self.dropout_ratio = float(dropout_ratio)

        if self.dropout_ratio < 0 or self.dropout_ratio >= 1:
            raise ValueError("dropout_ratio must be between 0 (inclusive) and 1 (exclusive)")
            
            
        self.zeta = float(zeta)
        if self.zeta <= 0:
            raise ValueError("zeta must be greater than zero")

        self.activation = activation
        if self.activation != None:
            if self.activation not in ['sigmoid', 'relu', 'leaky_relu', 'softmax']:
                raise ValueError("Invalid layer activation. Must be 'sigmoid', 'relu', 'leaky_relu', or 'softmax'")
        

        if next_layer != None:
            if not isintance(next_layer, MLP_Layer):
                raise TypeError("next_layer must be None or of type MLP_Layer")

        if prev_layer != None:
            if not isinstance(prev_layer, MLP_Layer):
                raise TypeError("prev_layer must be None or of type MLP_Layer")

        self.next_layer = next_layer
        self.prev_layer = prev_layer
        
        if dim_prev != None:
            self.W = np.random.randn(dim_prev, dim) * 0.1
            self.b = np.zeros((dim, 1))
            self.dW = np.zeros(self.W.shape)
            self.db = np.zeros(self.b.shape)
        else:
            self.W = None
            self.b = None
            self.dW = None
            self.db = None
        
        self.Z = None
        self.A = None

        
        self.dZ = None
        self.dA = None
             
       
            
    def forward_pass(self, test=False):
        self.Z = np.dot(self.W.T, self.prev_layer.A) + self.b # dim x n_examples
        self.A = self.activate()
        if test: #testing -- scale with zero dropout
            self.A = self.A * (1 - self.dropout_ratio)
        else: #training -- apply dropout
            dropout_mask = np.random.choice([0, 1], size = self.Z.shape, p=[self.dropout_ratio, 1 - self.dropout_ratio])
            self.A = self.A * dropout_mask
    
    def activate(self):
        if self.activation == 'sigmoid':
            return self.sigmoid()
        elif self.activation == 'relu':
            return self.relu()
        elif self.activation == 'leaky_relu':
            return self.leaky_relu()
        elif self.activation == 'softmax':
            return self.softmax()
            
    def sigmoid(self):
        return 1 / (1 + np.exp(-self.Z))
    
    def relu(self):
        return np.maximum(self.Z, np.zeros(self.Z.shape))
    
    def leaky_relu(self):
        return np.maximum(self.Z, np.zeros(self.Z.shape)) + self.zeta*np.minimum(self.Z, np.zeros(self.Z.shape))
    
    def softmax(self):
        return np.exp(self.Z) / (np.sum(np.exp(self.Z), axis=0).reshape(1, -1))
    
    
    def backward_pass(self):
        '''Calculates gradient for hidden layer'''
        self.dA = np.dot(self.next_layer.W, self.next_layer.dZ) # dim x n_examples

        if self.activation == 'sigmoid':
            self.dZ = self.dA * (self.A * (1 - self.A)) # dim x n_examples
        elif self.activation == 'relu':
            self.dZ = self.dA * (self.A > 0).astype(int)
        elif self.activation == 'leaky_relu':
            self.dZ = self.dA * (self.A > 0).astype(int)
            np.where(self.dZ, self.dZ, self.zeta) # if 0, set to zeta
        
        self.dW = np.dot(self.prev_layer.A, self.dZ.T) # dim_prev x dim
        self.db = np.sum(self.dZ, axis=1, keepdims=True) # dim x 1
        
        
    def update(self, alpha):
        self.W = self.W - alpha * self.dW
        self.b = self.b - alpha * self.b

# %% [markdown]
# ## CIFAR 10

# %%
trainloader_complete = torch.utils.data.DataLoader(trainset, batch_size=50000,
                                          shuffle=True, num_workers=2) #Entire Train Set
testloader_complete = torch.utils.data.DataLoader(testset, batch_size=10000,
                                          shuffle=True, num_workers=2) #Entire Test Set

X_train_tensor, y_train_tensor = iter(trainloader_complete).next()
X_test_tensor, y_test_tensor = iter(testloader_complete).next()

# %%
one_hot = OneHotEncoder(sparse=False)
y_train = one_hot.fit_transform(y_train_tensor.numpy().reshape(-1, 1))
y_test = one_hot.fit_transform(y_test_tensor.numpy().reshape(-1, 1))
X_train = X_train_tensor.numpy().reshape(50000, -1)
X_test = X_test_tensor.numpy().reshape(10000, -1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, random_state=42, shuffle=True, stratify=y_train, test_size=0.2)

# %%
def save_file(file, filename):
  with open(filename, 'wb') as f:
    pkl.dump(file, f) 

def document_model(model, X_train, y_train, X_val, y_val):
  result = {'model': None, 'train_acc_by_epoch': None, 'val_acc_by_epoch': None, 
            'train_acc': None, 'val_acc': None, 'conf_matrix_train': None, 
            'conf_matrix_val': None, 'train_time': None}
  t0 = time.clock()
  train_acc_by_epoch, val_acc_by_epoch = model.fit_document_acc(X_train, y_train, X_val, y_val)
  t1 = time.clock()

  tdiff = t1 - t0
  result['train_time'] = tdiff

  # cost = model.fit(X_train, y_train)

  print("EVALUATING ACCURACY")
  train_acc = model.predict_return_acc(X_train, y_train)
  val_acc = model.predict_return_acc(X_val, y_val)

  print("GENERATING CONFUSION MATRIX")
  y_pred_train, y_true_train = model.predict(X_train, y_train)
  y_pred_val, y_true_val = model.predict(X_val, y_val)
  conf_matrix_train = confusion_matrix(y_true_train, y_pred_train)
  conf_matrix_val = confusion_matrix(y_true_val, y_pred_val)

  result['model'] = model
  result['train_acc_by_epoch'] = train_acc_by_epoch
  result['val_acc_by_epoch'] = val_acc_by_epoch
  result['train_acc'] = train_acc
  result['val_acc'] = val_acc
  result['conf_matrix_train'] = conf_matrix_train
  result['conf_matrix_val'] = conf_matrix_val
  return result

# %% [markdown]
# First, let's settle on an optimized architecture to use for future experiments.
#
# Input Dimension: 3072
#
# Output Dimension: 10
#
#
# **Search Space**
#
#
# Number of Layers: [1, 2, 3, 4, 5]
#
# Hidden Nodes per Layer: [50-1000]

# %% [markdown]
# ### Zero Layer NN

# %%
mlp_0 = MLP([3072, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

# %%
mlp_0_results = document_model(mlp_0, X_train, y_train, X_val, y_val)
# Out:
# EPOCH 0| TRAIN ACCURACY: 0.098525 | VAL ACCURACY: 0.0997
# EVALUATING ACCURACY
# GENERATING CONFUSION MATRIX

# %%
save_file(mlp_0_results, 'mlp_0.pkl')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-64d073442022> in <module>()
# ----> 1 save_file(mlp_0_results, 'mlp_0.pkl')
#
# <ipython-input-110-16e85e27996d> in save_file(file, filename)
#       2   with open(filename, 'wb') as f:
#       3     pkl.dump(file, f)
# ----> 4   files.download(filename)
#       5
#       6
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %% [markdown]
# ### One Layer NN

# %%
mlp_10 = MLP([3072, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

# %%
mlp_10_results = document_model(mlp_10, X_train, y_train, X_val, y_val)
# Out:
# EPOCH 0| TRAIN ACCURACY: 0.08715 | VAL ACCURACY: 0.0869
# EPOCH 5 | TRAIN ACCURACY: 0.3164 | VAL ACCURACY: 0.3066
# EPOCH 10 | TRAIN ACCURACY: 0.3413 | VAL ACCURACY: 0.3278
# EPOCH 15 | TRAIN ACCURACY: 0.35545 | VAL ACCURACY: 0.3432
# EPOCH 20 | TRAIN ACCURACY: 0.36965 | VAL ACCURACY: 0.3565
# EPOCH 25 | TRAIN ACCURACY: 0.373 | VAL ACCURACY: 0.3607
# EPOCH 30 | TRAIN ACCURACY: 0.38005 | VAL ACCURACY: 0.3666
# EPOCH 35 | TRAIN ACCURACY: 0.38625 | VAL ACCURACY: 0.3729
# EPOCH 40 | TRAIN ACCURACY: 0.391225 | VAL ACCURACY: 0.3817
# EPOCH 45 | TRAIN ACCURACY: 0.396675 | VAL ACCURACY: 0.3866
# EPOCH 50 | TRAIN ACCURACY: 0.3989 | VAL ACCURACY: 0.3911
# EPOCH 55 | TRAIN ACCURACY: 0.399775 | VAL ACCURACY: 0.3883
# EPOCH 60 | TRAIN ACCURACY: 0.403325 | VAL ACCURACY: 0.3916
# EPOCH 65 | TRAIN ACCURACY: 0.405925 | VAL ACCURACY: 0.3916
# EPOCH 70 | TRAIN ACCURACY: 0.408075 | VAL ACCURACY: 0.3949
# EPOCH 75 | TRAIN ACCURACY: 0.410875 | VAL ACCURACY: 0.3932
# EPOCH 80 | TRAIN ACCURACY: 0.41295 | VAL ACCURACY: 0.3947
# EPOCH 85 | TRAIN ACCURACY: 0.413775 | VAL ACCURACY: 0.3996
# EPOCH 90 | TRAIN ACCURACY: 0.414425 | VAL ACCURACY: 0.4
# EPOCH 95 | TRAIN ACCURACY: 0.415375 | VAL ACCURACY: 0.4001
# EPOCH 100 | TRAIN ACCURACY: 0.418325 | VAL ACCURACY: 0.4007
# EPOCH 105 | TRAIN ACCURACY: 0.415575 | VAL ACCURACY: 0.3986
# EPOCH 110 | TRAIN ACCURACY: 0.418975 | VAL ACCURACY: 0.4033
# EPOCH 115 | TRAIN ACCURACY: 0.418425 | VAL ACCURACY: 0.4003
# EPOCH 120 | TRAIN ACCURACY: 0.418725 | VAL ACCURACY: 0.4046
# EPOCH 125 | TRAIN ACCURACY: 0.420325 | VAL ACCURACY: 0.4013
# EPOCH 130 | TRAIN ACCURACY: 0.423525 | VAL ACCURACY: 0.4028
# EPOCH 135 | TRAIN ACCURACY: 0.420725 | VAL ACCURACY: 0.4032
# EPOCH 140 | TRAIN ACCURACY: 0.424225 | VAL ACCURACY: 0.4019
# EPOCH 145 | TRAIN ACCURACY: 0.420775 | VAL ACCURACY: 0.3994
# EPOCH 150 | TRAIN ACCURACY: 0.42335 | VAL ACCURACY: 0.4029
# EPOCH 155 | TRAIN ACCURACY: 0.4268 | VAL ACCURACY: 0.404
# EPOCH 160 | TRAIN ACCURACY: 0.427275 | VAL ACCURACY: 0.4047
# EPOCH 165 | TRAIN ACCURACY: 0.426 | VAL ACCURACY: 0.4038
# EPOCH 170 | TRAIN ACCURACY: 0.429875 | VAL ACCURACY: 0.403
# EPOCH 175 | TRAIN ACCURACY: 0.426275 | VAL ACCURACY: 0.4001
# EPOCH 180 | TRAIN ACCURACY: 0.4263 | VAL ACCURACY: 0.4006
# EPOCH 185 | TRAIN ACCURACY: 0.430125 | VAL ACCURACY: 0.4014
# EPOCH 190 | TRAIN ACCURACY: 0.42975 | VAL ACCURACY: 0.3991
# EPOCH 195 | TRAIN ACCURACY: 0.431875 | VAL ACCURACY: 0.4014
# EPOCH 200 | TRAIN ACCURACY: 0.43195 | VAL ACCURACY: 0.4021
# EPOCH 205 | TRAIN ACCURACY: 0.4302 | VAL ACCURACY: 0.3998
# EPOCH 210 | TRAIN ACCURACY: 0.434675 | VAL ACCURACY: 0.3996
# EPOCH 215 | TRAIN ACCURACY: 0.4314 | VAL ACCURACY: 0.3989
# EPOCH 220 | TRAIN ACCURACY: 0.436275 | VAL ACCURACY: 0.4047
# EPOCH 225 | TRAIN ACCURACY: 0.43325 | VAL ACCURACY: 0.3983
# EPOCH 230 | TRAIN ACCURACY: 0.43525 | VAL ACCURACY: 0.3999
# EPOCH 235 | TRAIN ACCURACY: 0.435475 | VAL ACCURACY: 0.3989
# EPOCH 240 | TRAIN ACCURACY: 0.4347 | VAL ACCURACY: 0.3988
# EPOCH 245 | TRAIN ACCURACY: 0.4341 | VAL ACCURACY: 0.3961
# EPOCH 250 | TRAIN ACCURACY: 0.43905 | VAL ACCURACY: 0.4018
# EPOCH 255 | TRAIN ACCURACY: 0.44115 | VAL ACCURACY: 0.3993
# EPOCH 260 | TRAIN ACCURACY: 0.439225 | VAL ACCURACY: 0.3982
# EPOCH 265 | TRAIN ACCURACY: 0.4369 | VAL ACCURACY: 0.3987
# EPOCH 270 | TRAIN ACCURACY: 0.437175 | VAL ACCURACY: 0.3981
# EPOCH 275 | TRAIN ACCURACY: 0.437575 | VAL ACCURACY: 0.3975
# EPOCH 280 | TRAIN ACCURACY: 0.43605 | VAL ACCURACY: 0.393
# EPOCH 285 | TRAIN ACCURACY: 0.44225 | VAL ACCURACY: 0.4016
# EPOCH 290 | TRAIN ACCURACY: 0.440275 | VAL ACCURACY: 0.3966
# EPOCH 295 | TRAIN ACCURACY: 0.441275 | VAL ACCURACY: 0.398
# EPOCH 300 | TRAIN ACCURACY: 0.4404 | VAL ACCURACY: 0.3956
# EPOCH 305 | TRAIN ACCURACY: 0.438425 | VAL ACCURACY: 0.3952
# EPOCH 310 | TRAIN ACCURACY: 0.4388 | VAL ACCURACY: 0.3957
# EPOCH 315 | TRAIN ACCURACY: 0.44045 | VAL ACCURACY: 0.3951
# EPOCH 320 | TRAIN ACCURACY: 0.44145 | VAL ACCURACY: 0.398
# EPOCH 325 | TRAIN ACCURACY: 0.44225 | VAL ACCURACY: 0.3976
# EPOCH 330 | TRAIN ACCURACY: 0.4466 | VAL ACCURACY: 0.3992
# EPOCH 335 | TRAIN ACCURACY: 0.445775 | VAL ACCURACY: 0.3982
# EPOCH 340 | TRAIN ACCURACY: 0.44475 | VAL ACCURACY: 0.3962
# EPOCH 345 | TRAIN ACCURACY: 0.44285 | VAL ACCURACY: 0.3972
# EPOCH 350 | TRAIN ACCURACY: 0.440225 | VAL ACCURACY: 0.3962
# EPOCH 355 | TRAIN ACCURACY: 0.443225 | VAL ACCURACY: 0.3951
# EPOCH 360 | TRAIN ACCURACY: 0.44275 | VAL ACCURACY: 0.3951
# EPOCH 365 | TRAIN ACCURACY: 0.4425 | VAL ACCURACY: 0.3948
# EPOCH 370 | TRAIN ACCURACY: 0.4448 | VAL ACCURACY: 0.3959
# EPOCH 375 | TRAIN ACCURACY: 0.4443 | VAL ACCURACY: 0.3953
# EPOCH 380 | TRAIN ACCURACY: 0.445275 | VAL ACCURACY: 0.3946
# EPOCH 385 | TRAIN ACCURACY: 0.45265 | VAL ACCURACY: 0.4012
# EPOCH 390 | TRAIN ACCURACY: 0.45065 | VAL ACCURACY: 0.3971
# EPOCH 395 | TRAIN ACCURACY: 0.45195 | VAL ACCURACY: 0.3977
# EPOCH 400 | TRAIN ACCURACY: 0.44825 | VAL ACCURACY: 0.3964
# EPOCH 405 | TRAIN ACCURACY: 0.44875 | VAL ACCURACY: 0.393
# EPOCH 410 | TRAIN ACCURACY: 0.4479 | VAL ACCURACY: 0.3939
# EPOCH 415 | TRAIN ACCURACY: 0.45025 | VAL ACCURACY: 0.3928
# EPOCH 420 | TRAIN ACCURACY: 0.44425 | VAL ACCURACY: 0.3909
# EPOCH 425 | TRAIN ACCURACY: 0.447175 | VAL ACCURACY: 0.3912
# EPOCH 430 | TRAIN ACCURACY: 0.4474 | VAL ACCURACY: 0.393
# EPOCH 435 | TRAIN ACCURACY: 0.4482 | VAL ACCURACY: 0.3922
# EPOCH 440 | TRAIN ACCURACY: 0.44375 | VAL ACCURACY: 0.3882
# EPOCH 445 | TRAIN ACCURACY: 0.45395 | VAL ACCURACY: 0.3939
# EPOCH 450 | TRAIN ACCURACY: 0.45155 | VAL ACCURACY: 0.3929
# EPOCH 455 | TRAIN ACCURACY: 0.445775 | VAL ACCURACY: 0.3884
# EPOCH 460 | TRAIN ACCURACY: 0.44955 | VAL ACCURACY: 0.3897
# EPOCH 465 | TRAIN ACCURACY: 0.4451 | VAL ACCURACY: 0.3878
# EPOCH 470 | TRAIN ACCURACY: 0.444575 | VAL ACCURACY: 0.3874
# EPOCH 475 | TRAIN ACCURACY: 0.453425 | VAL ACCURACY: 0.3914
# EPOCH 480 | TRAIN ACCURACY: 0.452675 | VAL ACCURACY: 0.3929
# EPOCH 485 | TRAIN ACCURACY: 0.4484 | VAL ACCURACY: 0.3866
# EPOCH 490 | TRAIN ACCURACY: 0.447075 | VAL ACCURACY: 0.3886
# EPOCH 495 | TRAIN ACCURACY: 0.4536 | VAL ACCURACY: 0.39
# EPOCH 500 | TRAIN ACCURACY: 0.4538 | VAL ACCURACY: 0.39
# EPOCH 505 | TRAIN ACCURACY: 0.441525 | VAL ACCURACY: 0.3813
# EPOCH 510 | TRAIN ACCURACY: 0.455875 | VAL ACCURACY: 0.3914
# EPOCH 515 | TRAIN ACCURACY: 0.44685 | VAL ACCURACY: 0.3872
# EPOCH 520 | TRAIN ACCURACY: 0.452275 | VAL ACCURACY: 0.3887
# EPOCH 525 | TRAIN ACCURACY: 0.446725 | VAL ACCURACY: 0.3867
# EPOCH 530 | TRAIN ACCURACY: 0.450475 | VAL ACCURACY: 0.3871
# EPOCH 535 | TRAIN ACCURACY: 0.438325 | VAL ACCURACY: 0.3776
# EPOCH 540 | TRAIN ACCURACY: 0.449375 | VAL ACCURACY: 0.3849
# EPOCH 545 | TRAIN ACCURACY: 0.45825 | VAL ACCURACY: 0.3919
# EPOCH 550 | TRAIN ACCURACY: 0.4484 | VAL ACCURACY: 0.3836
# EPOCH 555 | TRAIN ACCURACY: 0.452225 | VAL ACCURACY: 0.3883
# EPOCH 560 | TRAIN ACCURACY: 0.4414 | VAL ACCURACY: 0.3769
# EPOCH 565 | TRAIN ACCURACY: 0.4537 | VAL ACCURACY: 0.3911
# EPOCH 570 | TRAIN ACCURACY: 0.4445 | VAL ACCURACY: 0.3803
# EPOCH 575 | TRAIN ACCURACY: 0.45255 | VAL ACCURACY: 0.3877
# EPOCH 580 | TRAIN ACCURACY: 0.4558 | VAL ACCURACY: 0.3892
# EPOCH 585 | TRAIN ACCURACY: 0.439775 | VAL ACCURACY: 0.3785
# EPOCH 590 | TRAIN ACCURACY: 0.453325 | VAL ACCURACY: 0.3841
# EPOCH 595 | TRAIN ACCURACY: 0.4549 | VAL ACCURACY: 0.3877
# EPOCH 600 | TRAIN ACCURACY: 0.44655 | VAL ACCURACY: 0.3804
# EPOCH 605 | TRAIN ACCURACY: 0.453725 | VAL ACCURACY: 0.3858
# EPOCH 610 | TRAIN ACCURACY: 0.45075 | VAL ACCURACY: 0.3802
# EPOCH 615 | TRAIN ACCURACY: 0.45725 | VAL ACCURACY: 0.3846
# EPOCH 620 | TRAIN ACCURACY: 0.461275 | VAL ACCURACY: 0.3901
# EPOCH 625 | TRAIN ACCURACY: 0.45635 | VAL ACCURACY: 0.3857
# EPOCH 630 | TRAIN ACCURACY: 0.45835 | VAL ACCURACY: 0.3873
# EPOCH 635 | TRAIN ACCURACY: 0.454175 | VAL ACCURACY: 0.3841
# EPOCH 640 | TRAIN ACCURACY: 0.4561 | VAL ACCURACY: 0.3864
# EPOCH 645 | TRAIN ACCURACY: 0.46575 | VAL ACCURACY: 0.3866
# EPOCH 650 | TRAIN ACCURACY: 0.45505 | VAL ACCURACY: 0.3878
# EPOCH 655 | TRAIN ACCURACY: 0.4552 | VAL ACCURACY: 0.385
# EPOCH 660 | TRAIN ACCURACY: 0.451325 | VAL ACCURACY: 0.3783
# EPOCH 665 | TRAIN ACCURACY: 0.4583 | VAL ACCURACY: 0.3873
# EPOCH 670 | TRAIN ACCURACY: 0.46245 | VAL ACCURACY: 0.3887
# EPOCH 675 | TRAIN ACCURACY: 0.45425 | VAL ACCURACY: 0.3819
# EPOCH 680 | TRAIN ACCURACY: 0.458975 | VAL ACCURACY: 0.3868
# EPOCH 685 | TRAIN ACCURACY: 0.45465 | VAL ACCURACY: 0.3827
# EPOCH 690 | TRAIN ACCURACY: 0.456975 | VAL ACCURACY: 0.381
# EPOCH 695 | TRAIN ACCURACY: 0.453675 | VAL ACCURACY: 0.3801
# EPOCH 700 | TRAIN ACCURACY: 0.4522 | VAL ACCURACY: 0.3812
# EPOCH 705 | TRAIN ACCURACY: 0.459125 | VAL ACCURACY: 0.3818
# EPOCH 710 | TRAIN ACCURACY: 0.461075 | VAL ACCURACY: 0.3855
# EPOCH 715 | TRAIN ACCURACY: 0.459525 | VAL ACCURACY: 0.3857
# EPOCH 720 | TRAIN ACCURACY: 0.458175 | VAL ACCURACY: 0.3847
# EPOCH 725 | TRAIN ACCURACY: 0.4386 | VAL ACCURACY: 0.3709
# EPOCH 730 | TRAIN ACCURACY: 0.462775 | VAL ACCURACY: 0.3857
# EPOCH 735 | TRAIN ACCURACY: 0.4566 | VAL ACCURACY: 0.3821
# EPOCH 740 | TRAIN ACCURACY: 0.4571 | VAL ACCURACY: 0.3799
# EPOCH 745 | TRAIN ACCURACY: 0.4597 | VAL ACCURACY: 0.3852
# EPOCH 750 | TRAIN ACCURACY: 0.456125 | VAL ACCURACY: 0.3793
# EPOCH 755 | TRAIN ACCURACY: 0.4452 | VAL ACCURACY: 0.3768
# EPOCH 760 | TRAIN ACCURACY: 0.457675 | VAL ACCURACY: 0.3795
# EPOCH 765 | TRAIN ACCURACY: 0.4564 | VAL ACCURACY: 0.3808
# EPOCH 770 | TRAIN ACCURACY: 0.4464 | VAL ACCURACY: 0.3788
# EPOCH 775 | TRAIN ACCURACY: 0.45955 | VAL ACCURACY: 0.3822
# EPOCH 780 | TRAIN ACCURACY: 0.45995 | VAL ACCURACY: 0.3849
# EPOCH 785 | TRAIN ACCURACY: 0.45315 | VAL ACCURACY: 0.3798
# EPOCH 790 | TRAIN ACCURACY: 0.451725 | VAL ACCURACY: 0.3774
# EPOCH 795 | TRAIN ACCURACY: 0.45285 | VAL ACCURACY: 0.3765
# EPOCH 800 | TRAIN ACCURACY: 0.456525 | VAL ACCURACY: 0.3797
# EPOCH 805 | TRAIN ACCURACY: 0.46725 | VAL ACCURACY: 0.3882
# EPOCH 810 | TRAIN ACCURACY: 0.4565 | VAL ACCURACY: 0.3753
# EPOCH 815 | TRAIN ACCURACY: 0.463225 | VAL ACCURACY: 0.3862
# EPOCH 820 | TRAIN ACCURACY: 0.4618 | VAL ACCURACY: 0.3835
# EPOCH 825 | TRAIN ACCURACY: 0.455075 | VAL ACCURACY: 0.3787
# EPOCH 830 | TRAIN ACCURACY: 0.445575 | VAL ACCURACY: 0.3723
# EPOCH 835 | TRAIN ACCURACY: 0.457825 | VAL ACCURACY: 0.3798
# EPOCH 840 | TRAIN ACCURACY: 0.468325 | VAL ACCURACY: 0.3846
# EPOCH 845 | TRAIN ACCURACY: 0.466175 | VAL ACCURACY: 0.3825
# EPOCH 850 | TRAIN ACCURACY: 0.458 | VAL ACCURACY: 0.3796
# EPOCH 855 | TRAIN ACCURACY: 0.462075 | VAL ACCURACY: 0.3827
# EPOCH 860 | TRAIN ACCURACY: 0.4591 | VAL ACCURACY: 0.3808
# EPOCH 865 | TRAIN ACCURACY: 0.468875 | VAL ACCURACY: 0.3837
# EPOCH 870 | TRAIN ACCURACY: 0.461575 | VAL ACCURACY: 0.382
# EPOCH 875 | TRAIN ACCURACY: 0.4665 | VAL ACCURACY: 0.3834
# EPOCH 880 | TRAIN ACCURACY: 0.4623 | VAL ACCURACY: 0.3817
# EPOCH 885 | TRAIN ACCURACY: 0.464625 | VAL ACCURACY: 0.383
# EPOCH 890 | TRAIN ACCURACY: 0.450825 | VAL ACCURACY: 0.3743
# EPOCH 895 | TRAIN ACCURACY: 0.453325 | VAL ACCURACY: 0.3772
# EPOCH 900 | TRAIN ACCURACY: 0.466025 | VAL ACCURACY: 0.3828
# EPOCH 905 | TRAIN ACCURACY: 0.45655 | VAL ACCURACY: 0.3745
# EPOCH 910 | TRAIN ACCURACY: 0.460675 | VAL ACCURACY: 0.38
# EPOCH 915 | TRAIN ACCURACY: 0.46835 | VAL ACCURACY: 0.3842
# EPOCH 920 | TRAIN ACCURACY: 0.45795 | VAL ACCURACY: 0.3742
# EPOCH 925 | TRAIN ACCURACY: 0.449725 | VAL ACCURACY: 0.3746
# EPOCH 930 | TRAIN ACCURACY: 0.464725 | VAL ACCURACY: 0.3851
# EPOCH 935 | TRAIN ACCURACY: 0.46115 | VAL ACCURACY: 0.3741
# EPOCH 940 | TRAIN ACCURACY: 0.456825 | VAL ACCURACY: 0.3762
# EPOCH 945 | TRAIN ACCURACY: 0.459375 | VAL ACCURACY: 0.3808
# EPOCH 950 | TRAIN ACCURACY: 0.46495 | VAL ACCURACY: 0.3785
# EPOCH 955 | TRAIN ACCURACY: 0.447475 | VAL ACCURACY: 0.3742
# EPOCH 960 | TRAIN ACCURACY: 0.454825 | VAL ACCURACY: 0.3779
# EPOCH 965 | TRAIN ACCURACY: 0.45175 | VAL ACCURACY: 0.3721
# EPOCH 970 | TRAIN ACCURACY: 0.45295 | VAL ACCURACY: 0.3772
# EPOCH 975 | TRAIN ACCURACY: 0.467475 | VAL ACCURACY: 0.3857
# EPOCH 980 | TRAIN ACCURACY: 0.4543 | VAL ACCURACY: 0.3735
# EPOCH 985 | TRAIN ACCURACY: 0.4725 | VAL ACCURACY: 0.3839
# EPOCH 990 | TRAIN ACCURACY: 0.459875 | VAL ACCURACY: 0.3751
# EPOCH 995 | TRAIN ACCURACY: 0.46775 | VAL ACCURACY: 0.3846
# EPOCH 1000 | TRAIN ACCURACY: 0.459675 | VAL ACCURACY: 0.3784
# EPOCH 1005 | TRAIN ACCURACY: 0.462625 | VAL ACCURACY: 0.3808
# EPOCH 1010 | TRAIN ACCURACY: 0.454075 | VAL ACCURACY: 0.3788
# EPOCH 1015 | TRAIN ACCURACY: 0.455775 | VAL ACCURACY: 0.3739
# EPOCH 1020 | TRAIN ACCURACY: 0.458875 | VAL ACCURACY: 0.3809
# EPOCH 1025 | TRAIN ACCURACY: 0.469275 | VAL ACCURACY: 0.3806
# EPOCH 1030 | TRAIN ACCURACY: 0.465875 | VAL ACCURACY: 0.3814
# EPOCH 1035 | TRAIN ACCURACY: 0.465025 | VAL ACCURACY: 0.3811
# EPOCH 1040 | TRAIN ACCURACY: 0.463575 | VAL ACCURACY: 0.3784
# EPOCH 1045 | TRAIN ACCURACY: 0.46525 | VAL ACCURACY: 0.3761
# EPOCH 1050 | TRAIN ACCURACY: 0.46425 | VAL ACCURACY: 0.3803
# EPOCH 1055 | TRAIN ACCURACY: 0.4755 | VAL ACCURACY: 0.3819
# EPOCH 1060 | TRAIN ACCURACY: 0.463625 | VAL ACCURACY: 0.3786
# EPOCH 1065 | TRAIN ACCURACY: 0.459075 | VAL ACCURACY: 0.3738
# EPOCH 1070 | TRAIN ACCURACY: 0.459075 | VAL ACCURACY: 0.3747
# EPOCH 1075 | TRAIN ACCURACY: 0.46525 | VAL ACCURACY: 0.3774
# EPOCH 1080 | TRAIN ACCURACY: 0.4639 | VAL ACCURACY: 0.3784
# EPOCH 1085 | TRAIN ACCURACY: 0.46675 | VAL ACCURACY: 0.3792
# EPOCH 1090 | TRAIN ACCURACY: 0.4633 | VAL ACCURACY: 0.3802
# EPOCH 1095 | TRAIN ACCURACY: 0.4533 | VAL ACCURACY: 0.3701
# EPOCH 1100 | TRAIN ACCURACY: 0.477625 | VAL ACCURACY: 0.3859
# EPOCH 1105 | TRAIN ACCURACY: 0.4684 | VAL ACCURACY: 0.3818
# EPOCH 1110 | TRAIN ACCURACY: 0.460975 | VAL ACCURACY: 0.3749
# EPOCH 1115 | TRAIN ACCURACY: 0.47165 | VAL ACCURACY: 0.3799
# EPOCH 1120 | TRAIN ACCURACY: 0.466125 | VAL ACCURACY: 0.3774
# EPOCH 1125 | TRAIN ACCURACY: 0.45085 | VAL ACCURACY: 0.3709
# EPOCH 1130 | TRAIN ACCURACY: 0.46775 | VAL ACCURACY: 0.3793
# EPOCH 1135 | TRAIN ACCURACY: 0.46845 | VAL ACCURACY: 0.3783
# EPOCH 1140 | TRAIN ACCURACY: 0.473525 | VAL ACCURACY: 0.3817
# EPOCH 1145 | TRAIN ACCURACY: 0.4592 | VAL ACCURACY: 0.3755
# EPOCH 1150 | TRAIN ACCURACY: 0.46845 | VAL ACCURACY: 0.3797
# EPOCH 1155 | TRAIN ACCURACY: 0.463025 | VAL ACCURACY: 0.3723
# EPOCH 1160 | TRAIN ACCURACY: 0.4643 | VAL ACCURACY: 0.3744
# EPOCH 1165 | TRAIN ACCURACY: 0.4706 | VAL ACCURACY: 0.3821
# EPOCH 1170 | TRAIN ACCURACY: 0.46205 | VAL ACCURACY: 0.3794
# EPOCH 1175 | TRAIN ACCURACY: 0.467675 | VAL ACCURACY: 0.3778
# EPOCH 1180 | TRAIN ACCURACY: 0.464425 | VAL ACCURACY: 0.3742
# EPOCH 1185 | TRAIN ACCURACY: 0.46365 | VAL ACCURACY: 0.3758
# EPOCH 1190 | TRAIN ACCURACY: 0.466925 | VAL ACCURACY: 0.3782
# EPOCH 1195 | TRAIN ACCURACY: 0.474975 | VAL ACCURACY: 0.3815
# EPOCH 1200 | TRAIN ACCURACY: 0.470825 | VAL ACCURACY: 0.3824
# EPOCH 1205 | TRAIN ACCURACY: 0.471775 | VAL ACCURACY: 0.3806
# EPOCH 1210 | TRAIN ACCURACY: 0.473775 | VAL ACCURACY: 0.3809
# EPOCH 1215 | TRAIN ACCURACY: 0.4448 | VAL ACCURACY: 0.3635
# EPOCH 1220 | TRAIN ACCURACY: 0.4714 | VAL ACCURACY: 0.3782
# EPOCH 1225 | TRAIN ACCURACY: 0.466975 | VAL ACCURACY: 0.3764
# EPOCH 1230 | TRAIN ACCURACY: 0.47405 | VAL ACCURACY: 0.3778
# EPOCH 1235 | TRAIN ACCURACY: 0.4728 | VAL ACCURACY: 0.3795
# EPOCH 1240 | TRAIN ACCURACY: 0.47345 | VAL ACCURACY: 0.38
# EPOCH 1245 | TRAIN ACCURACY: 0.467925 | VAL ACCURACY: 0.3797
# EPOCH 1250 | TRAIN ACCURACY: 0.47545 | VAL ACCURACY: 0.3835
# EPOCH 1255 | TRAIN ACCURACY: 0.46705 | VAL ACCURACY: 0.3767
# EPOCH 1260 | TRAIN ACCURACY: 0.472725 | VAL ACCURACY: 0.38
# EPOCH 1265 | TRAIN ACCURACY: 0.47395 | VAL ACCURACY: 0.3782
# EPOCH 1270 | TRAIN ACCURACY: 0.4671 | VAL ACCURACY: 0.3746
# EPOCH 1275 | TRAIN ACCURACY: 0.477875 | VAL ACCURACY: 0.3832
# EPOCH 1280 | TRAIN ACCURACY: 0.4588 | VAL ACCURACY: 0.3698
# EPOCH 1285 | TRAIN ACCURACY: 0.466375 | VAL ACCURACY: 0.3748
# EPOCH 1290 | TRAIN ACCURACY: 0.47735 | VAL ACCURACY: 0.38
# EPOCH 1295 | TRAIN ACCURACY: 0.475575 | VAL ACCURACY: 0.3798
# EPOCH 1300 | TRAIN ACCURACY: 0.46625 | VAL ACCURACY: 0.3779
# EPOCH 1305 | TRAIN ACCURACY: 0.457625 | VAL ACCURACY: 0.3697
# EPOCH 1310 | TRAIN ACCURACY: 0.4688 | VAL ACCURACY: 0.3795
# EPOCH 1315 | TRAIN ACCURACY: 0.4669 | VAL ACCURACY: 0.3788
# EPOCH 1320 | TRAIN ACCURACY: 0.4763 | VAL ACCURACY: 0.3817
# EPOCH 1325 | TRAIN ACCURACY: 0.476475 | VAL ACCURACY: 0.3789
# EPOCH 1330 | TRAIN ACCURACY: 0.472775 | VAL ACCURACY: 0.3785
# EPOCH 1335 | TRAIN ACCURACY: 0.476925 | VAL ACCURACY: 0.3789
# EPOCH 1340 | TRAIN ACCURACY: 0.47445 | VAL ACCURACY: 0.3788
# EPOCH 1345 | TRAIN ACCURACY: 0.478025 | VAL ACCURACY: 0.3818
# EPOCH 1350 | TRAIN ACCURACY: 0.470175 | VAL ACCURACY: 0.3762
# EPOCH 1355 | TRAIN ACCURACY: 0.47345 | VAL ACCURACY: 0.3758
# EPOCH 1360 | TRAIN ACCURACY: 0.454725 | VAL ACCURACY: 0.3713
# EPOCH 1365 | TRAIN ACCURACY: 0.463625 | VAL ACCURACY: 0.3744
# EPOCH 1370 | TRAIN ACCURACY: 0.473175 | VAL ACCURACY: 0.3767
# EPOCH 1375 | TRAIN ACCURACY: 0.463575 | VAL ACCURACY: 0.3745
# EPOCH 1380 | TRAIN ACCURACY: 0.4746 | VAL ACCURACY: 0.3793
# EPOCH 1385 | TRAIN ACCURACY: 0.4767 | VAL ACCURACY: 0.3787
# EPOCH 1390 | TRAIN ACCURACY: 0.477125 | VAL ACCURACY: 0.3809
# EPOCH 1395 | TRAIN ACCURACY: 0.46355 | VAL ACCURACY: 0.3748
# EPOCH 1400 | TRAIN ACCURACY: 0.4612 | VAL ACCURACY: 0.3738
# EPOCH 1405 | TRAIN ACCURACY: 0.4758 | VAL ACCURACY: 0.3806
# EPOCH 1410 | TRAIN ACCURACY: 0.470725 | VAL ACCURACY: 0.3755
# EPOCH 1415 | TRAIN ACCURACY: 0.471125 | VAL ACCURACY: 0.3741
# EPOCH 1420 | TRAIN ACCURACY: 0.47025 | VAL ACCURACY: 0.3758
# EPOCH 1425 | TRAIN ACCURACY: 0.47065 | VAL ACCURACY: 0.3769
# EPOCH 1430 | TRAIN ACCURACY: 0.47605 | VAL ACCURACY: 0.3812
# EPOCH 1435 | TRAIN ACCURACY: 0.461025 | VAL ACCURACY: 0.3686
# EPOCH 1440 | TRAIN ACCURACY: 0.471675 | VAL ACCURACY: 0.374
# EPOCH 1445 | TRAIN ACCURACY: 0.473175 | VAL ACCURACY: 0.3789
# EPOCH 1450 | TRAIN ACCURACY: 0.4741 | VAL ACCURACY: 0.379
# EPOCH 1455 | TRAIN ACCURACY: 0.463075 | VAL ACCURACY: 0.3717
# EPOCH 1460 | TRAIN ACCURACY: 0.473975 | VAL ACCURACY: 0.3775
# EPOCH 1465 | TRAIN ACCURACY: 0.4562 | VAL ACCURACY: 0.3729
# EPOCH 1470 | TRAIN ACCURACY: 0.4647 | VAL ACCURACY: 0.375
# EPOCH 1475 | TRAIN ACCURACY: 0.4586 | VAL ACCURACY: 0.3671
# EPOCH 1480 | TRAIN ACCURACY: 0.4737 | VAL ACCURACY: 0.3759
# EPOCH 1485 | TRAIN ACCURACY: 0.473375 | VAL ACCURACY: 0.3763
# EPOCH 1490 | TRAIN ACCURACY: 0.47655 | VAL ACCURACY: 0.3819
# EPOCH 1495 | TRAIN ACCURACY: 0.468875 | VAL ACCURACY: 0.3752
# EPOCH 1500 | TRAIN ACCURACY: 0.457175 | VAL ACCURACY: 0.3686
# EPOCH 1505 | TRAIN ACCURACY: 0.475 | VAL ACCURACY: 0.3766
# EPOCH 1510 | TRAIN ACCURACY: 0.457525 | VAL ACCURACY: 0.3738
# EPOCH 1515 | TRAIN ACCURACY: 0.460925 | VAL ACCURACY: 0.3677
# EPOCH 1520 | TRAIN ACCURACY: 0.46695 | VAL ACCURACY: 0.3738
# EPOCH 1525 | TRAIN ACCURACY: 0.4767 | VAL ACCURACY: 0.3783
# EPOCH 1530 | TRAIN ACCURACY: 0.475775 | VAL ACCURACY: 0.3764
# EPOCH 1535 | TRAIN ACCURACY: 0.47795 | VAL ACCURACY: 0.3794
# EPOCH 1540 | TRAIN ACCURACY: 0.461225 | VAL ACCURACY: 0.3721
# EPOCH 1545 | TRAIN ACCURACY: 0.458 | VAL ACCURACY: 0.3691
# EPOCH 1550 | TRAIN ACCURACY: 0.471025 | VAL ACCURACY: 0.378
# EPOCH 1555 | TRAIN ACCURACY: 0.4763 | VAL ACCURACY: 0.3783
# EPOCH 1560 | TRAIN ACCURACY: 0.46455 | VAL ACCURACY: 0.3744
# EPOCH 1565 | TRAIN ACCURACY: 0.467425 | VAL ACCURACY: 0.3763
# EPOCH 1570 | TRAIN ACCURACY: 0.463225 | VAL ACCURACY: 0.3744
# EPOCH 1575 | TRAIN ACCURACY: 0.4649 | VAL ACCURACY: 0.3713
# EPOCH 1580 | TRAIN ACCURACY: 0.475 | VAL ACCURACY: 0.3772
# EPOCH 1585 | TRAIN ACCURACY: 0.4636 | VAL ACCURACY: 0.3719
# EPOCH 1590 | TRAIN ACCURACY: 0.47735 | VAL ACCURACY: 0.3784
# EPOCH 1595 | TRAIN ACCURACY: 0.472375 | VAL ACCURACY: 0.3759
# EPOCH 1600 | TRAIN ACCURACY: 0.476975 | VAL ACCURACY: 0.3774
# EPOCH 1605 | TRAIN ACCURACY: 0.47745 | VAL ACCURACY: 0.3803
# EPOCH 1610 | TRAIN ACCURACY: 0.479875 | VAL ACCURACY: 0.3774
# EPOCH 1615 | TRAIN ACCURACY: 0.478875 | VAL ACCURACY: 0.3759
# EPOCH 1620 | TRAIN ACCURACY: 0.4807 | VAL ACCURACY: 0.377
# EPOCH 1625 | TRAIN ACCURACY: 0.46645 | VAL ACCURACY: 0.3745
# EPOCH 1630 | TRAIN ACCURACY: 0.4829 | VAL ACCURACY: 0.3805
# EPOCH 1635 | TRAIN ACCURACY: 0.475025 | VAL ACCURACY: 0.3787
# EPOCH 1640 | TRAIN ACCURACY: 0.48055 | VAL ACCURACY: 0.3754
# EPOCH 1645 | TRAIN ACCURACY: 0.450525 | VAL ACCURACY: 0.3598
# EPOCH 1650 | TRAIN ACCURACY: 0.46645 | VAL ACCURACY: 0.3703
# EPOCH 1655 | TRAIN ACCURACY: 0.47865 | VAL ACCURACY: 0.3763
# EPOCH 1660 | TRAIN ACCURACY: 0.479725 | VAL ACCURACY: 0.3787
# EPOCH 1665 | TRAIN ACCURACY: 0.47055 | VAL ACCURACY: 0.3747
# EPOCH 1670 | TRAIN ACCURACY: 0.47515 | VAL ACCURACY: 0.3761
# EPOCH 1675 | TRAIN ACCURACY: 0.4558 | VAL ACCURACY: 0.3674
# EPOCH 1680 | TRAIN ACCURACY: 0.460375 | VAL ACCURACY: 0.3725
# EPOCH 1685 | TRAIN ACCURACY: 0.469425 | VAL ACCURACY: 0.3745
# EPOCH 1690 | TRAIN ACCURACY: 0.482625 | VAL ACCURACY: 0.3788
# EPOCH 1695 | TRAIN ACCURACY: 0.47765 | VAL ACCURACY: 0.3761
# EPOCH 1700 | TRAIN ACCURACY: 0.4754 | VAL ACCURACY: 0.3793
# EPOCH 1705 | TRAIN ACCURACY: 0.481 | VAL ACCURACY: 0.3777
# EPOCH 1710 | TRAIN ACCURACY: 0.487175 | VAL ACCURACY: 0.3799
# EPOCH 1715 | TRAIN ACCURACY: 0.47595 | VAL ACCURACY: 0.3737
# EPOCH 1720 | TRAIN ACCURACY: 0.462075 | VAL ACCURACY: 0.368
# EPOCH 1725 | TRAIN ACCURACY: 0.483575 | VAL ACCURACY: 0.381
# EPOCH 1730 | TRAIN ACCURACY: 0.47425 | VAL ACCURACY: 0.378
# EPOCH 1735 | TRAIN ACCURACY: 0.478575 | VAL ACCURACY: 0.3783
# EPOCH 1740 | TRAIN ACCURACY: 0.476225 | VAL ACCURACY: 0.3772
# EPOCH 1745 | TRAIN ACCURACY: 0.4768 | VAL ACCURACY: 0.3782
# EPOCH 1750 | TRAIN ACCURACY: 0.468925 | VAL ACCURACY: 0.3711
# EPOCH 1755 | TRAIN ACCURACY: 0.467575 | VAL ACCURACY: 0.3743
# EPOCH 1760 | TRAIN ACCURACY: 0.469725 | VAL ACCURACY: 0.3724
# EPOCH 1765 | TRAIN ACCURACY: 0.47285 | VAL ACCURACY: 0.3732
# EPOCH 1770 | TRAIN ACCURACY: 0.476775 | VAL ACCURACY: 0.3729
# EPOCH 1775 | TRAIN ACCURACY: 0.475975 | VAL ACCURACY: 0.3748
# EPOCH 1780 | TRAIN ACCURACY: 0.47315 | VAL ACCURACY: 0.3765
# EPOCH 1785 | TRAIN ACCURACY: 0.478675 | VAL ACCURACY: 0.3766
# EPOCH 1790 | TRAIN ACCURACY: 0.478975 | VAL ACCURACY: 0.3785
# EPOCH 1795 | TRAIN ACCURACY: 0.487275 | VAL ACCURACY: 0.3819
# EPOCH 1800 | TRAIN ACCURACY: 0.4805 | VAL ACCURACY: 0.3741
# EPOCH 1805 | TRAIN ACCURACY: 0.477075 | VAL ACCURACY: 0.3779
# EPOCH 1810 | TRAIN ACCURACY: 0.481325 | VAL ACCURACY: 0.3736
# EPOCH 1815 | TRAIN ACCURACY: 0.4723 | VAL ACCURACY: 0.37
# EPOCH 1820 | TRAIN ACCURACY: 0.4818 | VAL ACCURACY: 0.378
# EPOCH 1825 | TRAIN ACCURACY: 0.484225 | VAL ACCURACY: 0.3782
# EPOCH 1830 | TRAIN ACCURACY: 0.481025 | VAL ACCURACY: 0.3788
# EPOCH 1835 | TRAIN ACCURACY: 0.461325 | VAL ACCURACY: 0.3653
# EPOCH 1840 | TRAIN ACCURACY: 0.478525 | VAL ACCURACY: 0.3765
# EPOCH 1845 | TRAIN ACCURACY: 0.476925 | VAL ACCURACY: 0.3705
# EPOCH 1850 | TRAIN ACCURACY: 0.476475 | VAL ACCURACY: 0.3789
# EPOCH 1855 | TRAIN ACCURACY: 0.47705 | VAL ACCURACY: 0.3748
# EPOCH 1860 | TRAIN ACCURACY: 0.471325 | VAL ACCURACY: 0.3679
# EPOCH 1865 | TRAIN ACCURACY: 0.476375 | VAL ACCURACY: 0.3752
# EPOCH 1870 | TRAIN ACCURACY: 0.4709 | VAL ACCURACY: 0.371
# EPOCH 1875 | TRAIN ACCURACY: 0.474675 | VAL ACCURACY: 0.375
# EPOCH 1880 | TRAIN ACCURACY: 0.475575 | VAL ACCURACY: 0.3737
# EPOCH 1885 | TRAIN ACCURACY: 0.481125 | VAL ACCURACY: 0.3749
# EPOCH 1890 | TRAIN ACCURACY: 0.47905 | VAL ACCURACY: 0.3739
# EPOCH 1895 | TRAIN ACCURACY: 0.480975 | VAL ACCURACY: 0.3722
# EPOCH 1900 | TRAIN ACCURACY: 0.478975 | VAL ACCURACY: 0.377
# EPOCH 1905 | TRAIN ACCURACY: 0.4814 | VAL ACCURACY: 0.3763
# EPOCH 1910 | TRAIN ACCURACY: 0.482125 | VAL ACCURACY: 0.3771
# EPOCH 1915 | TRAIN ACCURACY: 0.483125 | VAL ACCURACY: 0.3746
# EPOCH 1920 | TRAIN ACCURACY: 0.47885 | VAL ACCURACY: 0.3756
# EPOCH 1925 | TRAIN ACCURACY: 0.48125 | VAL ACCURACY: 0.3785
# EPOCH 1930 | TRAIN ACCURACY: 0.4791 | VAL ACCURACY: 0.3737
# EPOCH 1935 | TRAIN ACCURACY: 0.4713 | VAL ACCURACY: 0.3706
# EPOCH 1940 | TRAIN ACCURACY: 0.483725 | VAL ACCURACY: 0.3752
# EPOCH 1945 | TRAIN ACCURACY: 0.473325 | VAL ACCURACY: 0.3728
# EPOCH 1950 | TRAIN ACCURACY: 0.4802 | VAL ACCURACY: 0.378
# EPOCH 1955 | TRAIN ACCURACY: 0.489975 | VAL ACCURACY: 0.3735
# EPOCH 1960 | TRAIN ACCURACY: 0.47555 | VAL ACCURACY: 0.3752
# EPOCH 1965 | TRAIN ACCURACY: 0.472225 | VAL ACCURACY: 0.3703
# EPOCH 1970 | TRAIN ACCURACY: 0.4795 | VAL ACCURACY: 0.3773
# EPOCH 1975 | TRAIN ACCURACY: 0.4626 | VAL ACCURACY: 0.3695
# EPOCH 1980 | TRAIN ACCURACY: 0.4812 | VAL ACCURACY: 0.375
# EPOCH 1985 | TRAIN ACCURACY: 0.463825 | VAL ACCURACY: 0.3685
# EPOCH 1990 | TRAIN ACCURACY: 0.4803 | VAL ACCURACY: 0.3765
# EPOCH 1995 | TRAIN ACCURACY: 0.4873 | VAL ACCURACY: 0.377
# EPOCH 2000 | TRAIN ACCURACY: 0.460425 | VAL ACCURACY: 0.365
# EPOCH 2005 | TRAIN ACCURACY: 0.48005 | VAL ACCURACY: 0.3721
# EPOCH 2010 | TRAIN ACCURACY: 0.470475 | VAL ACCURACY: 0.3739
# EPOCH 2015 | TRAIN ACCURACY: 0.471 | VAL ACCURACY: 0.3714
# EPOCH 2020 | TRAIN ACCURACY: 0.47115 | VAL ACCURACY: 0.3716
# EPOCH 2025 | TRAIN ACCURACY: 0.48025 | VAL ACCURACY: 0.374
# EPOCH 2030 | TRAIN ACCURACY: 0.47435 | VAL ACCURACY: 0.3746
# EPOCH 2035 | TRAIN ACCURACY: 0.485675 | VAL ACCURACY: 0.3776
# EPOCH 2040 | TRAIN ACCURACY: 0.474775 | VAL ACCURACY: 0.3712
# EPOCH 2045 | TRAIN ACCURACY: 0.480075 | VAL ACCURACY: 0.3747
# EPOCH 2050 | TRAIN ACCURACY: 0.479775 | VAL ACCURACY: 0.3757
# EPOCH 2055 | TRAIN ACCURACY: 0.48505 | VAL ACCURACY: 0.3747
# EPOCH 2060 | TRAIN ACCURACY: 0.48515 | VAL ACCURACY: 0.3747
# EPOCH 2065 | TRAIN ACCURACY: 0.46695 | VAL ACCURACY: 0.3651
# EPOCH 2070 | TRAIN ACCURACY: 0.4723 | VAL ACCURACY: 0.372
# EPOCH 2075 | TRAIN ACCURACY: 0.479175 | VAL ACCURACY: 0.3716
# EPOCH 2080 | TRAIN ACCURACY: 0.48215 | VAL ACCURACY: 0.3786
# EPOCH 2085 | TRAIN ACCURACY: 0.484225 | VAL ACCURACY: 0.3764
# EPOCH 2090 | TRAIN ACCURACY: 0.47215 | VAL ACCURACY: 0.3724
# EPOCH 2095 | TRAIN ACCURACY: 0.4847 | VAL ACCURACY: 0.3776
# EPOCH 2100 | TRAIN ACCURACY: 0.4857 | VAL ACCURACY: 0.3765
# EPOCH 2105 | TRAIN ACCURACY: 0.474175 | VAL ACCURACY: 0.3667
# EPOCH 2110 | TRAIN ACCURACY: 0.471325 | VAL ACCURACY: 0.3698
# EPOCH 2115 | TRAIN ACCURACY: 0.47875 | VAL ACCURACY: 0.3732
# EPOCH 2120 | TRAIN ACCURACY: 0.478 | VAL ACCURACY: 0.3728
# EPOCH 2125 | TRAIN ACCURACY: 0.477625 | VAL ACCURACY: 0.3698
# EPOCH 2130 | TRAIN ACCURACY: 0.48385 | VAL ACCURACY: 0.3739
# EPOCH 2135 | TRAIN ACCURACY: 0.478925 | VAL ACCURACY: 0.3717
# EPOCH 2140 | TRAIN ACCURACY: 0.47835 | VAL ACCURACY: 0.3741
# EPOCH 2145 | TRAIN ACCURACY: 0.4654 | VAL ACCURACY: 0.3704
# EPOCH 2150 | TRAIN ACCURACY: 0.4831 | VAL ACCURACY: 0.3729
# EPOCH 2155 | TRAIN ACCURACY: 0.4825 | VAL ACCURACY: 0.376
# EPOCH 2160 | TRAIN ACCURACY: 0.48105 | VAL ACCURACY: 0.375
# EPOCH 2165 | TRAIN ACCURACY: 0.48125 | VAL ACCURACY: 0.3758
# EPOCH 2170 | TRAIN ACCURACY: 0.47025 | VAL ACCURACY: 0.3697
# EPOCH 2175 | TRAIN ACCURACY: 0.4834 | VAL ACCURACY: 0.3702
# EPOCH 2180 | TRAIN ACCURACY: 0.473625 | VAL ACCURACY: 0.3715
# EPOCH 2185 | TRAIN ACCURACY: 0.484525 | VAL ACCURACY: 0.3695
# EPOCH 2190 | TRAIN ACCURACY: 0.48675 | VAL ACCURACY: 0.3766
# EPOCH 2195 | TRAIN ACCURACY: 0.481325 | VAL ACCURACY: 0.3729
# EPOCH 2200 | TRAIN ACCURACY: 0.4779 | VAL ACCURACY: 0.3692
# EPOCH 2205 | TRAIN ACCURACY: 0.47885 | VAL ACCURACY: 0.3735
# EPOCH 2210 | TRAIN ACCURACY: 0.486625 | VAL ACCURACY: 0.3753
# EPOCH 2215 | TRAIN ACCURACY: 0.471825 | VAL ACCURACY: 0.3651
# EPOCH 2220 | TRAIN ACCURACY: 0.486825 | VAL ACCURACY: 0.3737
# EPOCH 2225 | TRAIN ACCURACY: 0.46315 | VAL ACCURACY: 0.3712
# EPOCH 2230 | TRAIN ACCURACY: 0.4805 | VAL ACCURACY: 0.3704
# EPOCH 2235 | TRAIN ACCURACY: 0.479125 | VAL ACCURACY: 0.3692
# EPOCH 2240 | TRAIN ACCURACY: 0.46755 | VAL ACCURACY: 0.3676
# EPOCH 2245 | TRAIN ACCURACY: 0.4825 | VAL ACCURACY: 0.3696
# EPOCH 2250 | TRAIN ACCURACY: 0.4847 | VAL ACCURACY: 0.3703
# EPOCH 2255 | TRAIN ACCURACY: 0.483775 | VAL ACCURACY: 0.3725
# EPOCH 2260 | TRAIN ACCURACY: 0.485425 | VAL ACCURACY: 0.3731
# EPOCH 2265 | TRAIN ACCURACY: 0.4825 | VAL ACCURACY: 0.3715
# EPOCH 2270 | TRAIN ACCURACY: 0.469425 | VAL ACCURACY: 0.3705
# EPOCH 2275 | TRAIN ACCURACY: 0.4879 | VAL ACCURACY: 0.3767
# EPOCH 2280 | TRAIN ACCURACY: 0.4741 | VAL ACCURACY: 0.3696
# EPOCH 2285 | TRAIN ACCURACY: 0.485125 | VAL ACCURACY: 0.3734
# EPOCH 2290 | TRAIN ACCURACY: 0.491125 | VAL ACCURACY: 0.374
# EPOCH 2295 | TRAIN ACCURACY: 0.480625 | VAL ACCURACY: 0.3671
# EPOCH 2300 | TRAIN ACCURACY: 0.46865 | VAL ACCURACY: 0.3695
# EPOCH 2305 | TRAIN ACCURACY: 0.490525 | VAL ACCURACY: 0.3736
# EPOCH 2310 | TRAIN ACCURACY: 0.48525 | VAL ACCURACY: 0.3755
# EPOCH 2315 | TRAIN ACCURACY: 0.453675 | VAL ACCURACY: 0.3579
# EPOCH 2320 | TRAIN ACCURACY: 0.472875 | VAL ACCURACY: 0.365
# EPOCH 2325 | TRAIN ACCURACY: 0.4891 | VAL ACCURACY: 0.37
# EPOCH 2330 | TRAIN ACCURACY: 0.48375 | VAL ACCURACY: 0.373
# EPOCH 2335 | TRAIN ACCURACY: 0.487875 | VAL ACCURACY: 0.3755
# EPOCH 2340 | TRAIN ACCURACY: 0.48695 | VAL ACCURACY: 0.3735
# EPOCH 2345 | TRAIN ACCURACY: 0.47935 | VAL ACCURACY: 0.3713
# EPOCH 2350 | TRAIN ACCURACY: 0.485325 | VAL ACCURACY: 0.373
# EPOCH 2355 | TRAIN ACCURACY: 0.48975 | VAL ACCURACY: 0.3765
# EPOCH 2360 | TRAIN ACCURACY: 0.476075 | VAL ACCURACY: 0.3701
# EPOCH 2365 | TRAIN ACCURACY: 0.48675 | VAL ACCURACY: 0.3742
# EPOCH 2370 | TRAIN ACCURACY: 0.47625 | VAL ACCURACY: 0.3687
# EPOCH 2375 | TRAIN ACCURACY: 0.485175 | VAL ACCURACY: 0.3729
# EPOCH 2380 | TRAIN ACCURACY: 0.4609 | VAL ACCURACY: 0.3645
# EPOCH 2385 | TRAIN ACCURACY: 0.47955 | VAL ACCURACY: 0.3728
# EPOCH 2390 | TRAIN ACCURACY: 0.488175 | VAL ACCURACY: 0.3709
# EPOCH 2395 | TRAIN ACCURACY: 0.488975 | VAL ACCURACY: 0.3729
# EPOCH 2400 | TRAIN ACCURACY: 0.4824 | VAL ACCURACY: 0.373
# EPOCH 2405 | TRAIN ACCURACY: 0.4755 | VAL ACCURACY: 0.3705
# EPOCH 2410 | TRAIN ACCURACY: 0.488225 | VAL ACCURACY: 0.3722
# EPOCH 2415 | TRAIN ACCURACY: 0.48285 | VAL ACCURACY: 0.3713
# EPOCH 2420 | TRAIN ACCURACY: 0.474125 | VAL ACCURACY: 0.3676
# EPOCH 2425 | TRAIN ACCURACY: 0.476475 | VAL ACCURACY: 0.3675
# EPOCH 2430 | TRAIN ACCURACY: 0.493225 | VAL ACCURACY: 0.3728
# EPOCH 2435 | TRAIN ACCURACY: 0.464775 | VAL ACCURACY: 0.3667
# EPOCH 2440 | TRAIN ACCURACY: 0.48255 | VAL ACCURACY: 0.3698
# EPOCH 2445 | TRAIN ACCURACY: 0.466275 | VAL ACCURACY: 0.3641
# EPOCH 2450 | TRAIN ACCURACY: 0.4884 | VAL ACCURACY: 0.3697
# EPOCH 2455 | TRAIN ACCURACY: 0.484 | VAL ACCURACY: 0.3716
# EPOCH 2460 | TRAIN ACCURACY: 0.467375 | VAL ACCURACY: 0.3671
# EPOCH 2465 | TRAIN ACCURACY: 0.489575 | VAL ACCURACY: 0.3717
# EPOCH 2470 | TRAIN ACCURACY: 0.488075 | VAL ACCURACY: 0.3711
# EPOCH 2475 | TRAIN ACCURACY: 0.481375 | VAL ACCURACY: 0.3704
# EPOCH 2480 | TRAIN ACCURACY: 0.46985 | VAL ACCURACY: 0.3678
# EPOCH 2485 | TRAIN ACCURACY: 0.4851 | VAL ACCURACY: 0.373
# EPOCH 2490 | TRAIN ACCURACY: 0.4832 | VAL ACCURACY: 0.3664
# EPOCH 2495 | TRAIN ACCURACY: 0.466825 | VAL ACCURACY: 0.3613
# EPOCH 2500 | TRAIN ACCURACY: 0.487175 | VAL ACCURACY: 0.3696
# EPOCH 2505 | TRAIN ACCURACY: 0.4816 | VAL ACCURACY: 0.3719
# EPOCH 2510 | TRAIN ACCURACY: 0.481175 | VAL ACCURACY: 0.3687
# EPOCH 2515 | TRAIN ACCURACY: 0.476175 | VAL ACCURACY: 0.3651
# EPOCH 2520 | TRAIN ACCURACY: 0.478625 | VAL ACCURACY: 0.3704
# EPOCH 2525 | TRAIN ACCURACY: 0.4823 | VAL ACCURACY: 0.3693
# EPOCH 2530 | TRAIN ACCURACY: 0.4741 | VAL ACCURACY: 0.3648
# EPOCH 2535 | TRAIN ACCURACY: 0.494575 | VAL ACCURACY: 0.3733
# EPOCH 2540 | TRAIN ACCURACY: 0.488225 | VAL ACCURACY: 0.3737
# EPOCH 2545 | TRAIN ACCURACY: 0.487625 | VAL ACCURACY: 0.3705
# EPOCH 2550 | TRAIN ACCURACY: 0.472375 | VAL ACCURACY: 0.3634
# EPOCH 2555 | TRAIN ACCURACY: 0.479175 | VAL ACCURACY: 0.3715
# EPOCH 2560 | TRAIN ACCURACY: 0.4651 | VAL ACCURACY: 0.3632
# EPOCH 2565 | TRAIN ACCURACY: 0.48825 | VAL ACCURACY: 0.3684
# EPOCH 2570 | TRAIN ACCURACY: 0.488275 | VAL ACCURACY: 0.3688
# EPOCH 2575 | TRAIN ACCURACY: 0.493925 | VAL ACCURACY: 0.3694
# EPOCH 2580 | TRAIN ACCURACY: 0.48095 | VAL ACCURACY: 0.3705
# EPOCH 2585 | TRAIN ACCURACY: 0.48865 | VAL ACCURACY: 0.3697
# EPOCH 2590 | TRAIN ACCURACY: 0.493775 | VAL ACCURACY: 0.3716
# EPOCH 2595 | TRAIN ACCURACY: 0.465575 | VAL ACCURACY: 0.3609
# EPOCH 2600 | TRAIN ACCURACY: 0.48975 | VAL ACCURACY: 0.3696
# EPOCH 2605 | TRAIN ACCURACY: 0.478325 | VAL ACCURACY: 0.3672
# EPOCH 2610 | TRAIN ACCURACY: 0.48455 | VAL ACCURACY: 0.3694
# EPOCH 2615 | TRAIN ACCURACY: 0.469525 | VAL ACCURACY: 0.3648
# EPOCH 2620 | TRAIN ACCURACY: 0.49055 | VAL ACCURACY: 0.3723
# EPOCH 2625 | TRAIN ACCURACY: 0.48835 | VAL ACCURACY: 0.3706
# EPOCH 2630 | TRAIN ACCURACY: 0.47155 | VAL ACCURACY: 0.3677
# EPOCH 2635 | TRAIN ACCURACY: 0.483425 | VAL ACCURACY: 0.3693
# EPOCH 2640 | TRAIN ACCURACY: 0.4908 | VAL ACCURACY: 0.3704
# EPOCH 2645 | TRAIN ACCURACY: 0.49275 | VAL ACCURACY: 0.3719
# EPOCH 2650 | TRAIN ACCURACY: 0.487975 | VAL ACCURACY: 0.3695
# EPOCH 2655 | TRAIN ACCURACY: 0.465025 | VAL ACCURACY: 0.3594
# EPOCH 2660 | TRAIN ACCURACY: 0.48055 | VAL ACCURACY: 0.3679
# EPOCH 2665 | TRAIN ACCURACY: 0.48595 | VAL ACCURACY: 0.3669
# EPOCH 2670 | TRAIN ACCURACY: 0.483975 | VAL ACCURACY: 0.3685
# EPOCH 2675 | TRAIN ACCURACY: 0.490925 | VAL ACCURACY: 0.3698
# EPOCH 2680 | TRAIN ACCURACY: 0.4671 | VAL ACCURACY: 0.3624
# EPOCH 2685 | TRAIN ACCURACY: 0.48355 | VAL ACCURACY: 0.3674
# EPOCH 2690 | TRAIN ACCURACY: 0.49425 | VAL ACCURACY: 0.3714
# EPOCH 2695 | TRAIN ACCURACY: 0.492675 | VAL ACCURACY: 0.3681
# EPOCH 2700 | TRAIN ACCURACY: 0.489875 | VAL ACCURACY: 0.37
# EPOCH 2705 | TRAIN ACCURACY: 0.482725 | VAL ACCURACY: 0.3704
# EPOCH 2710 | TRAIN ACCURACY: 0.477125 | VAL ACCURACY: 0.3666
# EPOCH 2715 | TRAIN ACCURACY: 0.487475 | VAL ACCURACY: 0.3697
# EPOCH 2720 | TRAIN ACCURACY: 0.466925 | VAL ACCURACY: 0.3647
# EPOCH 2725 | TRAIN ACCURACY: 0.4791 | VAL ACCURACY: 0.3685
# EPOCH 2730 | TRAIN ACCURACY: 0.48845 | VAL ACCURACY: 0.3676
# EPOCH 2735 | TRAIN ACCURACY: 0.48995 | VAL ACCURACY: 0.3677
# EPOCH 2740 | TRAIN ACCURACY: 0.49615 | VAL ACCURACY: 0.3719
# EPOCH 2745 | TRAIN ACCURACY: 0.4624 | VAL ACCURACY: 0.3608
# EPOCH 2750 | TRAIN ACCURACY: 0.49185 | VAL ACCURACY: 0.3679
# EPOCH 2755 | TRAIN ACCURACY: 0.48995 | VAL ACCURACY: 0.3709
# EPOCH 2760 | TRAIN ACCURACY: 0.47955 | VAL ACCURACY: 0.3674
# EPOCH 2765 | TRAIN ACCURACY: 0.49215 | VAL ACCURACY: 0.3721
# EPOCH 2770 | TRAIN ACCURACY: 0.49395 | VAL ACCURACY: 0.3706
# EPOCH 2775 | TRAIN ACCURACY: 0.485875 | VAL ACCURACY: 0.3691
# EPOCH 2780 | TRAIN ACCURACY: 0.48535 | VAL ACCURACY: 0.3679
# EPOCH 2785 | TRAIN ACCURACY: 0.47555 | VAL ACCURACY: 0.3609
# EPOCH 2790 | TRAIN ACCURACY: 0.494 | VAL ACCURACY: 0.3682
# EPOCH 2795 | TRAIN ACCURACY: 0.488 | VAL ACCURACY: 0.368
# EPOCH 2800 | TRAIN ACCURACY: 0.488275 | VAL ACCURACY: 0.3672
# EPOCH 2805 | TRAIN ACCURACY: 0.483825 | VAL ACCURACY: 0.3672
# EPOCH 2810 | TRAIN ACCURACY: 0.484525 | VAL ACCURACY: 0.3694
# EPOCH 2815 | TRAIN ACCURACY: 0.482425 | VAL ACCURACY: 0.3639
# EPOCH 2820 | TRAIN ACCURACY: 0.49095 | VAL ACCURACY: 0.37
# EPOCH 2825 | TRAIN ACCURACY: 0.478425 | VAL ACCURACY: 0.3686
# EPOCH 2830 | TRAIN ACCURACY: 0.48605 | VAL ACCURACY: 0.3686
# EPOCH 2835 | TRAIN ACCURACY: 0.48125 | VAL ACCURACY: 0.3621
# EPOCH 2840 | TRAIN ACCURACY: 0.48995 | VAL ACCURACY: 0.3666
# EPOCH 2845 | TRAIN ACCURACY: 0.467775 | VAL ACCURACY: 0.3605
# EPOCH 2850 | TRAIN ACCURACY: 0.483375 | VAL ACCURACY: 0.3681
# EPOCH 2855 | TRAIN ACCURACY: 0.4874 | VAL ACCURACY: 0.3647
# EPOCH 2860 | TRAIN ACCURACY: 0.4805 | VAL ACCURACY: 0.3665
# EPOCH 2865 | TRAIN ACCURACY: 0.482475 | VAL ACCURACY: 0.3629
# EPOCH 2870 | TRAIN ACCURACY: 0.48895 | VAL ACCURACY: 0.3664
# EPOCH 2875 | TRAIN ACCURACY: 0.47815 | VAL ACCURACY: 0.3648
# EPOCH 2880 | TRAIN ACCURACY: 0.493125 | VAL ACCURACY: 0.3657
# EPOCH 2885 | TRAIN ACCURACY: 0.488775 | VAL ACCURACY: 0.37
# EPOCH 2890 | TRAIN ACCURACY: 0.48775 | VAL ACCURACY: 0.3673
# EPOCH 2895 | TRAIN ACCURACY: 0.468625 | VAL ACCURACY: 0.3597
# EPOCH 2900 | TRAIN ACCURACY: 0.4958 | VAL ACCURACY: 0.3666
# EPOCH 2905 | TRAIN ACCURACY: 0.473725 | VAL ACCURACY: 0.3622
# EPOCH 2910 | TRAIN ACCURACY: 0.47675 | VAL ACCURACY: 0.3613
# EPOCH 2915 | TRAIN ACCURACY: 0.476875 | VAL ACCURACY: 0.3664
# EPOCH 2920 | TRAIN ACCURACY: 0.486325 | VAL ACCURACY: 0.3665
# EPOCH 2925 | TRAIN ACCURACY: 0.495725 | VAL ACCURACY: 0.3741
# EPOCH 2930 | TRAIN ACCURACY: 0.483825 | VAL ACCURACY: 0.3687
# EPOCH 2935 | TRAIN ACCURACY: 0.48455 | VAL ACCURACY: 0.3674
# EPOCH 2940 | TRAIN ACCURACY: 0.476875 | VAL ACCURACY: 0.3639
# EPOCH 2945 | TRAIN ACCURACY: 0.49375 | VAL ACCURACY: 0.3684
# EPOCH 2950 | TRAIN ACCURACY: 0.480475 | VAL ACCURACY: 0.3664
# EPOCH 2955 | TRAIN ACCURACY: 0.4944 | VAL ACCURACY: 0.3686
# EPOCH 2960 | TRAIN ACCURACY: 0.4892 | VAL ACCURACY: 0.3707
# EPOCH 2965 | TRAIN ACCURACY: 0.490975 | VAL ACCURACY: 0.3676
# EPOCH 2970 | TRAIN ACCURACY: 0.474275 | VAL ACCURACY: 0.3637
# EPOCH 2975 | TRAIN ACCURACY: 0.4908 | VAL ACCURACY: 0.3685
# EPOCH 2980 | TRAIN ACCURACY: 0.481725 | VAL ACCURACY: 0.3634
# EPOCH 2985 | TRAIN ACCURACY: 0.4846 | VAL ACCURACY: 0.3642
# EPOCH 2990 | TRAIN ACCURACY: 0.492825 | VAL ACCURACY: 0.3676
# EPOCH 2995 | TRAIN ACCURACY: 0.477975 | VAL ACCURACY: 0.3639
# EPOCH 3000 | TRAIN ACCURACY: 0.488875 | VAL ACCURACY: 0.3672
# EPOCH 3005 | TRAIN ACCURACY: 0.494525 | VAL ACCURACY: 0.3685
# EPOCH 3010 | TRAIN ACCURACY: 0.490175 | VAL ACCURACY: 0.3706
# EPOCH 3015 | TRAIN ACCURACY: 0.4913 | VAL ACCURACY: 0.364
# EPOCH 3020 | TRAIN ACCURACY: 0.493975 | VAL ACCURACY: 0.3673
# EPOCH 3025 | TRAIN ACCURACY: 0.492225 | VAL ACCURACY: 0.3668
# EPOCH 3030 | TRAIN ACCURACY: 0.490475 | VAL ACCURACY: 0.3649
# EPOCH 3035 | TRAIN ACCURACY: 0.488175 | VAL ACCURACY: 0.3627
# EPOCH 3040 | TRAIN ACCURACY: 0.48355 | VAL ACCURACY: 0.364
# EPOCH 3045 | TRAIN ACCURACY: 0.489875 | VAL ACCURACY: 0.3666
# EPOCH 3050 | TRAIN ACCURACY: 0.48035 | VAL ACCURACY: 0.365
# EPOCH 3055 | TRAIN ACCURACY: 0.493975 | VAL ACCURACY: 0.3654
# EPOCH 3060 | TRAIN ACCURACY: 0.4909 | VAL ACCURACY: 0.3667
# EPOCH 3065 | TRAIN ACCURACY: 0.48005 | VAL ACCURACY: 0.362
# EPOCH 3070 | TRAIN ACCURACY: 0.465725 | VAL ACCURACY: 0.364
# EPOCH 3075 | TRAIN ACCURACY: 0.493125 | VAL ACCURACY: 0.3681
# EPOCH 3080 | TRAIN ACCURACY: 0.495275 | VAL ACCURACY: 0.3672
# EPOCH 3085 | TRAIN ACCURACY: 0.49005 | VAL ACCURACY: 0.3662
# EPOCH 3090 | TRAIN ACCURACY: 0.489375 | VAL ACCURACY: 0.3673
# EPOCH 3095 | TRAIN ACCURACY: 0.490125 | VAL ACCURACY: 0.3671
# EPOCH 3100 | TRAIN ACCURACY: 0.48765 | VAL ACCURACY: 0.363
# EPOCH 3105 | TRAIN ACCURACY: 0.492775 | VAL ACCURACY: 0.3658
# EPOCH 3110 | TRAIN ACCURACY: 0.48355 | VAL ACCURACY: 0.3695
# EPOCH 3115 | TRAIN ACCURACY: 0.4909 | VAL ACCURACY: 0.3667
# EPOCH 3120 | TRAIN ACCURACY: 0.488 | VAL ACCURACY: 0.3671
# EPOCH 3125 | TRAIN ACCURACY: 0.486775 | VAL ACCURACY: 0.3657
# EPOCH 3130 | TRAIN ACCURACY: 0.496425 | VAL ACCURACY: 0.3667
# EPOCH 3135 | TRAIN ACCURACY: 0.488975 | VAL ACCURACY: 0.3656
# EPOCH 3140 | TRAIN ACCURACY: 0.474925 | VAL ACCURACY: 0.3631
# EPOCH 3145 | TRAIN ACCURACY: 0.47115 | VAL ACCURACY: 0.3601
# EPOCH 3150 | TRAIN ACCURACY: 0.492225 | VAL ACCURACY: 0.3679
# EPOCH 3155 | TRAIN ACCURACY: 0.48935 | VAL ACCURACY: 0.3649
# EPOCH 3160 | TRAIN ACCURACY: 0.4789 | VAL ACCURACY: 0.3621
# EPOCH 3165 | TRAIN ACCURACY: 0.491725 | VAL ACCURACY: 0.3654
# EPOCH 3170 | TRAIN ACCURACY: 0.48725 | VAL ACCURACY: 0.3673
# EPOCH 3175 | TRAIN ACCURACY: 0.498775 | VAL ACCURACY: 0.3677
# EPOCH 3180 | TRAIN ACCURACY: 0.495375 | VAL ACCURACY: 0.3681
# EPOCH 3185 | TRAIN ACCURACY: 0.49265 | VAL ACCURACY: 0.3667
# EPOCH 3190 | TRAIN ACCURACY: 0.4848 | VAL ACCURACY: 0.3681
# EPOCH 3195 | TRAIN ACCURACY: 0.488825 | VAL ACCURACY: 0.3642
# EPOCH 3200 | TRAIN ACCURACY: 0.493525 | VAL ACCURACY: 0.3615
# EPOCH 3205 | TRAIN ACCURACY: 0.4924 | VAL ACCURACY: 0.3652
# EPOCH 3210 | TRAIN ACCURACY: 0.491225 | VAL ACCURACY: 0.3652
# EPOCH 3215 | TRAIN ACCURACY: 0.4943 | VAL ACCURACY: 0.3673
# EPOCH 3220 | TRAIN ACCURACY: 0.487675 | VAL ACCURACY: 0.3648
# EPOCH 3225 | TRAIN ACCURACY: 0.484825 | VAL ACCURACY: 0.3635
# EPOCH 3230 | TRAIN ACCURACY: 0.4882 | VAL ACCURACY: 0.3637
# EPOCH 3235 | TRAIN ACCURACY: 0.494 | VAL ACCURACY: 0.3673
# EPOCH 3240 | TRAIN ACCURACY: 0.491625 | VAL ACCURACY: 0.3675
# EPOCH 3245 | TRAIN ACCURACY: 0.46915 | VAL ACCURACY: 0.3607
# EPOCH 3250 | TRAIN ACCURACY: 0.477675 | VAL ACCURACY: 0.3623
# EPOCH 3255 | TRAIN ACCURACY: 0.489975 | VAL ACCURACY: 0.3643
# EPOCH 3260 | TRAIN ACCURACY: 0.494775 | VAL ACCURACY: 0.3668
# EPOCH 3265 | TRAIN ACCURACY: 0.498125 | VAL ACCURACY: 0.3697
# EPOCH 3270 | TRAIN ACCURACY: 0.49425 | VAL ACCURACY: 0.365
# EPOCH 3275 | TRAIN ACCURACY: 0.492775 | VAL ACCURACY: 0.3675
# EPOCH 3280 | TRAIN ACCURACY: 0.4807 | VAL ACCURACY: 0.3652
# EPOCH 3285 | TRAIN ACCURACY: 0.47295 | VAL ACCURACY: 0.3614
# EPOCH 3290 | TRAIN ACCURACY: 0.4913 | VAL ACCURACY: 0.3629
# EPOCH 3295 | TRAIN ACCURACY: 0.494725 | VAL ACCURACY: 0.3673
# EPOCH 3300 | TRAIN ACCURACY: 0.490875 | VAL ACCURACY: 0.3636
# EPOCH 3305 | TRAIN ACCURACY: 0.4954 | VAL ACCURACY: 0.3657
# EPOCH 3310 | TRAIN ACCURACY: 0.487 | VAL ACCURACY: 0.3624
# EPOCH 3315 | TRAIN ACCURACY: 0.497825 | VAL ACCURACY: 0.3662
# EPOCH 3320 | TRAIN ACCURACY: 0.4874 | VAL ACCURACY: 0.3626
# EPOCH 3325 | TRAIN ACCURACY: 0.49565 | VAL ACCURACY: 0.3646
# EPOCH 3330 | TRAIN ACCURACY: 0.49025 | VAL ACCURACY: 0.3625
# EPOCH 3335 | TRAIN ACCURACY: 0.48425 | VAL ACCURACY: 0.3674
# EPOCH 3340 | TRAIN ACCURACY: 0.4942 | VAL ACCURACY: 0.3615
# EPOCH 3345 | TRAIN ACCURACY: 0.492925 | VAL ACCURACY: 0.3636
# EPOCH 3350 | TRAIN ACCURACY: 0.495275 | VAL ACCURACY: 0.3664
# EPOCH 3355 | TRAIN ACCURACY: 0.4929 | VAL ACCURACY: 0.3618
# EPOCH 3360 | TRAIN ACCURACY: 0.486775 | VAL ACCURACY: 0.3621
# EPOCH 3365 | TRAIN ACCURACY: 0.492725 | VAL ACCURACY: 0.3642
# EPOCH 3370 | TRAIN ACCURACY: 0.486025 | VAL ACCURACY: 0.366
# EPOCH 3375 | TRAIN ACCURACY: 0.489775 | VAL ACCURACY: 0.363
# EPOCH 3380 | TRAIN ACCURACY: 0.48945 | VAL ACCURACY: 0.3627
# EPOCH 3385 | TRAIN ACCURACY: 0.483225 | VAL ACCURACY: 0.3603
# EPOCH 3390 | TRAIN ACCURACY: 0.489075 | VAL ACCURACY: 0.3608
# EPOCH 3395 | TRAIN ACCURACY: 0.481975 | VAL ACCURACY: 0.3619
# EPOCH 3400 | TRAIN ACCURACY: 0.486425 | VAL ACCURACY: 0.3649
# EPOCH 3405 | TRAIN ACCURACY: 0.491975 | VAL ACCURACY: 0.3653
# EPOCH 3410 | TRAIN ACCURACY: 0.490975 | VAL ACCURACY: 0.3631
# EPOCH 3415 | TRAIN ACCURACY: 0.496475 | VAL ACCURACY: 0.3651
# EPOCH 3420 | TRAIN ACCURACY: 0.492675 | VAL ACCURACY: 0.3628
# EPOCH 3425 | TRAIN ACCURACY: 0.48735 | VAL ACCURACY: 0.3613
# EPOCH 3430 | TRAIN ACCURACY: 0.48935 | VAL ACCURACY: 0.3617
# EPOCH 3435 | TRAIN ACCURACY: 0.4866 | VAL ACCURACY: 0.3615
# EPOCH 3440 | TRAIN ACCURACY: 0.493875 | VAL ACCURACY: 0.3639
# EPOCH 3445 | TRAIN ACCURACY: 0.49535 | VAL ACCURACY: 0.3641
# EPOCH 3450 | TRAIN ACCURACY: 0.4913 | VAL ACCURACY: 0.3652
# EPOCH 3455 | TRAIN ACCURACY: 0.4847 | VAL ACCURACY: 0.3627
# EPOCH 3460 | TRAIN ACCURACY: 0.462875 | VAL ACCURACY: 0.3552
# EPOCH 3465 | TRAIN ACCURACY: 0.48555 | VAL ACCURACY: 0.3663
# EPOCH 3470 | TRAIN ACCURACY: 0.491075 | VAL ACCURACY: 0.3594
# EPOCH 3475 | TRAIN ACCURACY: 0.489 | VAL ACCURACY: 0.364
# EPOCH 3480 | TRAIN ACCURACY: 0.492875 | VAL ACCURACY: 0.3633
# EPOCH 3485 | TRAIN ACCURACY: 0.49345 | VAL ACCURACY: 0.3668
# EPOCH 3490 | TRAIN ACCURACY: 0.4778 | VAL ACCURACY: 0.3569
# EPOCH 3495 | TRAIN ACCURACY: 0.49215 | VAL ACCURACY: 0.3643
# EPOCH 3500 | TRAIN ACCURACY: 0.490125 | VAL ACCURACY: 0.3664
# EPOCH 3505 | TRAIN ACCURACY: 0.4897 | VAL ACCURACY: 0.3646
# EPOCH 3510 | TRAIN ACCURACY: 0.483775 | VAL ACCURACY: 0.3618
# EPOCH 3515 | TRAIN ACCURACY: 0.490925 | VAL ACCURACY: 0.367
# EPOCH 3520 | TRAIN ACCURACY: 0.4861 | VAL ACCURACY: 0.3634
# EPOCH 3525 | TRAIN ACCURACY: 0.4878 | VAL ACCURACY: 0.3609
# EPOCH 3530 | TRAIN ACCURACY: 0.471575 | VAL ACCURACY: 0.3564
# EPOCH 3535 | TRAIN ACCURACY: 0.499275 | VAL ACCURACY: 0.3673
# EPOCH 3540 | TRAIN ACCURACY: 0.4801 | VAL ACCURACY: 0.3566
# EPOCH 3545 | TRAIN ACCURACY: 0.492275 | VAL ACCURACY: 0.3625
# EPOCH 3550 | TRAIN ACCURACY: 0.4933 | VAL ACCURACY: 0.3648
# EPOCH 3555 | TRAIN ACCURACY: 0.4943 | VAL ACCURACY: 0.3657
# EPOCH 3560 | TRAIN ACCURACY: 0.4894 | VAL ACCURACY: 0.363
# EPOCH 3565 | TRAIN ACCURACY: 0.494925 | VAL ACCURACY: 0.3666
# EPOCH 3570 | TRAIN ACCURACY: 0.495775 | VAL ACCURACY: 0.3651
# EPOCH 3575 | TRAIN ACCURACY: 0.496325 | VAL ACCURACY: 0.3643
# EPOCH 3580 | TRAIN ACCURACY: 0.49695 | VAL ACCURACY: 0.3617
# EPOCH 3585 | TRAIN ACCURACY: 0.46185 | VAL ACCURACY: 0.3562
# EPOCH 3590 | TRAIN ACCURACY: 0.489225 | VAL ACCURACY: 0.3597
# EPOCH 3595 | TRAIN ACCURACY: 0.4962 | VAL ACCURACY: 0.3649
# EPOCH 3600 | TRAIN ACCURACY: 0.491625 | VAL ACCURACY: 0.3648
# EPOCH 3605 | TRAIN ACCURACY: 0.49775 | VAL ACCURACY: 0.3619
# EPOCH 3610 | TRAIN ACCURACY: 0.4937 | VAL ACCURACY: 0.3655
# EPOCH 3615 | TRAIN ACCURACY: 0.4919 | VAL ACCURACY: 0.3607
# EPOCH 3620 | TRAIN ACCURACY: 0.479525 | VAL ACCURACY: 0.3597
# EPOCH 3625 | TRAIN ACCURACY: 0.497825 | VAL ACCURACY: 0.3642
# EPOCH 3630 | TRAIN ACCURACY: 0.489925 | VAL ACCURACY: 0.3638
# EPOCH 3635 | TRAIN ACCURACY: 0.48625 | VAL ACCURACY: 0.3633
# EPOCH 3640 | TRAIN ACCURACY: 0.474775 | VAL ACCURACY: 0.358
# EPOCH 3645 | TRAIN ACCURACY: 0.488875 | VAL ACCURACY: 0.3612
# EPOCH 3650 | TRAIN ACCURACY: 0.4977 | VAL ACCURACY: 0.3652
# EPOCH 3655 | TRAIN ACCURACY: 0.48935 | VAL ACCURACY: 0.3625
# EPOCH 3660 | TRAIN ACCURACY: 0.4955 | VAL ACCURACY: 0.3603
# EPOCH 3665 | TRAIN ACCURACY: 0.497025 | VAL ACCURACY: 0.3629
# EPOCH 3670 | TRAIN ACCURACY: 0.494425 | VAL ACCURACY: 0.3612
# EPOCH 3675 | TRAIN ACCURACY: 0.50055 | VAL ACCURACY: 0.3632
# EPOCH 3680 | TRAIN ACCURACY: 0.486425 | VAL ACCURACY: 0.3554
# EPOCH 3685 | TRAIN ACCURACY: 0.489575 | VAL ACCURACY: 0.3652
# EPOCH 3690 | TRAIN ACCURACY: 0.491925 | VAL ACCURACY: 0.3643
# EPOCH 3695 | TRAIN ACCURACY: 0.485075 | VAL ACCURACY: 0.362
# EPOCH 3700 | TRAIN ACCURACY: 0.486425 | VAL ACCURACY: 0.3562
# EPOCH 3705 | TRAIN ACCURACY: 0.480575 | VAL ACCURACY: 0.3603
# EPOCH 3710 | TRAIN ACCURACY: 0.49135 | VAL ACCURACY: 0.3628
# EPOCH 3715 | TRAIN ACCURACY: 0.49615 | VAL ACCURACY: 0.3636
# EPOCH 3720 | TRAIN ACCURACY: 0.49145 | VAL ACCURACY: 0.3615
# EPOCH 3725 | TRAIN ACCURACY: 0.4859 | VAL ACCURACY: 0.3577
# EPOCH 3730 | TRAIN ACCURACY: 0.49475 | VAL ACCURACY: 0.3656
# EPOCH 3735 | TRAIN ACCURACY: 0.496875 | VAL ACCURACY: 0.3637
# EPOCH 3740 | TRAIN ACCURACY: 0.4944 | VAL ACCURACY: 0.3625
# EPOCH 3745 | TRAIN ACCURACY: 0.495175 | VAL ACCURACY: 0.3623
# EPOCH 3750 | TRAIN ACCURACY: 0.4959 | VAL ACCURACY: 0.3648
# EPOCH 3755 | TRAIN ACCURACY: 0.4916 | VAL ACCURACY: 0.3623
# EPOCH 3760 | TRAIN ACCURACY: 0.497925 | VAL ACCURACY: 0.363
# EPOCH 3765 | TRAIN ACCURACY: 0.496475 | VAL ACCURACY: 0.3626
# EPOCH 3770 | TRAIN ACCURACY: 0.48145 | VAL ACCURACY: 0.3633
# EPOCH 3775 | TRAIN ACCURACY: 0.4985 | VAL ACCURACY: 0.3623
# EPOCH 3780 | TRAIN ACCURACY: 0.483725 | VAL ACCURACY: 0.3575
# EPOCH 3785 | TRAIN ACCURACY: 0.499825 | VAL ACCURACY: 0.368
# EPOCH 3790 | TRAIN ACCURACY: 0.49215 | VAL ACCURACY: 0.3623
# EPOCH 3795 | TRAIN ACCURACY: 0.4962 | VAL ACCURACY: 0.3634
# EPOCH 3800 | TRAIN ACCURACY: 0.48785 | VAL ACCURACY: 0.3631
# EPOCH 3805 | TRAIN ACCURACY: 0.492825 | VAL ACCURACY: 0.3643
# EPOCH 3810 | TRAIN ACCURACY: 0.49925 | VAL ACCURACY: 0.3628
# EPOCH 3815 | TRAIN ACCURACY: 0.4949 | VAL ACCURACY: 0.3606
# EPOCH 3820 | TRAIN ACCURACY: 0.495075 | VAL ACCURACY: 0.3627
# EPOCH 3825 | TRAIN ACCURACY: 0.493275 | VAL ACCURACY: 0.3619
# EPOCH 3830 | TRAIN ACCURACY: 0.484825 | VAL ACCURACY: 0.3614
# EPOCH 3835 | TRAIN ACCURACY: 0.491325 | VAL ACCURACY: 0.3618
# EPOCH 3840 | TRAIN ACCURACY: 0.500325 | VAL ACCURACY: 0.3628
# EPOCH 3845 | TRAIN ACCURACY: 0.484525 | VAL ACCURACY: 0.361
# EPOCH 3850 | TRAIN ACCURACY: 0.48935 | VAL ACCURACY: 0.3622
# EPOCH 3855 | TRAIN ACCURACY: 0.48895 | VAL ACCURACY: 0.3604
# EPOCH 3860 | TRAIN ACCURACY: 0.493075 | VAL ACCURACY: 0.365
# EPOCH 3865 | TRAIN ACCURACY: 0.494725 | VAL ACCURACY: 0.3639
# EPOCH 3870 | TRAIN ACCURACY: 0.495325 | VAL ACCURACY: 0.364
# EPOCH 3875 | TRAIN ACCURACY: 0.495675 | VAL ACCURACY: 0.3618
# EPOCH 3880 | TRAIN ACCURACY: 0.50105 | VAL ACCURACY: 0.3645
# EPOCH 3885 | TRAIN ACCURACY: 0.46955 | VAL ACCURACY: 0.358
# EPOCH 3890 | TRAIN ACCURACY: 0.49715 | VAL ACCURACY: 0.3619
# EPOCH 3895 | TRAIN ACCURACY: 0.484775 | VAL ACCURACY: 0.361
# EPOCH 3900 | TRAIN ACCURACY: 0.498275 | VAL ACCURACY: 0.3612
# EPOCH 3905 | TRAIN ACCURACY: 0.49795 | VAL ACCURACY: 0.362
# EPOCH 3910 | TRAIN ACCURACY: 0.49505 | VAL ACCURACY: 0.3648
# EPOCH 3915 | TRAIN ACCURACY: 0.49575 | VAL ACCURACY: 0.3609
# EPOCH 3920 | TRAIN ACCURACY: 0.50305 | VAL ACCURACY: 0.3625
# EPOCH 3925 | TRAIN ACCURACY: 0.497275 | VAL ACCURACY: 0.3622
# EPOCH 3930 | TRAIN ACCURACY: 0.49915 | VAL ACCURACY: 0.3629
# EPOCH 3935 | TRAIN ACCURACY: 0.494325 | VAL ACCURACY: 0.3636
# EPOCH 3940 | TRAIN ACCURACY: 0.488575 | VAL ACCURACY: 0.3622
# EPOCH 3945 | TRAIN ACCURACY: 0.48565 | VAL ACCURACY: 0.3576
# EPOCH 3950 | TRAIN ACCURACY: 0.49465 | VAL ACCURACY: 0.3637
# EPOCH 3955 | TRAIN ACCURACY: 0.487875 | VAL ACCURACY: 0.3618
# EPOCH 3960 | TRAIN ACCURACY: 0.494725 | VAL ACCURACY: 0.3628
# EPOCH 3965 | TRAIN ACCURACY: 0.493225 | VAL ACCURACY: 0.3598
# EPOCH 3970 | TRAIN ACCURACY: 0.480725 | VAL ACCURACY: 0.3607
# EPOCH 3975 | TRAIN ACCURACY: 0.488 | VAL ACCURACY: 0.3583
# EPOCH 3980 | TRAIN ACCURACY: 0.496875 | VAL ACCURACY: 0.3627
# EPOCH 3985 | TRAIN ACCURACY: 0.49555 | VAL ACCURACY: 0.3614
# EPOCH 3990 | TRAIN ACCURACY: 0.50085 | VAL ACCURACY: 0.3615
# EPOCH 3995 | TRAIN ACCURACY: 0.488775 | VAL ACCURACY: 0.355
# EPOCH 4000 | TRAIN ACCURACY: 0.48985 | VAL ACCURACY: 0.3554
# ...
# EPOCH 8805 | TRAIN ACCURACY: 0.511125 | VAL ACCURACY: 0.3495
# EPOCH 8810 | TRAIN ACCURACY: 0.509425 | VAL ACCURACY: 0.3527
# EPOCH 8815 | TRAIN ACCURACY: 0.5109 | VAL ACCURACY: 0.346
# EPOCH 8820 | TRAIN ACCURACY: 0.515375 | VAL ACCURACY: 0.348
# EPOCH 8825 | TRAIN ACCURACY: 0.508675 | VAL ACCURACY: 0.348
# EPOCH 8830 | TRAIN ACCURACY: 0.514525 | VAL ACCURACY: 0.3531
# EPOCH 8835 | TRAIN ACCURACY: 0.5113 | VAL ACCURACY: 0.35
# EPOCH 8840 | TRAIN ACCURACY: 0.51145 | VAL ACCURACY: 0.3483
# EPOCH 8845 | TRAIN ACCURACY: 0.513675 | VAL ACCURACY: 0.354
# EPOCH 8850 | TRAIN ACCURACY: 0.5124 | VAL ACCURACY: 0.3474
# EPOCH 8855 | TRAIN ACCURACY: 0.513475 | VAL ACCURACY: 0.3495
# EPOCH 8860 | TRAIN ACCURACY: 0.50975 | VAL ACCURACY: 0.349
# EPOCH 8865 | TRAIN ACCURACY: 0.514725 | VAL ACCURACY: 0.3524
# EPOCH 8870 | TRAIN ACCURACY: 0.5108 | VAL ACCURACY: 0.3501
# EPOCH 8875 | TRAIN ACCURACY: 0.5152 | VAL ACCURACY: 0.349
# EPOCH 8880 | TRAIN ACCURACY: 0.495125 | VAL ACCURACY: 0.3499
# EPOCH 8885 | TRAIN ACCURACY: 0.503075 | VAL ACCURACY: 0.3486
# EPOCH 8890 | TRAIN ACCURACY: 0.5172 | VAL ACCURACY: 0.349
# EPOCH 8895 | TRAIN ACCURACY: 0.50855 | VAL ACCURACY: 0.3499
# EPOCH 8900 | TRAIN ACCURACY: 0.5136 | VAL ACCURACY: 0.3511
# EPOCH 8905 | TRAIN ACCURACY: 0.5107 | VAL ACCURACY: 0.3516
# EPOCH 8910 | TRAIN ACCURACY: 0.514425 | VAL ACCURACY: 0.3496
# EPOCH 8915 | TRAIN ACCURACY: 0.506975 | VAL ACCURACY: 0.3489
# EPOCH 8920 | TRAIN ACCURACY: 0.503175 | VAL ACCURACY: 0.3483
# EPOCH 8925 | TRAIN ACCURACY: 0.5143 | VAL ACCURACY: 0.3501
# EPOCH 8930 | TRAIN ACCURACY: 0.5088 | VAL ACCURACY: 0.3491
# EPOCH 8935 | TRAIN ACCURACY: 0.51025 | VAL ACCURACY: 0.3538
# EPOCH 8940 | TRAIN ACCURACY: 0.511925 | VAL ACCURACY: 0.3489
# EPOCH 8945 | TRAIN ACCURACY: 0.5081 | VAL ACCURACY: 0.3481
# EPOCH 8950 | TRAIN ACCURACY: 0.50935 | VAL ACCURACY: 0.3482
# EPOCH 8955 | TRAIN ACCURACY: 0.505775 | VAL ACCURACY: 0.3481
# EPOCH 8960 | TRAIN ACCURACY: 0.5085 | VAL ACCURACY: 0.3516
# EPOCH 8965 | TRAIN ACCURACY: 0.4925 | VAL ACCURACY: 0.346
# EPOCH 8970 | TRAIN ACCURACY: 0.510425 | VAL ACCURACY: 0.3518
# EPOCH 8975 | TRAIN ACCURACY: 0.507425 | VAL ACCURACY: 0.3466
# EPOCH 8980 | TRAIN ACCURACY: 0.5152 | VAL ACCURACY: 0.3518
# EPOCH 8985 | TRAIN ACCURACY: 0.48795 | VAL ACCURACY: 0.3482
# EPOCH 8990 | TRAIN ACCURACY: 0.504525 | VAL ACCURACY: 0.3496
# EPOCH 8995 | TRAIN ACCURACY: 0.517 | VAL ACCURACY: 0.3503
# EPOCH 9000 | TRAIN ACCURACY: 0.511675 | VAL ACCURACY: 0.352
# EPOCH 9005 | TRAIN ACCURACY: 0.5079 | VAL ACCURACY: 0.3448
# EPOCH 9010 | TRAIN ACCURACY: 0.515725 | VAL ACCURACY: 0.3493
# EPOCH 9015 | TRAIN ACCURACY: 0.5109 | VAL ACCURACY: 0.3528
# EPOCH 9020 | TRAIN ACCURACY: 0.5072 | VAL ACCURACY: 0.346
# EPOCH 9025 | TRAIN ACCURACY: 0.510525 | VAL ACCURACY: 0.3501
# EPOCH 9030 | TRAIN ACCURACY: 0.498925 | VAL ACCURACY: 0.347
# EPOCH 9035 | TRAIN ACCURACY: 0.500775 | VAL ACCURACY: 0.3499
# EPOCH 9040 | TRAIN ACCURACY: 0.50035 | VAL ACCURACY: 0.3529
# EPOCH 9045 | TRAIN ACCURACY: 0.5098 | VAL ACCURACY: 0.3499
# EPOCH 9050 | TRAIN ACCURACY: 0.51075 | VAL ACCURACY: 0.3495
# EPOCH 9055 | TRAIN ACCURACY: 0.51505 | VAL ACCURACY: 0.3502
# EPOCH 9060 | TRAIN ACCURACY: 0.503675 | VAL ACCURACY: 0.3485
# EPOCH 9065 | TRAIN ACCURACY: 0.51295 | VAL ACCURACY: 0.3519
# EPOCH 9070 | TRAIN ACCURACY: 0.498825 | VAL ACCURACY: 0.3454
# EPOCH 9075 | TRAIN ACCURACY: 0.5142 | VAL ACCURACY: 0.3527
# EPOCH 9080 | TRAIN ACCURACY: 0.5105 | VAL ACCURACY: 0.3505
# EPOCH 9085 | TRAIN ACCURACY: 0.51265 | VAL ACCURACY: 0.3496
# EPOCH 9090 | TRAIN ACCURACY: 0.49525 | VAL ACCURACY: 0.3457
# EPOCH 9095 | TRAIN ACCURACY: 0.5074 | VAL ACCURACY: 0.3474
# EPOCH 9100 | TRAIN ACCURACY: 0.515125 | VAL ACCURACY: 0.3504
# EPOCH 9105 | TRAIN ACCURACY: 0.510875 | VAL ACCURACY: 0.3506
# EPOCH 9110 | TRAIN ACCURACY: 0.49395 | VAL ACCURACY: 0.3477
# EPOCH 9115 | TRAIN ACCURACY: 0.513625 | VAL ACCURACY: 0.3527
# EPOCH 9120 | TRAIN ACCURACY: 0.513875 | VAL ACCURACY: 0.3492
# EPOCH 9125 | TRAIN ACCURACY: 0.51335 | VAL ACCURACY: 0.3492
# EPOCH 9130 | TRAIN ACCURACY: 0.487 | VAL ACCURACY: 0.3491
# EPOCH 9135 | TRAIN ACCURACY: 0.5002 | VAL ACCURACY: 0.3474
# EPOCH 9140 | TRAIN ACCURACY: 0.510625 | VAL ACCURACY: 0.3492
# EPOCH 9145 | TRAIN ACCURACY: 0.5138 | VAL ACCURACY: 0.3508
# EPOCH 9150 | TRAIN ACCURACY: 0.514575 | VAL ACCURACY: 0.3496
# EPOCH 9155 | TRAIN ACCURACY: 0.513825 | VAL ACCURACY: 0.3507
# EPOCH 9160 | TRAIN ACCURACY: 0.5156 | VAL ACCURACY: 0.3469
# EPOCH 9165 | TRAIN ACCURACY: 0.51315 | VAL ACCURACY: 0.351
# EPOCH 9170 | TRAIN ACCURACY: 0.510725 | VAL ACCURACY: 0.3495
# EPOCH 9175 | TRAIN ACCURACY: 0.493175 | VAL ACCURACY: 0.3475
# EPOCH 9180 | TRAIN ACCURACY: 0.512425 | VAL ACCURACY: 0.3507
# EPOCH 9185 | TRAIN ACCURACY: 0.50195 | VAL ACCURACY: 0.3478
# EPOCH 9190 | TRAIN ACCURACY: 0.498 | VAL ACCURACY: 0.3444
# EPOCH 9195 | TRAIN ACCURACY: 0.5116 | VAL ACCURACY: 0.3489
# EPOCH 9200 | TRAIN ACCURACY: 0.5109 | VAL ACCURACY: 0.3501
# EPOCH 9205 | TRAIN ACCURACY: 0.506675 | VAL ACCURACY: 0.3493
# EPOCH 9210 | TRAIN ACCURACY: 0.5132 | VAL ACCURACY: 0.3493
# EPOCH 9215 | TRAIN ACCURACY: 0.513225 | VAL ACCURACY: 0.3494
# EPOCH 9220 | TRAIN ACCURACY: 0.510775 | VAL ACCURACY: 0.3495
# EPOCH 9225 | TRAIN ACCURACY: 0.514875 | VAL ACCURACY: 0.353
# EPOCH 9230 | TRAIN ACCURACY: 0.51075 | VAL ACCURACY: 0.3495
# EPOCH 9235 | TRAIN ACCURACY: 0.489225 | VAL ACCURACY: 0.3474
# EPOCH 9240 | TRAIN ACCURACY: 0.50715 | VAL ACCURACY: 0.3509
# EPOCH 9245 | TRAIN ACCURACY: 0.510775 | VAL ACCURACY: 0.3528
# EPOCH 9250 | TRAIN ACCURACY: 0.5041 | VAL ACCURACY: 0.3519
# EPOCH 9255 | TRAIN ACCURACY: 0.5104 | VAL ACCURACY: 0.3487
# EPOCH 9260 | TRAIN ACCURACY: 0.483275 | VAL ACCURACY: 0.3453
# EPOCH 9265 | TRAIN ACCURACY: 0.491725 | VAL ACCURACY: 0.3417
# EPOCH 9270 | TRAIN ACCURACY: 0.507975 | VAL ACCURACY: 0.3483
# EPOCH 9275 | TRAIN ACCURACY: 0.51225 | VAL ACCURACY: 0.3531
# EPOCH 9280 | TRAIN ACCURACY: 0.48825 | VAL ACCURACY: 0.3471
# EPOCH 9285 | TRAIN ACCURACY: 0.50925 | VAL ACCURACY: 0.3495
# EPOCH 9290 | TRAIN ACCURACY: 0.5156 | VAL ACCURACY: 0.3516
# EPOCH 9295 | TRAIN ACCURACY: 0.511225 | VAL ACCURACY: 0.3497
# EPOCH 9300 | TRAIN ACCURACY: 0.51115 | VAL ACCURACY: 0.3474
# EPOCH 9305 | TRAIN ACCURACY: 0.5071 | VAL ACCURACY: 0.3489
# EPOCH 9310 | TRAIN ACCURACY: 0.514875 | VAL ACCURACY: 0.3483
# EPOCH 9315 | TRAIN ACCURACY: 0.507925 | VAL ACCURACY: 0.3462
# EPOCH 9320 | TRAIN ACCURACY: 0.5125 | VAL ACCURACY: 0.3515
# EPOCH 9325 | TRAIN ACCURACY: 0.515725 | VAL ACCURACY: 0.3496
# EPOCH 9330 | TRAIN ACCURACY: 0.51515 | VAL ACCURACY: 0.3498
# EPOCH 9335 | TRAIN ACCURACY: 0.49535 | VAL ACCURACY: 0.3465
# EPOCH 9340 | TRAIN ACCURACY: 0.515125 | VAL ACCURACY: 0.3505
# EPOCH 9345 | TRAIN ACCURACY: 0.5178 | VAL ACCURACY: 0.3497
# EPOCH 9350 | TRAIN ACCURACY: 0.5024 | VAL ACCURACY: 0.3456
# EPOCH 9355 | TRAIN ACCURACY: 0.50955 | VAL ACCURACY: 0.3461
# EPOCH 9360 | TRAIN ACCURACY: 0.50875 | VAL ACCURACY: 0.3472
# EPOCH 9365 | TRAIN ACCURACY: 0.508025 | VAL ACCURACY: 0.3473
# EPOCH 9370 | TRAIN ACCURACY: 0.51385 | VAL ACCURACY: 0.3466
# EPOCH 9375 | TRAIN ACCURACY: 0.5098 | VAL ACCURACY: 0.3498
# EPOCH 9380 | TRAIN ACCURACY: 0.506825 | VAL ACCURACY: 0.3515
# EPOCH 9385 | TRAIN ACCURACY: 0.518075 | VAL ACCURACY: 0.3528
# EPOCH 9390 | TRAIN ACCURACY: 0.51595 | VAL ACCURACY: 0.3478
# EPOCH 9395 | TRAIN ACCURACY: 0.510675 | VAL ACCURACY: 0.3468
# EPOCH 9400 | TRAIN ACCURACY: 0.51605 | VAL ACCURACY: 0.3483
# EPOCH 9405 | TRAIN ACCURACY: 0.5149 | VAL ACCURACY: 0.3471
# EPOCH 9410 | TRAIN ACCURACY: 0.513875 | VAL ACCURACY: 0.3501
# EPOCH 9415 | TRAIN ACCURACY: 0.50895 | VAL ACCURACY: 0.348
# EPOCH 9420 | TRAIN ACCURACY: 0.50825 | VAL ACCURACY: 0.3436
# EPOCH 9425 | TRAIN ACCURACY: 0.5151 | VAL ACCURACY: 0.3497
# EPOCH 9430 | TRAIN ACCURACY: 0.503525 | VAL ACCURACY: 0.351
# EPOCH 9435 | TRAIN ACCURACY: 0.50715 | VAL ACCURACY: 0.3504
# EPOCH 9440 | TRAIN ACCURACY: 0.5129 | VAL ACCURACY: 0.3493
# EPOCH 9445 | TRAIN ACCURACY: 0.5178 | VAL ACCURACY: 0.3494
# EPOCH 9450 | TRAIN ACCURACY: 0.5149 | VAL ACCURACY: 0.3481
# EPOCH 9455 | TRAIN ACCURACY: 0.5122 | VAL ACCURACY: 0.3506
# EPOCH 9460 | TRAIN ACCURACY: 0.4984 | VAL ACCURACY: 0.3486
# EPOCH 9465 | TRAIN ACCURACY: 0.5154 | VAL ACCURACY: 0.3502
# EPOCH 9470 | TRAIN ACCURACY: 0.513775 | VAL ACCURACY: 0.3497
# EPOCH 9475 | TRAIN ACCURACY: 0.51225 | VAL ACCURACY: 0.3508
# EPOCH 9480 | TRAIN ACCURACY: 0.51585 | VAL ACCURACY: 0.3506
# EPOCH 9485 | TRAIN ACCURACY: 0.50795 | VAL ACCURACY: 0.3454
# EPOCH 9490 | TRAIN ACCURACY: 0.512825 | VAL ACCURACY: 0.348
# EPOCH 9495 | TRAIN ACCURACY: 0.514125 | VAL ACCURACY: 0.3515
# EPOCH 9500 | TRAIN ACCURACY: 0.512525 | VAL ACCURACY: 0.3502
# EPOCH 9505 | TRAIN ACCURACY: 0.5019 | VAL ACCURACY: 0.3481
# EPOCH 9510 | TRAIN ACCURACY: 0.516 | VAL ACCURACY: 0.3503
# EPOCH 9515 | TRAIN ACCURACY: 0.515525 | VAL ACCURACY: 0.3505
# EPOCH 9520 | TRAIN ACCURACY: 0.511225 | VAL ACCURACY: 0.3442
# EPOCH 9525 | TRAIN ACCURACY: 0.51185 | VAL ACCURACY: 0.3506
# EPOCH 9530 | TRAIN ACCURACY: 0.5111 | VAL ACCURACY: 0.3494
# EPOCH 9535 | TRAIN ACCURACY: 0.51255 | VAL ACCURACY: 0.3502
# EPOCH 9540 | TRAIN ACCURACY: 0.50115 | VAL ACCURACY: 0.3429
# EPOCH 9545 | TRAIN ACCURACY: 0.515975 | VAL ACCURACY: 0.3499
# EPOCH 9550 | TRAIN ACCURACY: 0.5149 | VAL ACCURACY: 0.3506
# EPOCH 9555 | TRAIN ACCURACY: 0.51235 | VAL ACCURACY: 0.349
# EPOCH 9560 | TRAIN ACCURACY: 0.5127 | VAL ACCURACY: 0.3473
# EPOCH 9565 | TRAIN ACCURACY: 0.504175 | VAL ACCURACY: 0.3479
# EPOCH 9570 | TRAIN ACCURACY: 0.51315 | VAL ACCURACY: 0.3488
# EPOCH 9575 | TRAIN ACCURACY: 0.51245 | VAL ACCURACY: 0.351
# EPOCH 9580 | TRAIN ACCURACY: 0.503975 | VAL ACCURACY: 0.349
# EPOCH 9585 | TRAIN ACCURACY: 0.503275 | VAL ACCURACY: 0.3463
# EPOCH 9590 | TRAIN ACCURACY: 0.5086 | VAL ACCURACY: 0.3511
# EPOCH 9595 | TRAIN ACCURACY: 0.50675 | VAL ACCURACY: 0.3475
# EPOCH 9600 | TRAIN ACCURACY: 0.5167 | VAL ACCURACY: 0.3479
# EPOCH 9605 | TRAIN ACCURACY: 0.514 | VAL ACCURACY: 0.3501
# EPOCH 9610 | TRAIN ACCURACY: 0.486475 | VAL ACCURACY: 0.3454
# EPOCH 9615 | TRAIN ACCURACY: 0.5112 | VAL ACCURACY: 0.3486
# EPOCH 9620 | TRAIN ACCURACY: 0.5062 | VAL ACCURACY: 0.3523
# EPOCH 9625 | TRAIN ACCURACY: 0.513925 | VAL ACCURACY: 0.3513
# EPOCH 9630 | TRAIN ACCURACY: 0.516575 | VAL ACCURACY: 0.3541
# EPOCH 9635 | TRAIN ACCURACY: 0.51605 | VAL ACCURACY: 0.35
# EPOCH 9640 | TRAIN ACCURACY: 0.51305 | VAL ACCURACY: 0.3479
# EPOCH 9645 | TRAIN ACCURACY: 0.509225 | VAL ACCURACY: 0.3507
# EPOCH 9650 | TRAIN ACCURACY: 0.5193 | VAL ACCURACY: 0.3525
# EPOCH 9655 | TRAIN ACCURACY: 0.4976 | VAL ACCURACY: 0.3453
# EPOCH 9660 | TRAIN ACCURACY: 0.51405 | VAL ACCURACY: 0.3494
# EPOCH 9665 | TRAIN ACCURACY: 0.51155 | VAL ACCURACY: 0.3466
# EPOCH 9670 | TRAIN ACCURACY: 0.508075 | VAL ACCURACY: 0.3497
# EPOCH 9675 | TRAIN ACCURACY: 0.5164 | VAL ACCURACY: 0.3513
# EPOCH 9680 | TRAIN ACCURACY: 0.5168 | VAL ACCURACY: 0.3484
# EPOCH 9685 | TRAIN ACCURACY: 0.491875 | VAL ACCURACY: 0.3462
# EPOCH 9690 | TRAIN ACCURACY: 0.512325 | VAL ACCURACY: 0.3479
# EPOCH 9695 | TRAIN ACCURACY: 0.50825 | VAL ACCURACY: 0.35
# EPOCH 9700 | TRAIN ACCURACY: 0.513925 | VAL ACCURACY: 0.348
# EPOCH 9705 | TRAIN ACCURACY: 0.516075 | VAL ACCURACY: 0.3493
# EPOCH 9710 | TRAIN ACCURACY: 0.4928 | VAL ACCURACY: 0.3445
# EPOCH 9715 | TRAIN ACCURACY: 0.51845 | VAL ACCURACY: 0.3518
# EPOCH 9720 | TRAIN ACCURACY: 0.51745 | VAL ACCURACY: 0.3508
# EPOCH 9725 | TRAIN ACCURACY: 0.51335 | VAL ACCURACY: 0.3503
# EPOCH 9730 | TRAIN ACCURACY: 0.513725 | VAL ACCURACY: 0.3492
# EPOCH 9735 | TRAIN ACCURACY: 0.51445 | VAL ACCURACY: 0.3458
# EPOCH 9740 | TRAIN ACCURACY: 0.518275 | VAL ACCURACY: 0.3528
# EPOCH 9745 | TRAIN ACCURACY: 0.5158 | VAL ACCURACY: 0.3525
# EPOCH 9750 | TRAIN ACCURACY: 0.4876 | VAL ACCURACY: 0.3464
# EPOCH 9755 | TRAIN ACCURACY: 0.519375 | VAL ACCURACY: 0.3508
# EPOCH 9760 | TRAIN ACCURACY: 0.518275 | VAL ACCURACY: 0.3488
# EPOCH 9765 | TRAIN ACCURACY: 0.516075 | VAL ACCURACY: 0.3481
# EPOCH 9770 | TRAIN ACCURACY: 0.489025 | VAL ACCURACY: 0.3449
# EPOCH 9775 | TRAIN ACCURACY: 0.514275 | VAL ACCURACY: 0.3487
# EPOCH 9780 | TRAIN ACCURACY: 0.51645 | VAL ACCURACY: 0.3518
# EPOCH 9785 | TRAIN ACCURACY: 0.513575 | VAL ACCURACY: 0.3509
# EPOCH 9790 | TRAIN ACCURACY: 0.510525 | VAL ACCURACY: 0.3489
# EPOCH 9795 | TRAIN ACCURACY: 0.50765 | VAL ACCURACY: 0.349
# EPOCH 9800 | TRAIN ACCURACY: 0.5167 | VAL ACCURACY: 0.3503
# EPOCH 9805 | TRAIN ACCURACY: 0.509025 | VAL ACCURACY: 0.3493
# EPOCH 9810 | TRAIN ACCURACY: 0.5218 | VAL ACCURACY: 0.3492
# EPOCH 9815 | TRAIN ACCURACY: 0.493375 | VAL ACCURACY: 0.3485
# EPOCH 9820 | TRAIN ACCURACY: 0.5167 | VAL ACCURACY: 0.351
# EPOCH 9825 | TRAIN ACCURACY: 0.519475 | VAL ACCURACY: 0.3514
# EPOCH 9830 | TRAIN ACCURACY: 0.51175 | VAL ACCURACY: 0.3499
# EPOCH 9835 | TRAIN ACCURACY: 0.51545 | VAL ACCURACY: 0.3521
# EPOCH 9840 | TRAIN ACCURACY: 0.500675 | VAL ACCURACY: 0.3504
# EPOCH 9845 | TRAIN ACCURACY: 0.5164 | VAL ACCURACY: 0.3473
# EPOCH 9850 | TRAIN ACCURACY: 0.50705 | VAL ACCURACY: 0.3486
# EPOCH 9855 | TRAIN ACCURACY: 0.51445 | VAL ACCURACY: 0.3489
# EPOCH 9860 | TRAIN ACCURACY: 0.497275 | VAL ACCURACY: 0.3497
# EPOCH 9865 | TRAIN ACCURACY: 0.50195 | VAL ACCURACY: 0.3503
# EPOCH 9870 | TRAIN ACCURACY: 0.5103 | VAL ACCURACY: 0.3481
# EPOCH 9875 | TRAIN ACCURACY: 0.516175 | VAL ACCURACY: 0.352
# EPOCH 9880 | TRAIN ACCURACY: 0.518925 | VAL ACCURACY: 0.3518
# EPOCH 9885 | TRAIN ACCURACY: 0.516075 | VAL ACCURACY: 0.3464
# EPOCH 9890 | TRAIN ACCURACY: 0.5112 | VAL ACCURACY: 0.3467
# EPOCH 9895 | TRAIN ACCURACY: 0.49695 | VAL ACCURACY: 0.3469
# EPOCH 9900 | TRAIN ACCURACY: 0.515925 | VAL ACCURACY: 0.346
# EPOCH 9905 | TRAIN ACCURACY: 0.515875 | VAL ACCURACY: 0.3508
# EPOCH 9910 | TRAIN ACCURACY: 0.514875 | VAL ACCURACY: 0.3495
# EPOCH 9915 | TRAIN ACCURACY: 0.514875 | VAL ACCURACY: 0.3496
# EPOCH 9920 | TRAIN ACCURACY: 0.5208 | VAL ACCURACY: 0.349
# EPOCH 9925 | TRAIN ACCURACY: 0.515975 | VAL ACCURACY: 0.3491
# EPOCH 9930 | TRAIN ACCURACY: 0.5009 | VAL ACCURACY: 0.3496
# EPOCH 9935 | TRAIN ACCURACY: 0.505575 | VAL ACCURACY: 0.3474
# EPOCH 9940 | TRAIN ACCURACY: 0.51565 | VAL ACCURACY: 0.3508
# EPOCH 9945 | TRAIN ACCURACY: 0.51615 | VAL ACCURACY: 0.3497
# EPOCH 9950 | TRAIN ACCURACY: 0.517075 | VAL ACCURACY: 0.3489
# EPOCH 9955 | TRAIN ACCURACY: 0.5172 | VAL ACCURACY: 0.3497
# EPOCH 9960 | TRAIN ACCURACY: 0.50955 | VAL ACCURACY: 0.3487
# EPOCH 9965 | TRAIN ACCURACY: 0.516175 | VAL ACCURACY: 0.3496
# EPOCH 9970 | TRAIN ACCURACY: 0.5104 | VAL ACCURACY: 0.3462
# EPOCH 9975 | TRAIN ACCURACY: 0.518325 | VAL ACCURACY: 0.3504
# EPOCH 9980 | TRAIN ACCURACY: 0.512225 | VAL ACCURACY: 0.3493
# EPOCH 9985 | TRAIN ACCURACY: 0.5102 | VAL ACCURACY: 0.3477
# EPOCH 9990 | TRAIN ACCURACY: 0.5112 | VAL ACCURACY: 0.35
# EPOCH 9995 | TRAIN ACCURACY: 0.4966 | VAL ACCURACY: 0.3469
# EPOCH 10000 | TRAIN ACCURACY: 0.51415 | VAL ACCURACY: 0.3492
# EVALUATING ACCURACY
# GENERATING CONFUSION MATRIX
# SAVING RESULTS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-769ffa239116> in <module>()
# ----> 1 mlp_10_results = document_model(mlp_10, X_train, y_train, X_val, y_val, 'mlp_10.pkl')
#
# <ipython-input-90-bcc11b47739b> in document_model(model, X_train, y_train, X_val, y_val, filename)
#      37
#      38   print("SAVING RESULTS")
# ---> 39   save_file(result, filename)
#      40   return result
#
# <ipython-input-90-bcc11b47739b> in save_file(file, filename)
#       2   with open(filename, 'wb') as f:
#       3     pkl.dump(file, f)
# ----> 4   files.download(filename)
#       5
#       6
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
mlp_50 = MLP([3072, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

# %%
mlp_50_results = document_model(mlp_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_50_results, 'mlp_50.pkl')

# %%
mlp_100 = MLP([3072, 100, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

# %%
mlp_100_results = document_model(mlp_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_results, 'mlp_100.pkl')

# %%
mlp_200 = MLP([3072, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

# %%
mlp_200_results = document_model(mlp_200, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_results, 'mlp_200.pkl')

# %%
mlp_500 = MLP([3072, 500, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

# %%
mlp_500_results = document_model(mlp_500, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_results, 'mlp_500.pkl')

# %%
mlp_1000 = MLP([3072, 1000, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

# %%
mlp_1000_results = document_model(mlp_1000, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_1000_results, 'mlp_1000.pkl')

# %%
files.download('mlp_1000.pkl')

# %% [markdown]
# ### Two Layer NN

# %%
mlp_10_10 = MLP([3072, 10, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_50_10 = MLP([3072, 50, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_50_50 = MLP([3072, 50, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_10 = MLP([3072, 100, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_50 = MLP([3072, 100, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_100 = MLP([3072, 100, 100, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_10 = MLP([3072, 200, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_50 = MLP([3072, 200, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_100 = MLP([3072, 200, 100, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_200 = MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_500_10 = MLP([3072, 500, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_500_50 = MLP([3072, 500, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_500_100 = MLP([3072, 500, 100, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_500_200 = MLP([3072, 500, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_500_500 = MLP([3072, 500, 500, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

mlp_1000_10 = MLP([3072, 1000, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_1000_50 = MLP([3072, 1000, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_1000_100 = MLP([3072, 1000, 100, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_1000_200 = MLP([3072, 1000, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_1000_500 = MLP([3072, 1000, 500, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_1000_1000 = MLP([3072, 1000, 1000, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

# %%
mlp_10_10_results = document_model(mlp_10_10, X_train, y_train, X_val, y_val)
# Out:
# EPOCH 0| TRAIN ACCURACY: 0.10495 | VAL ACCURACY: 0.101
# EPOCH 5 | TRAIN ACCURACY: 0.15525 | VAL ACCURACY: 0.1514
# EPOCH 10 | TRAIN ACCURACY: 0.19515 | VAL ACCURACY: 0.1918
# EPOCH 15 | TRAIN ACCURACY: 0.19925 | VAL ACCURACY: 0.1995
# EPOCH 20 | TRAIN ACCURACY: 0.203575 | VAL ACCURACY: 0.2045
# EPOCH 25 | TRAIN ACCURACY: 0.20825 | VAL ACCURACY: 0.2076
# EPOCH 30 | TRAIN ACCURACY: 0.21165 | VAL ACCURACY: 0.209
# EPOCH 35 | TRAIN ACCURACY: 0.219875 | VAL ACCURACY: 0.2207
# EPOCH 40 | TRAIN ACCURACY: 0.2175 | VAL ACCURACY: 0.2163
# EPOCH 45 | TRAIN ACCURACY: 0.245275 | VAL ACCURACY: 0.2466
# EPOCH 50 | TRAIN ACCURACY: 0.25405 | VAL ACCURACY: 0.2523
# EPOCH 55 | TRAIN ACCURACY: 0.256775 | VAL ACCURACY: 0.2562
# EPOCH 60 | TRAIN ACCURACY: 0.25615 | VAL ACCURACY: 0.2565
# EPOCH 65 | TRAIN ACCURACY: 0.255975 | VAL ACCURACY: 0.2542
# EPOCH 70 | TRAIN ACCURACY: 0.2543 | VAL ACCURACY: 0.2563
# EPOCH 75 | TRAIN ACCURACY: 0.2627 | VAL ACCURACY: 0.2612
# EPOCH 80 | TRAIN ACCURACY: 0.251125 | VAL ACCURACY: 0.2509
# EPOCH 85 | TRAIN ACCURACY: 0.261975 | VAL ACCURACY: 0.2603
# EPOCH 90 | TRAIN ACCURACY: 0.25275 | VAL ACCURACY: 0.2548
# EPOCH 95 | TRAIN ACCURACY: 0.25495 | VAL ACCURACY: 0.2546
# EPOCH 100 | TRAIN ACCURACY: 0.26015 | VAL ACCURACY: 0.259
# EPOCH 105 | TRAIN ACCURACY: 0.251725 | VAL ACCURACY: 0.2531
# EPOCH 110 | TRAIN ACCURACY: 0.26115 | VAL ACCURACY: 0.2613
# EPOCH 115 | TRAIN ACCURACY: 0.2591 | VAL ACCURACY: 0.2586
# EPOCH 120 | TRAIN ACCURACY: 0.254175 | VAL ACCURACY: 0.2539
# EPOCH 125 | TRAIN ACCURACY: 0.263375 | VAL ACCURACY: 0.2602
# EPOCH 130 | TRAIN ACCURACY: 0.252075 | VAL ACCURACY: 0.2529
# EPOCH 135 | TRAIN ACCURACY: 0.2549 | VAL ACCURACY: 0.2568
# EPOCH 140 | TRAIN ACCURACY: 0.25055 | VAL ACCURACY: 0.2527
# EPOCH 145 | TRAIN ACCURACY: 0.252575 | VAL ACCURACY: 0.2559
# EPOCH 150 | TRAIN ACCURACY: 0.2537 | VAL ACCURACY: 0.2555
# EPOCH 155 | TRAIN ACCURACY: 0.252975 | VAL ACCURACY: 0.2558
# EPOCH 160 | TRAIN ACCURACY: 0.25275 | VAL ACCURACY: 0.2545
# EPOCH 165 | TRAIN ACCURACY: 0.25505 | VAL ACCURACY: 0.2559
# EPOCH 170 | TRAIN ACCURACY: 0.251775 | VAL ACCURACY: 0.2539
# EPOCH 175 | TRAIN ACCURACY: 0.2536 | VAL ACCURACY: 0.2545
# EPOCH 180 | TRAIN ACCURACY: 0.2559 | VAL ACCURACY: 0.2547
# EPOCH 185 | TRAIN ACCURACY: 0.25145 | VAL ACCURACY: 0.2528
# EPOCH 190 | TRAIN ACCURACY: 0.254075 | VAL ACCURACY: 0.2544
# EPOCH 195 | TRAIN ACCURACY: 0.25305 | VAL ACCURACY: 0.2551
# EPOCH 200 | TRAIN ACCURACY: 0.25255 | VAL ACCURACY: 0.2537
# EPOCH 205 | TRAIN ACCURACY: 0.253375 | VAL ACCURACY: 0.2551
# EPOCH 210 | TRAIN ACCURACY: 0.247175 | VAL ACCURACY: 0.2466
# EPOCH 215 | TRAIN ACCURACY: 0.253525 | VAL ACCURACY: 0.2534
# EPOCH 220 | TRAIN ACCURACY: 0.254 | VAL ACCURACY: 0.2545
# EPOCH 225 | TRAIN ACCURACY: 0.25385 | VAL ACCURACY: 0.2539
# EPOCH 230 | TRAIN ACCURACY: 0.255325 | VAL ACCURACY: 0.2567
# EPOCH 235 | TRAIN ACCURACY: 0.2552 | VAL ACCURACY: 0.2565
# EPOCH 240 | TRAIN ACCURACY: 0.2584 | VAL ACCURACY: 0.2573
# EPOCH 245 | TRAIN ACCURACY: 0.256975 | VAL ACCURACY: 0.2591
# EPOCH 250 | TRAIN ACCURACY: 0.256875 | VAL ACCURACY: 0.2576
# EPOCH 255 | TRAIN ACCURACY: 0.258525 | VAL ACCURACY: 0.2577
# EPOCH 260 | TRAIN ACCURACY: 0.25575 | VAL ACCURACY: 0.2561
# EPOCH 265 | TRAIN ACCURACY: 0.255275 | VAL ACCURACY: 0.2546
# EPOCH 270 | TRAIN ACCURACY: 0.256275 | VAL ACCURACY: 0.2559
# EPOCH 275 | TRAIN ACCURACY: 0.25715 | VAL ACCURACY: 0.2569
# EPOCH 280 | TRAIN ACCURACY: 0.2622 | VAL ACCURACY: 0.2576
# EPOCH 285 | TRAIN ACCURACY: 0.256975 | VAL ACCURACY: 0.2579
# EPOCH 290 | TRAIN ACCURACY: 0.25845 | VAL ACCURACY: 0.2592
# EPOCH 295 | TRAIN ACCURACY: 0.258525 | VAL ACCURACY: 0.2606
# EPOCH 300 | TRAIN ACCURACY: 0.257375 | VAL ACCURACY: 0.2561
# EPOCH 305 | TRAIN ACCURACY: 0.258925 | VAL ACCURACY: 0.26
# EPOCH 310 | TRAIN ACCURACY: 0.257425 | VAL ACCURACY: 0.2565
# EPOCH 315 | TRAIN ACCURACY: 0.256575 | VAL ACCURACY: 0.255
# EPOCH 320 | TRAIN ACCURACY: 0.2597 | VAL ACCURACY: 0.257
# EPOCH 325 | TRAIN ACCURACY: 0.260675 | VAL ACCURACY: 0.259
# EPOCH 330 | TRAIN ACCURACY: 0.257325 | VAL ACCURACY: 0.2534
# EPOCH 335 | TRAIN ACCURACY: 0.261225 | VAL ACCURACY: 0.2591
# EPOCH 340 | TRAIN ACCURACY: 0.259775 | VAL ACCURACY: 0.259
# EPOCH 345 | TRAIN ACCURACY: 0.2589 | VAL ACCURACY: 0.2566
# EPOCH 350 | TRAIN ACCURACY: 0.260825 | VAL ACCURACY: 0.2586
# EPOCH 355 | TRAIN ACCURACY: 0.26505 | VAL ACCURACY: 0.2603
# EPOCH 360 | TRAIN ACCURACY: 0.26 | VAL ACCURACY: 0.2574
# EPOCH 365 | TRAIN ACCURACY: 0.2626 | VAL ACCURACY: 0.2591
# EPOCH 370 | TRAIN ACCURACY: 0.2618 | VAL ACCURACY: 0.2585
# EPOCH 375 | TRAIN ACCURACY: 0.26035 | VAL ACCURACY: 0.2581
# EPOCH 380 | TRAIN ACCURACY: 0.259625 | VAL ACCURACY: 0.258
# EPOCH 385 | TRAIN ACCURACY: 0.2636 | VAL ACCURACY: 0.2587
# EPOCH 390 | TRAIN ACCURACY: 0.267525 | VAL ACCURACY: 0.2605
# EPOCH 395 | TRAIN ACCURACY: 0.261675 | VAL ACCURACY: 0.2574
# EPOCH 400 | TRAIN ACCURACY: 0.263375 | VAL ACCURACY: 0.2589
# EPOCH 405 | TRAIN ACCURACY: 0.260775 | VAL ACCURACY: 0.2563
# EPOCH 410 | TRAIN ACCURACY: 0.26675 | VAL ACCURACY: 0.2619
# EPOCH 415 | TRAIN ACCURACY: 0.267625 | VAL ACCURACY: 0.2613
# EPOCH 420 | TRAIN ACCURACY: 0.263625 | VAL ACCURACY: 0.2603
# EPOCH 425 | TRAIN ACCURACY: 0.27005 | VAL ACCURACY: 0.2631
# EPOCH 430 | TRAIN ACCURACY: 0.266775 | VAL ACCURACY: 0.2625
# EPOCH 435 | TRAIN ACCURACY: 0.2638 | VAL ACCURACY: 0.2559
# EPOCH 440 | TRAIN ACCURACY: 0.263225 | VAL ACCURACY: 0.2583
# EPOCH 445 | TRAIN ACCURACY: 0.2674 | VAL ACCURACY: 0.2619
# EPOCH 450 | TRAIN ACCURACY: 0.264325 | VAL ACCURACY: 0.2604
# EPOCH 455 | TRAIN ACCURACY: 0.264525 | VAL ACCURACY: 0.2622
# EPOCH 460 | TRAIN ACCURACY: 0.265925 | VAL ACCURACY: 0.2604
# EPOCH 465 | TRAIN ACCURACY: 0.267175 | VAL ACCURACY: 0.2626
# EPOCH 470 | TRAIN ACCURACY: 0.26635 | VAL ACCURACY: 0.2585
# EPOCH 475 | TRAIN ACCURACY: 0.2686 | VAL ACCURACY: 0.2639
# EPOCH 480 | TRAIN ACCURACY: 0.280475 | VAL ACCURACY: 0.2698
# EPOCH 485 | TRAIN ACCURACY: 0.27115 | VAL ACCURACY: 0.2628
# EPOCH 490 | TRAIN ACCURACY: 0.267125 | VAL ACCURACY: 0.2605
# EPOCH 495 | TRAIN ACCURACY: 0.26575 | VAL ACCURACY: 0.2623
# EPOCH 500 | TRAIN ACCURACY: 0.26715 | VAL ACCURACY: 0.2614
# EPOCH 505 | TRAIN ACCURACY: 0.273675 | VAL ACCURACY: 0.2648
# EPOCH 510 | TRAIN ACCURACY: 0.272675 | VAL ACCURACY: 0.2636
# EPOCH 515 | TRAIN ACCURACY: 0.267825 | VAL ACCURACY: 0.2591
# EPOCH 520 | TRAIN ACCURACY: 0.267325 | VAL ACCURACY: 0.2603
# EPOCH 525 | TRAIN ACCURACY: 0.2657 | VAL ACCURACY: 0.2583
# EPOCH 530 | TRAIN ACCURACY: 0.265125 | VAL ACCURACY: 0.2574
# EPOCH 535 | TRAIN ACCURACY: 0.26965 | VAL ACCURACY: 0.2613
# EPOCH 540 | TRAIN ACCURACY: 0.269325 | VAL ACCURACY: 0.2633
# EPOCH 545 | TRAIN ACCURACY: 0.268175 | VAL ACCURACY: 0.2597
# EPOCH 550 | TRAIN ACCURACY: 0.27005 | VAL ACCURACY: 0.2619
# EPOCH 555 | TRAIN ACCURACY: 0.276275 | VAL ACCURACY: 0.2667
# EPOCH 560 | TRAIN ACCURACY: 0.26905 | VAL ACCURACY: 0.2598
# EPOCH 565 | TRAIN ACCURACY: 0.26905 | VAL ACCURACY: 0.2606
# EPOCH 570 | TRAIN ACCURACY: 0.274075 | VAL ACCURACY: 0.2641
# EPOCH 575 | TRAIN ACCURACY: 0.26845 | VAL ACCURACY: 0.26
# EPOCH 580 | TRAIN ACCURACY: 0.275375 | VAL ACCURACY: 0.2639
# EPOCH 585 | TRAIN ACCURACY: 0.273225 | VAL ACCURACY: 0.2628
# EPOCH 590 | TRAIN ACCURACY: 0.269925 | VAL ACCURACY: 0.2612
# EPOCH 595 | TRAIN ACCURACY: 0.27185 | VAL ACCURACY: 0.2625
# EPOCH 600 | TRAIN ACCURACY: 0.27735 | VAL ACCURACY: 0.2678
# EPOCH 605 | TRAIN ACCURACY: 0.270825 | VAL ACCURACY: 0.2622
# EPOCH 610 | TRAIN ACCURACY: 0.27085 | VAL ACCURACY: 0.2632
# EPOCH 615 | TRAIN ACCURACY: 0.273 | VAL ACCURACY: 0.2654
# EPOCH 620 | TRAIN ACCURACY: 0.27185 | VAL ACCURACY: 0.2622
# EPOCH 625 | TRAIN ACCURACY: 0.271825 | VAL ACCURACY: 0.2623
# EPOCH 630 | TRAIN ACCURACY: 0.281125 | VAL ACCURACY: 0.2707
# EPOCH 635 | TRAIN ACCURACY: 0.273 | VAL ACCURACY: 0.2613
# EPOCH 640 | TRAIN ACCURACY: 0.275325 | VAL ACCURACY: 0.2623
# EPOCH 645 | TRAIN ACCURACY: 0.275925 | VAL ACCURACY: 0.2645
# EPOCH 650 | TRAIN ACCURACY: 0.277 | VAL ACCURACY: 0.2652
# EPOCH 655 | TRAIN ACCURACY: 0.27525 | VAL ACCURACY: 0.263
# EPOCH 660 | TRAIN ACCURACY: 0.27345 | VAL ACCURACY: 0.264
# EPOCH 665 | TRAIN ACCURACY: 0.274475 | VAL ACCURACY: 0.2635
# EPOCH 670 | TRAIN ACCURACY: 0.27695 | VAL ACCURACY: 0.2641
# EPOCH 675 | TRAIN ACCURACY: 0.27695 | VAL ACCURACY: 0.2635
# EPOCH 680 | TRAIN ACCURACY: 0.274275 | VAL ACCURACY: 0.2625
# EPOCH 685 | TRAIN ACCURACY: 0.275725 | VAL ACCURACY: 0.2644
# EPOCH 690 | TRAIN ACCURACY: 0.274825 | VAL ACCURACY: 0.264
# EPOCH 695 | TRAIN ACCURACY: 0.276375 | VAL ACCURACY: 0.2666
# EPOCH 700 | TRAIN ACCURACY: 0.27365 | VAL ACCURACY: 0.2629
# EPOCH 705 | TRAIN ACCURACY: 0.275125 | VAL ACCURACY: 0.2652
# EPOCH 710 | TRAIN ACCURACY: 0.2787 | VAL ACCURACY: 0.2662
# EPOCH 715 | TRAIN ACCURACY: 0.27835 | VAL ACCURACY: 0.2649
# EPOCH 720 | TRAIN ACCURACY: 0.27255 | VAL ACCURACY: 0.2618
# EPOCH 725 | TRAIN ACCURACY: 0.27805 | VAL ACCURACY: 0.2643
# EPOCH 730 | TRAIN ACCURACY: 0.275475 | VAL ACCURACY: 0.2627
# EPOCH 735 | TRAIN ACCURACY: 0.276475 | VAL ACCURACY: 0.2648
# EPOCH 740 | TRAIN ACCURACY: 0.279475 | VAL ACCURACY: 0.267
# EPOCH 745 | TRAIN ACCURACY: 0.276725 | VAL ACCURACY: 0.2643
# EPOCH 750 | TRAIN ACCURACY: 0.281225 | VAL ACCURACY: 0.2688
# EPOCH 755 | TRAIN ACCURACY: 0.283825 | VAL ACCURACY: 0.2711
# EPOCH 760 | TRAIN ACCURACY: 0.27905 | VAL ACCURACY: 0.2656
# EPOCH 765 | TRAIN ACCURACY: 0.283725 | VAL ACCURACY: 0.2702
# EPOCH 770 | TRAIN ACCURACY: 0.2815 | VAL ACCURACY: 0.2674
# EPOCH 775 | TRAIN ACCURACY: 0.27815 | VAL ACCURACY: 0.2645
# EPOCH 780 | TRAIN ACCURACY: 0.28315 | VAL ACCURACY: 0.2705
# EPOCH 785 | TRAIN ACCURACY: 0.2842 | VAL ACCURACY: 0.2724
# EPOCH 790 | TRAIN ACCURACY: 0.286 | VAL ACCURACY: 0.2754
# EPOCH 795 | TRAIN ACCURACY: 0.276975 | VAL ACCURACY: 0.2662
# EPOCH 800 | TRAIN ACCURACY: 0.28015 | VAL ACCURACY: 0.2656
# EPOCH 805 | TRAIN ACCURACY: 0.282125 | VAL ACCURACY: 0.2666
# EPOCH 810 | TRAIN ACCURACY: 0.2808 | VAL ACCURACY: 0.2666
# EPOCH 815 | TRAIN ACCURACY: 0.2842 | VAL ACCURACY: 0.2702
# EPOCH 820 | TRAIN ACCURACY: 0.282125 | VAL ACCURACY: 0.268
# EPOCH 825 | TRAIN ACCURACY: 0.279325 | VAL ACCURACY: 0.2647
# EPOCH 830 | TRAIN ACCURACY: 0.2826 | VAL ACCURACY: 0.2689
# EPOCH 835 | TRAIN ACCURACY: 0.281 | VAL ACCURACY: 0.2657
# EPOCH 840 | TRAIN ACCURACY: 0.281525 | VAL ACCURACY: 0.2663
# EPOCH 845 | TRAIN ACCURACY: 0.286525 | VAL ACCURACY: 0.2718
# EPOCH 850 | TRAIN ACCURACY: 0.28265 | VAL ACCURACY: 0.2678
# EPOCH 855 | TRAIN ACCURACY: 0.2799 | VAL ACCURACY: 0.2657
# EPOCH 860 | TRAIN ACCURACY: 0.28135 | VAL ACCURACY: 0.2683
# EPOCH 865 | TRAIN ACCURACY: 0.282525 | VAL ACCURACY: 0.2669
# EPOCH 870 | TRAIN ACCURACY: 0.278775 | VAL ACCURACY: 0.2625
# EPOCH 875 | TRAIN ACCURACY: 0.2835 | VAL ACCURACY: 0.269
# EPOCH 880 | TRAIN ACCURACY: 0.2786 | VAL ACCURACY: 0.2647
# EPOCH 885 | TRAIN ACCURACY: 0.27955 | VAL ACCURACY: 0.2649
# EPOCH 890 | TRAIN ACCURACY: 0.281875 | VAL ACCURACY: 0.2645
# EPOCH 895 | TRAIN ACCURACY: 0.283375 | VAL ACCURACY: 0.2681
# EPOCH 900 | TRAIN ACCURACY: 0.283475 | VAL ACCURACY: 0.2681
# EPOCH 905 | TRAIN ACCURACY: 0.2812 | VAL ACCURACY: 0.2646
# EPOCH 910 | TRAIN ACCURACY: 0.284125 | VAL ACCURACY: 0.2705
# EPOCH 915 | TRAIN ACCURACY: 0.28445 | VAL ACCURACY: 0.2674
# EPOCH 920 | TRAIN ACCURACY: 0.282025 | VAL ACCURACY: 0.2665
# EPOCH 925 | TRAIN ACCURACY: 0.281925 | VAL ACCURACY: 0.2684
# EPOCH 930 | TRAIN ACCURACY: 0.2833 | VAL ACCURACY: 0.2667
# EPOCH 935 | TRAIN ACCURACY: 0.282825 | VAL ACCURACY: 0.2675
# EPOCH 940 | TRAIN ACCURACY: 0.2819 | VAL ACCURACY: 0.2662
# EPOCH 945 | TRAIN ACCURACY: 0.281025 | VAL ACCURACY: 0.2644
# EPOCH 950 | TRAIN ACCURACY: 0.281075 | VAL ACCURACY: 0.2646
# EPOCH 955 | TRAIN ACCURACY: 0.282275 | VAL ACCURACY: 0.2654
# EPOCH 960 | TRAIN ACCURACY: 0.285425 | VAL ACCURACY: 0.2692
# EPOCH 965 | TRAIN ACCURACY: 0.285425 | VAL ACCURACY: 0.2687
# EPOCH 970 | TRAIN ACCURACY: 0.2813 | VAL ACCURACY: 0.2665
# EPOCH 975 | TRAIN ACCURACY: 0.2828 | VAL ACCURACY: 0.2665
# EPOCH 980 | TRAIN ACCURACY: 0.2822 | VAL ACCURACY: 0.2666
# EPOCH 985 | TRAIN ACCURACY: 0.2828 | VAL ACCURACY: 0.2653
# EPOCH 990 | TRAIN ACCURACY: 0.28225 | VAL ACCURACY: 0.2662
# EPOCH 995 | TRAIN ACCURACY: 0.282825 | VAL ACCURACY: 0.2659
# EPOCH 1000 | TRAIN ACCURACY: 0.28235 | VAL ACCURACY: 0.2637
# EVALUATING ACCURACY
# GENERATING CONFUSION MATRIX

# %%
save_file(mlp_10_10_results, 'mlp_10_10.pkl')

# %%
files.download('mlp_10_10.pkl')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-11-32ec38dafd1f> in <module>()
# ----> 1 files.download('mlp_10_10.pkl')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: TypeError: Failed to fetch

# %%
mlp_50_10_results = document_model(mlp_50_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_50_10_results, 'mlp_50_10.pkl')

# %%
files.download('mlp_50_10.pkl')

# %%
mlp_50_50_results = document_model(mlp_50_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_50_50_results, 'mlp_50_50.pkl')

# %%
files.download('mlp_50_50.pkl')

# %%
mlp_100_10_results = document_model(mlp_100_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_10_results, 'mlp_100_10.pkl')

# %%
files.download('mlp_100_10.pkl')

# %%
mlp_100_50_results = document_model(mlp_100_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_50_results, 'mlp_100_50.pkl')

# %%
files.download('mlp_100_50.pkl')

# %%
mlp_100_100_results = document_model(mlp_100_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_100_results, 'mlp_100_100.pkl')

# %%
files.download('mlp_100_100.pkl')

# %%
mlp_200_10_results = document_model(mlp_200_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_10_results, 'mlp_200_10.pkl')

# %%
files.download('mlp_200_10.pkl')

# %%
mlp_200_50_results = document_model(mlp_200_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_50_results, 'mlp_200_50.pkl')

# %%
files.download('mlp_200_50.pkl')

# %%
mlp_200_100_results = document_model(mlp_200_100, X_train, y_train, X_val, y_val)
# Out:
# EPOCH 0| TRAIN ACCURACY: 0.105625 | VAL ACCURACY: 0.1043
# EPOCH 5 | TRAIN ACCURACY: 0.322775 | VAL ACCURACY: 0.3142
# EPOCH 10 | TRAIN ACCURACY: 0.350675 | VAL ACCURACY: 0.344
# EPOCH 15 | TRAIN ACCURACY: 0.3711 | VAL ACCURACY: 0.3671
# EPOCH 20 | TRAIN ACCURACY: 0.38175 | VAL ACCURACY: 0.3758
# EPOCH 25 | TRAIN ACCURACY: 0.39075 | VAL ACCURACY: 0.3881
# EPOCH 30 | TRAIN ACCURACY: 0.39555 | VAL ACCURACY: 0.3928
# EPOCH 35 | TRAIN ACCURACY: 0.40525 | VAL ACCURACY: 0.3983
# EPOCH 40 | TRAIN ACCURACY: 0.41105 | VAL ACCURACY: 0.4053
# EPOCH 45 | TRAIN ACCURACY: 0.415925 | VAL ACCURACY: 0.4105
# EPOCH 50 | TRAIN ACCURACY: 0.422375 | VAL ACCURACY: 0.4156
# EPOCH 55 | TRAIN ACCURACY: 0.42555 | VAL ACCURACY: 0.419
# EPOCH 60 | TRAIN ACCURACY: 0.43075 | VAL ACCURACY: 0.4244
# EPOCH 65 | TRAIN ACCURACY: 0.4362 | VAL ACCURACY: 0.4277
# EPOCH 70 | TRAIN ACCURACY: 0.4388 | VAL ACCURACY: 0.4302
# EPOCH 75 | TRAIN ACCURACY: 0.443525 | VAL ACCURACY: 0.4332
# EPOCH 80 | TRAIN ACCURACY: 0.448475 | VAL ACCURACY: 0.4351
# EPOCH 85 | TRAIN ACCURACY: 0.450975 | VAL ACCURACY: 0.4393
# EPOCH 90 | TRAIN ACCURACY: 0.45295 | VAL ACCURACY: 0.4426
# EPOCH 95 | TRAIN ACCURACY: 0.4578 | VAL ACCURACY: 0.4426
# EPOCH 100 | TRAIN ACCURACY: 0.461375 | VAL ACCURACY: 0.4459
# EPOCH 105 | TRAIN ACCURACY: 0.463925 | VAL ACCURACY: 0.4493
# EPOCH 110 | TRAIN ACCURACY: 0.467275 | VAL ACCURACY: 0.4494
# EPOCH 115 | TRAIN ACCURACY: 0.47095 | VAL ACCURACY: 0.4509
# EPOCH 120 | TRAIN ACCURACY: 0.47255 | VAL ACCURACY: 0.4572
# EPOCH 125 | TRAIN ACCURACY: 0.47535 | VAL ACCURACY: 0.4535
# EPOCH 130 | TRAIN ACCURACY: 0.479175 | VAL ACCURACY: 0.4562
# EPOCH 135 | TRAIN ACCURACY: 0.4809 | VAL ACCURACY: 0.4584
# EPOCH 140 | TRAIN ACCURACY: 0.484425 | VAL ACCURACY: 0.4623
# EPOCH 145 | TRAIN ACCURACY: 0.487 | VAL ACCURACY: 0.4623
# EPOCH 150 | TRAIN ACCURACY: 0.487275 | VAL ACCURACY: 0.4618
# EPOCH 155 | TRAIN ACCURACY: 0.49155 | VAL ACCURACY: 0.4631
# EPOCH 160 | TRAIN ACCURACY: 0.494125 | VAL ACCURACY: 0.4668
# EPOCH 165 | TRAIN ACCURACY: 0.495925 | VAL ACCURACY: 0.4703
# EPOCH 170 | TRAIN ACCURACY: 0.4971 | VAL ACCURACY: 0.4684
# EPOCH 175 | TRAIN ACCURACY: 0.5018 | VAL ACCURACY: 0.4701
# EPOCH 180 | TRAIN ACCURACY: 0.504 | VAL ACCURACY: 0.4709
# EPOCH 185 | TRAIN ACCURACY: 0.50525 | VAL ACCURACY: 0.4717
# EPOCH 190 | TRAIN ACCURACY: 0.50645 | VAL ACCURACY: 0.4748
# EPOCH 195 | TRAIN ACCURACY: 0.509625 | VAL ACCURACY: 0.4747
# EPOCH 200 | TRAIN ACCURACY: 0.511975 | VAL ACCURACY: 0.4763
# EPOCH 205 | TRAIN ACCURACY: 0.512125 | VAL ACCURACY: 0.478
# EPOCH 210 | TRAIN ACCURACY: 0.5151 | VAL ACCURACY: 0.4788
# EPOCH 215 | TRAIN ACCURACY: 0.515725 | VAL ACCURACY: 0.4788
# EPOCH 220 | TRAIN ACCURACY: 0.516475 | VAL ACCURACY: 0.4778
# EPOCH 225 | TRAIN ACCURACY: 0.5209 | VAL ACCURACY: 0.4799
# EPOCH 230 | TRAIN ACCURACY: 0.522375 | VAL ACCURACY: 0.4812
# EPOCH 235 | TRAIN ACCURACY: 0.52345 | VAL ACCURACY: 0.4803
# EPOCH 240 | TRAIN ACCURACY: 0.5258 | VAL ACCURACY: 0.4808
# EPOCH 245 | TRAIN ACCURACY: 0.5276 | VAL ACCURACY: 0.4837
# EPOCH 250 | TRAIN ACCURACY: 0.5314 | VAL ACCURACY: 0.4856
# EPOCH 255 | TRAIN ACCURACY: 0.531375 | VAL ACCURACY: 0.4836
# EPOCH 260 | TRAIN ACCURACY: 0.533175 | VAL ACCURACY: 0.4844
# EPOCH 265 | TRAIN ACCURACY: 0.535175 | VAL ACCURACY: 0.4865
# EPOCH 270 | TRAIN ACCURACY: 0.53705 | VAL ACCURACY: 0.4886
# EPOCH 275 | TRAIN ACCURACY: 0.539925 | VAL ACCURACY: 0.4884
# EPOCH 280 | TRAIN ACCURACY: 0.541075 | VAL ACCURACY: 0.4892
# EPOCH 285 | TRAIN ACCURACY: 0.542775 | VAL ACCURACY: 0.489
# EPOCH 290 | TRAIN ACCURACY: 0.545175 | VAL ACCURACY: 0.4913
# EPOCH 295 | TRAIN ACCURACY: 0.5462 | VAL ACCURACY: 0.4908
# EPOCH 300 | TRAIN ACCURACY: 0.548025 | VAL ACCURACY: 0.4905
# EPOCH 305 | TRAIN ACCURACY: 0.549825 | VAL ACCURACY: 0.4914
# EPOCH 310 | TRAIN ACCURACY: 0.5512 | VAL ACCURACY: 0.4925
# EPOCH 315 | TRAIN ACCURACY: 0.553625 | VAL ACCURACY: 0.4926
# EPOCH 320 | TRAIN ACCURACY: 0.556325 | VAL ACCURACY: 0.4932
# EPOCH 325 | TRAIN ACCURACY: 0.5578 | VAL ACCURACY: 0.4926
# EPOCH 330 | TRAIN ACCURACY: 0.558325 | VAL ACCURACY: 0.4942
# EPOCH 335 | TRAIN ACCURACY: 0.560025 | VAL ACCURACY: 0.4931
# EPOCH 340 | TRAIN ACCURACY: 0.56045 | VAL ACCURACY: 0.4939
# EPOCH 345 | TRAIN ACCURACY: 0.562075 | VAL ACCURACY: 0.4941
# EPOCH 350 | TRAIN ACCURACY: 0.563625 | VAL ACCURACY: 0.4945
# EPOCH 355 | TRAIN ACCURACY: 0.56595 | VAL ACCURACY: 0.4932
# EPOCH 360 | TRAIN ACCURACY: 0.566675 | VAL ACCURACY: 0.4952
# EPOCH 365 | TRAIN ACCURACY: 0.568875 | VAL ACCURACY: 0.4978
# EPOCH 370 | TRAIN ACCURACY: 0.570675 | VAL ACCURACY: 0.4988
# EPOCH 375 | TRAIN ACCURACY: 0.57125 | VAL ACCURACY: 0.4964
# EPOCH 380 | TRAIN ACCURACY: 0.573025 | VAL ACCURACY: 0.4952
# EPOCH 385 | TRAIN ACCURACY: 0.5741 | VAL ACCURACY: 0.4956
# EPOCH 390 | TRAIN ACCURACY: 0.577325 | VAL ACCURACY: 0.4999
# EPOCH 395 | TRAIN ACCURACY: 0.578375 | VAL ACCURACY: 0.4992
# EPOCH 400 | TRAIN ACCURACY: 0.579475 | VAL ACCURACY: 0.502
# EPOCH 405 | TRAIN ACCURACY: 0.5797 | VAL ACCURACY: 0.4986
# EPOCH 410 | TRAIN ACCURACY: 0.582925 | VAL ACCURACY: 0.4969
# EPOCH 415 | TRAIN ACCURACY: 0.583375 | VAL ACCURACY: 0.5006
# EPOCH 420 | TRAIN ACCURACY: 0.584575 | VAL ACCURACY: 0.5009
# EPOCH 425 | TRAIN ACCURACY: 0.5862 | VAL ACCURACY: 0.5014
# EPOCH 430 | TRAIN ACCURACY: 0.587975 | VAL ACCURACY: 0.5021
# EPOCH 435 | TRAIN ACCURACY: 0.5887 | VAL ACCURACY: 0.5015
# EPOCH 440 | TRAIN ACCURACY: 0.58915 | VAL ACCURACY: 0.5008
# EPOCH 445 | TRAIN ACCURACY: 0.590225 | VAL ACCURACY: 0.5025
# EPOCH 450 | TRAIN ACCURACY: 0.592725 | VAL ACCURACY: 0.505
# EPOCH 455 | TRAIN ACCURACY: 0.594525 | VAL ACCURACY: 0.5038
# EPOCH 460 | TRAIN ACCURACY: 0.5949 | VAL ACCURACY: 0.5026
# EPOCH 465 | TRAIN ACCURACY: 0.59755 | VAL ACCURACY: 0.5052
# EPOCH 470 | TRAIN ACCURACY: 0.598725 | VAL ACCURACY: 0.5049
# EPOCH 475 | TRAIN ACCURACY: 0.59945 | VAL ACCURACY: 0.5048
# EPOCH 480 | TRAIN ACCURACY: 0.6005 | VAL ACCURACY: 0.505
# EPOCH 485 | TRAIN ACCURACY: 0.602625 | VAL ACCURACY: 0.5053
# EPOCH 490 | TRAIN ACCURACY: 0.6051 | VAL ACCURACY: 0.5062
# EPOCH 495 | TRAIN ACCURACY: 0.60415 | VAL ACCURACY: 0.5054
# EPOCH 500 | TRAIN ACCURACY: 0.6062 | VAL ACCURACY: 0.5058
# EPOCH 505 | TRAIN ACCURACY: 0.607 | VAL ACCURACY: 0.5078
# EPOCH 510 | TRAIN ACCURACY: 0.608525 | VAL ACCURACY: 0.5077
# EPOCH 515 | TRAIN ACCURACY: 0.6086 | VAL ACCURACY: 0.5075
# EPOCH 520 | TRAIN ACCURACY: 0.610975 | VAL ACCURACY: 0.5076
# EPOCH 525 | TRAIN ACCURACY: 0.61115 | VAL ACCURACY: 0.507
# EPOCH 530 | TRAIN ACCURACY: 0.612925 | VAL ACCURACY: 0.5075
# EPOCH 535 | TRAIN ACCURACY: 0.6142 | VAL ACCURACY: 0.5073
# EPOCH 540 | TRAIN ACCURACY: 0.616325 | VAL ACCURACY: 0.5082
# EPOCH 545 | TRAIN ACCURACY: 0.616775 | VAL ACCURACY: 0.5085
# EPOCH 550 | TRAIN ACCURACY: 0.6188 | VAL ACCURACY: 0.5073
# EPOCH 555 | TRAIN ACCURACY: 0.619075 | VAL ACCURACY: 0.5095
# EPOCH 560 | TRAIN ACCURACY: 0.62365 | VAL ACCURACY: 0.5102
# EPOCH 565 | TRAIN ACCURACY: 0.621675 | VAL ACCURACY: 0.5081
# EPOCH 570 | TRAIN ACCURACY: 0.62375 | VAL ACCURACY: 0.5078
# EPOCH 575 | TRAIN ACCURACY: 0.625175 | VAL ACCURACY: 0.5102
# EPOCH 580 | TRAIN ACCURACY: 0.625 | VAL ACCURACY: 0.5091
# EPOCH 585 | TRAIN ACCURACY: 0.628625 | VAL ACCURACY: 0.5092
# EPOCH 590 | TRAIN ACCURACY: 0.627125 | VAL ACCURACY: 0.5085
# EPOCH 595 | TRAIN ACCURACY: 0.62985 | VAL ACCURACY: 0.5105
# EPOCH 600 | TRAIN ACCURACY: 0.6291 | VAL ACCURACY: 0.5123
# EPOCH 605 | TRAIN ACCURACY: 0.6316 | VAL ACCURACY: 0.5089
# EPOCH 610 | TRAIN ACCURACY: 0.63355 | VAL ACCURACY: 0.5127
# EPOCH 615 | TRAIN ACCURACY: 0.63415 | VAL ACCURACY: 0.5138
# EPOCH 620 | TRAIN ACCURACY: 0.637225 | VAL ACCURACY: 0.5123
# EPOCH 625 | TRAIN ACCURACY: 0.63545 | VAL ACCURACY: 0.5106
# EPOCH 630 | TRAIN ACCURACY: 0.638575 | VAL ACCURACY: 0.5128
# EPOCH 635 | TRAIN ACCURACY: 0.63905 | VAL ACCURACY: 0.5147
# EPOCH 640 | TRAIN ACCURACY: 0.639 | VAL ACCURACY: 0.5111
# EPOCH 645 | TRAIN ACCURACY: 0.643375 | VAL ACCURACY: 0.5102
# EPOCH 650 | TRAIN ACCURACY: 0.642525 | VAL ACCURACY: 0.5163
# EPOCH 655 | TRAIN ACCURACY: 0.643325 | VAL ACCURACY: 0.5088
# EPOCH 660 | TRAIN ACCURACY: 0.64645 | VAL ACCURACY: 0.5118
# EPOCH 665 | TRAIN ACCURACY: 0.6475 | VAL ACCURACY: 0.5123
# EPOCH 670 | TRAIN ACCURACY: 0.64785 | VAL ACCURACY: 0.5118
# EPOCH 675 | TRAIN ACCURACY: 0.648925 | VAL ACCURACY: 0.5139
# EPOCH 680 | TRAIN ACCURACY: 0.648875 | VAL ACCURACY: 0.5111
# EPOCH 685 | TRAIN ACCURACY: 0.65145 | VAL ACCURACY: 0.5141
# EPOCH 690 | TRAIN ACCURACY: 0.6512 | VAL ACCURACY: 0.5121
# EPOCH 695 | TRAIN ACCURACY: 0.65475 | VAL ACCURACY: 0.5139
# EPOCH 700 | TRAIN ACCURACY: 0.6556 | VAL ACCURACY: 0.5135
# EPOCH 705 | TRAIN ACCURACY: 0.657675 | VAL ACCURACY: 0.5108
# EPOCH 710 | TRAIN ACCURACY: 0.656375 | VAL ACCURACY: 0.5126
# EPOCH 715 | TRAIN ACCURACY: 0.65755 | VAL ACCURACY: 0.5144
# EPOCH 720 | TRAIN ACCURACY: 0.6588 | VAL ACCURACY: 0.5141
# EPOCH 725 | TRAIN ACCURACY: 0.658825 | VAL ACCURACY: 0.5141
# EPOCH 730 | TRAIN ACCURACY: 0.658975 | VAL ACCURACY: 0.5142
# EPOCH 735 | TRAIN ACCURACY: 0.660425 | VAL ACCURACY: 0.5146
# EPOCH 740 | TRAIN ACCURACY: 0.661675 | VAL ACCURACY: 0.5141
# EPOCH 745 | TRAIN ACCURACY: 0.6647 | VAL ACCURACY: 0.5153
# EPOCH 750 | TRAIN ACCURACY: 0.664075 | VAL ACCURACY: 0.5163
# EPOCH 755 | TRAIN ACCURACY: 0.6673 | VAL ACCURACY: 0.5171
# EPOCH 760 | TRAIN ACCURACY: 0.6665 | VAL ACCURACY: 0.5147
# EPOCH 765 | TRAIN ACCURACY: 0.668375 | VAL ACCURACY: 0.5145
# EPOCH 770 | TRAIN ACCURACY: 0.6677 | VAL ACCURACY: 0.5131
# EPOCH 775 | TRAIN ACCURACY: 0.669925 | VAL ACCURACY: 0.5134
# EPOCH 780 | TRAIN ACCURACY: 0.67245 | VAL ACCURACY: 0.5182
# EPOCH 785 | TRAIN ACCURACY: 0.674325 | VAL ACCURACY: 0.5172
# EPOCH 790 | TRAIN ACCURACY: 0.6734 | VAL ACCURACY: 0.5146
# EPOCH 795 | TRAIN ACCURACY: 0.672725 | VAL ACCURACY: 0.5152
# EPOCH 800 | TRAIN ACCURACY: 0.67365 | VAL ACCURACY: 0.5163
# EPOCH 805 | TRAIN ACCURACY: 0.674875 | VAL ACCURACY: 0.512
# EPOCH 810 | TRAIN ACCURACY: 0.6786 | VAL ACCURACY: 0.5132
# EPOCH 815 | TRAIN ACCURACY: 0.67765 | VAL ACCURACY: 0.5139
# EPOCH 820 | TRAIN ACCURACY: 0.680725 | VAL ACCURACY: 0.5168
# EPOCH 825 | TRAIN ACCURACY: 0.68 | VAL ACCURACY: 0.5167
# EPOCH 830 | TRAIN ACCURACY: 0.68255 | VAL ACCURACY: 0.5138
# EPOCH 835 | TRAIN ACCURACY: 0.683225 | VAL ACCURACY: 0.5174
# EPOCH 840 | TRAIN ACCURACY: 0.684775 | VAL ACCURACY: 0.5162
# EPOCH 845 | TRAIN ACCURACY: 0.684275 | VAL ACCURACY: 0.5159
# EPOCH 850 | TRAIN ACCURACY: 0.68625 | VAL ACCURACY: 0.5176
# EPOCH 855 | TRAIN ACCURACY: 0.6851 | VAL ACCURACY: 0.5172
# EPOCH 860 | TRAIN ACCURACY: 0.687 | VAL ACCURACY: 0.5162
# EPOCH 865 | TRAIN ACCURACY: 0.689825 | VAL ACCURACY: 0.517
# EPOCH 870 | TRAIN ACCURACY: 0.689775 | VAL ACCURACY: 0.5153
# EPOCH 875 | TRAIN ACCURACY: 0.6893 | VAL ACCURACY: 0.5143
# EPOCH 880 | TRAIN ACCURACY: 0.690675 | VAL ACCURACY: 0.514
# EPOCH 885 | TRAIN ACCURACY: 0.69475 | VAL ACCURACY: 0.5168
# EPOCH 890 | TRAIN ACCURACY: 0.694675 | VAL ACCURACY: 0.5168
# EPOCH 895 | TRAIN ACCURACY: 0.694425 | VAL ACCURACY: 0.5187
# EPOCH 900 | TRAIN ACCURACY: 0.696 | VAL ACCURACY: 0.5186
# EPOCH 905 | TRAIN ACCURACY: 0.6945 | VAL ACCURACY: 0.5145
# EPOCH 910 | TRAIN ACCURACY: 0.696425 | VAL ACCURACY: 0.5174
# EPOCH 915 | TRAIN ACCURACY: 0.69905 | VAL ACCURACY: 0.5188
# EPOCH 920 | TRAIN ACCURACY: 0.699 | VAL ACCURACY: 0.5183
# EPOCH 925 | TRAIN ACCURACY: 0.702475 | VAL ACCURACY: 0.5165
# EPOCH 930 | TRAIN ACCURACY: 0.701375 | VAL ACCURACY: 0.5158
# EPOCH 935 | TRAIN ACCURACY: 0.703375 | VAL ACCURACY: 0.5185
# EPOCH 940 | TRAIN ACCURACY: 0.70215 | VAL ACCURACY: 0.518
# EPOCH 945 | TRAIN ACCURACY: 0.7047 | VAL ACCURACY: 0.5186
# EPOCH 950 | TRAIN ACCURACY: 0.706925 | VAL ACCURACY: 0.5171
# EPOCH 955 | TRAIN ACCURACY: 0.70585 | VAL ACCURACY: 0.5176
# EPOCH 960 | TRAIN ACCURACY: 0.70655 | VAL ACCURACY: 0.5172
# EPOCH 965 | TRAIN ACCURACY: 0.70675 | VAL ACCURACY: 0.5173
# EPOCH 970 | TRAIN ACCURACY: 0.708725 | VAL ACCURACY: 0.5177
# EPOCH 975 | TRAIN ACCURACY: 0.707 | VAL ACCURACY: 0.5145
# EPOCH 980 | TRAIN ACCURACY: 0.7115 | VAL ACCURACY: 0.5167
# EPOCH 985 | TRAIN ACCURACY: 0.711475 | VAL ACCURACY: 0.5162
# EPOCH 990 | TRAIN ACCURACY: 0.713775 | VAL ACCURACY: 0.5166
# EPOCH 995 | TRAIN ACCURACY: 0.712025 | VAL ACCURACY: 0.52
# EPOCH 1000 | TRAIN ACCURACY: 0.712775 | VAL ACCURACY: 0.519
# EVALUATING ACCURACY
# GENERATING CONFUSION MATRIX

# %%
save_file(mlp_200_100_results, 'mlp_200_100.pkl')

# %%
files.download('mlp_200_100.pkl')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 42362, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 320, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 351, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 364, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 724, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 803, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-85f506f3f2fc> in <module>()
# ----> 1 files.download('mlp_200_100.pkl')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      99     reply = _read_next_input_message()
#     100     if reply == _NOT_READY or not isinstance(reply, dict):
# --> 101       time.sleep(0.025)
#     102       continue
#     103     if (reply.get('type') == 'colab_reply' and
#
# KeyboardInterrupt:

# %%
mlp_200_200_results = document_model(mlp_200_200, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_results, 'mlp_200_200.pkl')

# %%
files.download('mlp_200_200.pkl')

# %%
mlp_500_10_results = document_model(mlp_500_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_10_results, 'mlp_500_10.pkl')

# %%
files.download('mlp_500_10.pkl')

# %%
mlp_500_50_results = document_model(mlp_500_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_50_results, 'mlp_500_50.pkl')

# %%
files.download('mlp_500_50.pkl')

# %%
mlp_500_100_results = document_model(mlp_500_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_100_results, 'mlp_500_100.pkl')

# %%
files.download('mlp_500_100.pkl')

# %%
mlp_500_200_results = document_model(mlp_500_200, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_200_results, 'mlp_500_200.pkl')

# %%
files.download('mlp_500_200.pkl')

# %%
mlp_500_500_results = document_model(mlp_500_500, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_500_results, 'mlp_500_500.pkl')

# %%
files.download('mlp_500_500.pkl')

# %%
mlp_1000_10_results = document_model(mlp_1000_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_1000_10_results, 'mlp_1000_10.pkl')

# %%
files.download('mlp_1000_10.pkl')

# %%
mlp_1000_50_results = document_model(mlp_1000_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_1000_50_results, 'mlp_1000_50.pkl')

# %%
files.download('mlp_1000_50.pkl')

# %%
mlp_1000_100_results = document_model(mlp_1000_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_1000_100_results, 'mlp_1000_100.pkl')

# %%
files.download('mlp_1000_100.pkl')

# %%
mlp_1000_200_results = document_model(mlp_1000_200, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_1000_200_results, 'mlp_1000_200.pkl')

# %%
files.download('mlp_1000_200.pkl')

# %%
mlp_1000_500_results = document_model(mlp_1000_500, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_1000_500_results, 'mlp_1000_500.pkl')

# %%
files.download('mlp_1000_500.pkl')

# %%
mlp_1000_1000_results = document_model(mlp_1000_1000, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_1000_1000_results, 'mlp_1000_1000.pkl')

# %%
files.download('mlp_1000_1000.pkl')

# %% [markdown]
# ### Three Layer NN

# %%
mlp_10_10_10 = MLP([3072, 10, 10, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_50_10_10 = MLP([3072, 50, 10, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_50_50_10 = MLP([3072, 50, 50, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_50_50_50 = MLP([3072, 50, 50, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_10_10 = MLP([3072, 100, 10, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_50_10 = MLP([3072, 100, 50, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_50_50 = MLP([3072, 100, 50, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_100_10 = MLP([3072, 100, 100, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_100_50 = MLP([3072, 100, 100, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_100_100_100 = MLP([3072, 100, 100, 100, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_10_10 = MLP([3072, 200, 10, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_50_10 = MLP([3072, 200, 50, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_50_50 = MLP([3072, 200, 50, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_100_10 = MLP([3072, 200, 100, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_100_50 = MLP([3072, 200, 100, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_100_100 = MLP([3072, 200, 100, 100, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_200_10 = MLP([3072, 200, 200, 10, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_200_50 = MLP([3072, 200, 200, 50, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_200_100 = MLP([3072, 200, 200, 100, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_200_200 = MLP([3072, 200, 200, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)

mlp_500_50_50 = MLP([3072, 500, 50, 50, 10], 2000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_100_50 = MLP([3072, 500, 100, 50, 10], 2000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_100_100 = MLP([3072, 500, 100, 100, 10], 2000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_200_50 = MLP([3072, 500, 200, 50, 10], 3000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_200_100 = MLP([3072, 500, 200, 100, 10], 3000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_200_200 = MLP([3072, 500, 200, 200, 10], 3000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_500_50 = MLP([3072, 500, 500, 50, 10], 3000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_500_100 = MLP([3072, 500, 500, 100, 10], 3000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_500_200 = MLP([3072, 500, 500, 200, 10], 3000, 1024, 0.05, 'relu', 'softmax', 0.5)
mlp_500_500_500 = MLP([3072, 500, 500, 500, 10], 3000, 1024, 0.05, 'relu', 'softmax', 0.5)

# %%
mlp_10_10_10_results = document_model(mlp_10_10_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_10_10_10_results, 'mlp_10_10_10.pkl')

# %%
files.download('mlp_10_10_10.pkl')

# %%
mlp_50_10_10_results = document_model(mlp_50_10_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_50_10_10_results, 'mlp_50_10_10.pkl')

# %%
files.download('mlp_50_10_10.pkl')

# %%
mlp_50_50_10_results = document_model(mlp_50_50_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_50_50_10_results, 'mlp_50_50_10.pkl')

# %%
files.download('mlp_50_50_10.pkl')

# %%
mlp_50_50_50_results = document_model(mlp_50_50_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_50_50_50_results, 'mlp_50_50_50.pkl')

# %%
files.download('mlp_50_50_50.pkl')

# %%
mlp_100_10_10_results = document_model(mlp_100_10_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_10_10_results, 'mlp_100_10_10.pkl')

# %%
files.download('mlp_100_10_10.pkl')

# %%
mlp_100_50_10_results = document_model(mlp_100_50_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_50_10_results, 'mlp_100_50_10.pkl')

# %%
files.download('mlp_100_50_10.pkl')

# %%
mlp_100_50_50_results = document_model(mlp_100_50_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_50_50_results, 'mlp_100_50_50.pkl')

# %%
files.download('mlp_100_50_50.pkl')

# %%
mlp_100_100_10_results = document_model(mlp_100_100_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_100_10_results, 'mlp_100_100_10.pkl')

# %%
files.download('mlp_100_100_10.pkl')

# %%
mlp_100_100_50_results = document_model(mlp_100_100_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_100_50_results, 'mlp_100_100_50.pkl')

# %%
files.download('mlp_100_100_50.pkl')

# %%
mlp_100_100_100_results = document_model(mlp_100_100_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_100_100_100_results, 'mlp_100_100_100.pkl')

# %%
files.download('mlp_100_100_100.pkl')

# %%
mlp_200_10_10_results = document_model(mlp_200_10_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_10_10_results, 'mlp_200_10_10.pkl')

# %%
files.download('mlp_200_10_10.pkl')

# %%
mlp_200_50_10_results = document_model(mlp_200_50_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_50_10_results, 'mlp_200_50_10.pkl')

# %%
files.download('mlp_200_50_10.pkl')

# %%
mlp_200_50_50_results = document_model(mlp_200_50_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_50_50_results, 'mlp_200_50_50.pkl')

# %%
files.download('mlp_200_50_50.pkl')

# %%
mlp_200_100_10_results = document_model(mlp_200_100_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_100_10_results, 'mlp_200_100_10.pkl')

# %%
files.download('mlp_200_100_10.pkl')

# %%
mlp_200_100_50_results = document_model(mlp_200_100_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_100_50_results, 'mlp_200_100_50.pkl')

# %%
files.download('mlp_200_100_50.pkl')

# %%
mlp_200_100_100_results = document_model(mlp_200_100_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_100_100_results, 'mlp_200_100_100.pkl')

# %%
files.download('mlp_200_100_100.pkl')

# %%
mlp_200_200_10_results = document_model(mlp_200_200_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_10_results, 'mlp_200_200_10.pkl')

# %%
files.download('mlp_200_200_10.pkl')

# %%
mlp_200_200_50_results = document_model(mlp_200_200_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_50_results, 'mlp_200_200_50.pkl')

# %%
files.download('mlp_200_200_50.pkl')

# %%
mlp_200_200_100_results = document_model(mlp_200_200_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_100_results, 'mlp_200_200_100.pkl')

# %%
files.download('mlp_200_200_100.pkl')

# %%
mlp_200_200_200_results = document_model(mlp_200_200_200, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_200_results, 'mlp_200_200_200.pkl')

# %%
files.download('mlp_200_200_200.pkl')

# %%
mlp_500_10_10_results = document_model(mlp_500_10_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_10_10_results, 'mlp_500_10_10.pkl')

# %%
files.download('mlp_500_10_10.pkl')

# %%
mlp_500_50_10_results = document_model(mlp_500_50_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_50_10_results, 'mlp_500_50_10.pkl')

# %%
files.download('mlp_500_50_10.pkl')

# %%
mlp_500_50_50_results = document_model(mlp_500_50_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_50_50_results, 'mlp_500_50_50.pkl')

# %%
files.download('mlp_500_50_50.pkl')

# %%
mlp_500_100_10_results = document_model(mlp_500_100_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_100_10_results, 'mlp_500_100_10.pkl')

# %%
files.download('mlp_500_100_10.pkl')

# %%
mlp_500_100_50_results = document_model(mlp_500_100_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_100_50_results, 'mlp_500_100_50.pkl')

# %%
files.download('mlp_500_100_50.pkl')

# %%
mlp_500_100_100_results = document_model(mlp_500_100_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_100_100_results, 'mlp_500_100_100.pkl')

# %%
files.download('mlp_500_100_100.pkl')

# %%
mlp_500_200_10_results = document_model(mlp_500_200_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_200_10_results, 'mlp_500_200_10.pkl')

# %%
files.download('mlp_500_200_10.pkl')

# %%
mlp_500_200_50_results = document_model(mlp_500_200_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_200_50_results, 'mlp_500_200_50.pkl')

# %%
files.download('mlp_500_200_50.pkl')

# %%
mlp_500_200_100_results = document_model(mlp_500_200_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_200_100_results, 'mlp_500_200_100.pkl')

# %%
files.download('mlp_500_200_100.pkl')

# %%
mlp_500_200_200_results = document_model(mlp_500_200_200, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_200_200_results, 'mlp_500_200_200.pkl')

# %%
files.download('mlp_500_200_200.pkl')

# %%
mlp_500_500_10_results = document_model(mlp_500_500_10, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_500_10_results, 'mlp_500_500_10.pkl')

# %%
files.download('mlp_500_500_10.pkl')

# %%
mlp_500_500_50_results = document_model(mlp_500_500_50, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_500_50_results, 'mlp_500_500_50.pkl')

# %%
files.download('mlp_500_500_50.pkl')

# %%
mlp_500_500_100_results = document_model(mlp_500_500_100, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_500_100_results, 'mlp_500_500_100.pkl')

# %%
files.download('mlp_500_500_100.pkl')

# %%
mlp_500_500_200_results = document_model(mlp_500_500_200, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_500_200_results, 'mlp_500_500_200.pkl')

# %%
files.download('mlp_500_500_200.pkl')

# %%
mlp_500_500_500_results = document_model(mlp_500_500_500, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_500_500_500_results, 'mlp_500_500_500.pkl')

# %%
files.download('mlp_500_500_500.pkl')

# %% [markdown]
# ### Dropout

# %%
mlp_200_200_0 = MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0)
mlp_200_200_02 = MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.2)
mlp_200_200_04 = MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.4)
mlp_200_200_06 = MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.6)
mlp_200_200_08 = MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.8)

# %%
mlp_200_200_0_results = document_model(mlp_200_200_0, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_0_results, 'mlp_200_200_0.pkl')

# %%
mlp_200_200_02_results = document_model(mlp_200_200_02, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_02_results, 'mlp_200_200_02.pkl')

# %%
mlp_200_200_04_results = document_model(mlp_200_200_04, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_04_results, 'mlp_200_200_04.pkl')

# %%
mlp_200_200_06_results = document_model(mlp_200_200_06, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_06_results, 'mlp_200_200_06.pkl')

# %%
mlp_200_200_08_results = document_model(mlp_200_200_08, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_08_results, 'mlp_200_200_08.pkl')

# %% [markdown]
# ### Activation

# %%
mlp_200_200_relu =  MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'relu', 'softmax', 0.5)
mlp_200_200_leakyrelu =  MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'leaky_relu', 'softmax', 0.5)
mlp_200_200_sigmoid =  MLP([3072, 200, 200, 10], 1000, 1024, 0.1, 'sigmoid', 'softmax', 0.5)

# %%
mlp_200_200_relu_results = document_model(mlp_200_200_relu, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_relu_results, 'mlp_200_200_relu.pkl')

# %%
mlp_200_200_leakyrelu_results = document_model(mlp_200_200_leakyrelu, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_leakyrelu_results, 'mlp_200_200_leakyrelu.pkl')

# %%
mlp_200_200_sigmoid_results = document_model(mlp_200_200_sigmoid, X_train, y_train, X_val, y_val)

# %%
save_file(mlp_200_200_sigmoid_results, 'mlp_200_200_sigmoid.pkl')

# %% [markdown]
# # CNN Implementation

# %%
#testing code

class Swish(nn.Module):
    def forward(self, input_tensor):
        return input_tensor * torch.sigmoid(input_tensor)

# %%
epochfunctrain = []
epochfunctest = [] #arrays to store results
def accuracyepoch (epoch, test):
  correct = 0
  total = 0 #temp variables to store results
  with torch.no_grad():
      for data in test: #extracting data
          images, labels = data 
          outputs = net(images) #running conv net
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)   #adding label size to total
          correct += (predicted == labels).sum().item() #if label is predicted than incr correct

 
  if test==trainloader: #appending arrays depending on train or test
    epochfunctrain.append(100*correct/total)
    print('Accuracy: %d %%' % (
      100 * correct / total)+ ' epoch of train ' + str(epoch+1)) #printing results
  elif test==testloader:
    print('Accuracy: %d %%' % (
      100 * correct / total)+ ' epoch of test ' + str(epoch+1)) #printing results
    (epochfunctest.append(100*correct/total))

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()   
        self.conv1 = nn.Conv2d(3, 6, 5) #Convolutional Layer 1, f=5, increase filters from 3 to 6.
        self.pool = nn.MaxPool2d(2, 2) #Pooling Layer, used multiple times it is a 2X2 Layer
        self.conv2 = nn.Conv2d(6, 16, 5) #Convolutional Layer 2, f=5, increase filters from 6 to 16.
        self.fc1 = nn.Linear(16 * 5 * 5, 120) #Apply linear transformation to data Input: 400, output 120
        self.fc2 = nn.Linear(120, 84) #Linear transformation, input 120, output 84
        self.fc3 = nn.Linear(84, 10)  #Linear transformation, input 84, output 10
        
    def forward(self, x):
        m=Swish()
        swish=m.forward
        x = self.pool(swish(self.conv1(x))) #Layer 1: Conv Layer 1, with Relu as function, 
                                              #then we apply 2x2 pooling
        x = self.pool(swish(self.conv2(x))) #Layer 2: Conv Layer 2, with Relu as function, 
                                              #then we apply 2x2 pooling                                     
        x = x.view(-1, 16 * 5 * 5)
        x = swish(self.fc1(x))
        x = swish(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
for epoch in range(50):  # loop over the dataset multiple times 
    

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0
            
    accuracyepoch(epoch, testloader)
    accuracyepoch(epoch, trainloader)  
        

print('Finished Training')
# Out:
# [1,  2000] loss: 0.468
# [1,  4000] loss: 0.490
# [1,  6000] loss: 0.530
# [1,  8000] loss: 0.535
# [1, 10000] loss: 0.536
# [1, 12000] loss: 0.561
# Accuracy: 61 % epoch of test 1
# Accuracy: 84 % epoch of train 1
# [2,  2000] loss: 0.436
# [2,  4000] loss: 0.499
# [2,  6000] loss: 0.501
# [2,  8000] loss: 0.537
# [2, 10000] loss: 0.563
# [2, 12000] loss: 0.575
# Accuracy: 59 % epoch of test 2
# Accuracy: 80 % epoch of train 2
# [3,  2000] loss: 0.442
# [3,  4000] loss: 0.467
# [3,  6000] loss: 0.503
# [3,  8000] loss: 0.543
# [3, 10000] loss: 0.549
# [3, 12000] loss: 0.553
# Accuracy: 61 % epoch of test 3
# Accuracy: 85 % epoch of train 3
# [4,  2000] loss: 0.433
# [4,  4000] loss: 0.462
# [4,  6000] loss: 0.511
# [4,  8000] loss: 0.528
# [4, 10000] loss: 0.540
# [4, 12000] loss: 0.598
# Accuracy: 59 % epoch of test 4
# Accuracy: 81 % epoch of train 4
# [5,  2000] loss: 0.424
# [5,  4000] loss: 0.479
# [5,  6000] loss: 0.493
# [5,  8000] loss: 0.525
# [5, 10000] loss: 0.528
# [5, 12000] loss: 0.564
# Accuracy: 60 % epoch of test 5
# Accuracy: 84 % epoch of train 5
# [6,  2000] loss: 0.396
# [6,  4000] loss: 0.462
# [6,  6000] loss: 0.499
# [6,  8000] loss: 0.515
# [6, 10000] loss: 0.553
# [6, 12000] loss: 0.545
# Accuracy: 59 % epoch of test 6
# Accuracy: 84 % epoch of train 6
# [7,  2000] loss: 0.428
# [7,  4000] loss: 0.447
# [7,  6000] loss: 0.488
# [7,  8000] loss: 0.518
# [7, 10000] loss: 0.523
# [7, 12000] loss: 0.542
# Accuracy: 59 % epoch of test 7
# Accuracy: 85 % epoch of train 7
# [8,  2000] loss: 0.398
# [8,  4000] loss: 0.460
# [8,  6000] loss: 0.478
# [8,  8000] loss: 0.521
# [8, 10000] loss: 0.559
# [8, 12000] loss: 0.557
# Accuracy: 60 % epoch of test 8
# Accuracy: 84 % epoch of train 8
# [9,  2000] loss: 0.405
# [9,  4000] loss: 0.456
# [9,  6000] loss: 0.485
# [9,  8000] loss: 0.538
# [9, 10000] loss: 0.510
# [9, 12000] loss: 0.553
# Accuracy: 60 % epoch of test 9
# Accuracy: 85 % epoch of train 9
# [10,  2000] loss: 0.428
# [10,  4000] loss: 0.453
# [10,  6000] loss: 0.498
# [10,  8000] loss: 0.517
# [10, 10000] loss: 0.545
# [10, 12000] loss: 0.542
# Accuracy: 59 % epoch of test 10
# Accuracy: 85 % epoch of train 10
# [11,  2000] loss: 0.404
# [11,  4000] loss: 0.444
# [11,  6000] loss: 0.514
# [11,  8000] loss: 0.519
# [11, 10000] loss: 0.497
# [11, 12000] loss: 0.533
# Accuracy: 60 % epoch of test 11
# Accuracy: 86 % epoch of train 11
# [12,  2000] loss: 0.390
# [12,  4000] loss: 0.444
# [12,  6000] loss: 0.494
# [12,  8000] loss: 0.494
# [12, 10000] loss: 0.539
# [12, 12000] loss: 0.507
# Accuracy: 60 % epoch of test 12
# Accuracy: 86 % epoch of train 12
# [13,  2000] loss: 0.414
# [13,  4000] loss: 0.446
# [13,  6000] loss: 0.495
# [13,  8000] loss: 0.494
# [13, 10000] loss: 0.524
# [13, 12000] loss: 0.537
# Accuracy: 60 % epoch of test 13
# Accuracy: 85 % epoch of train 13
# [14,  2000] loss: 0.425
# [14,  4000] loss: 0.448
# [14,  6000] loss: 0.480
# [14,  8000] loss: 0.487
# [14, 10000] loss: 0.499
# [14, 12000] loss: 0.538
# Accuracy: 60 % epoch of test 14
# Accuracy: 85 % epoch of train 14
# [15,  2000] loss: 0.390
# [15,  4000] loss: 0.461
# [15,  6000] loss: 0.502
# [15,  8000] loss: 0.508
# [15, 10000] loss: 0.526
# [15, 12000] loss: 0.534
# Accuracy: 54 % epoch of test 15
# Accuracy: 73 % epoch of train 15
# [16,  2000] loss: 0.423
# [16,  4000] loss: 0.482
# [16,  6000] loss: 0.467
# [16,  8000] loss: 0.488
# [16, 10000] loss: 0.527
# [16, 12000] loss: 0.518
# Accuracy: 59 % epoch of test 16
# Accuracy: 85 % epoch of train 16
# [17,  2000] loss: 0.398
# [17,  4000] loss: 0.430
# [17,  6000] loss: 0.464
# [17,  8000] loss: 0.520
# [17, 10000] loss: 0.517
# [17, 12000] loss: 0.520
# Accuracy: 57 % epoch of test 17
# Accuracy: 81 % epoch of train 17
# [18,  2000] loss: 0.398
# [18,  4000] loss: 0.442
# [18,  6000] loss: 0.496
# [18,  8000] loss: 0.504
# [18, 10000] loss: 0.547
# [18, 12000] loss: 0.550
# Accuracy: 58 % epoch of test 18
# Accuracy: 85 % epoch of train 18
# [19,  2000] loss: 0.415
# [19,  4000] loss: 0.436
# [19,  6000] loss: 0.468
# [19,  8000] loss: 0.509
# [19, 10000] loss: 0.513
# [19, 12000] loss: 0.507
# Accuracy: 60 % epoch of test 19
# Accuracy: 87 % epoch of train 19
# [20,  2000] loss: 0.388
# [20,  4000] loss: 0.460
# [20,  6000] loss: 0.482
# [20,  8000] loss: 0.507
# [20, 10000] loss: 0.515
# [20, 12000] loss: 0.510
# Accuracy: 59 % epoch of test 20
# Accuracy: 86 % epoch of train 20
# [21,  2000] loss: 0.399
# [21,  4000] loss: 0.449
# [21,  6000] loss: 0.471
# [21,  8000] loss: 0.514
# [21, 10000] loss: 0.515
# [21, 12000] loss: 0.542
# Accuracy: 58 % epoch of test 21
# Accuracy: 84 % epoch of train 21
# [22,  2000] loss: 0.400
# [22,  4000] loss: 0.460
# [22,  6000] loss: 0.449
# [22,  8000] loss: 0.486
# [22, 10000] loss: 0.535
# [22, 12000] loss: 0.555
# Accuracy: 59 % epoch of test 22
# Accuracy: 85 % epoch of train 22
# [23,  2000] loss: 0.413
# [23,  4000] loss: 0.477
# [23,  6000] loss: 0.490
# [23,  8000] loss: 0.499
# [23, 10000] loss: 0.527
# [23, 12000] loss: 0.532
# Accuracy: 59 % epoch of test 23
# Accuracy: 87 % epoch of train 23
# [24,  2000] loss: 0.401
# [24,  4000] loss: 0.445
# [24,  6000] loss: 0.481
# [24,  8000] loss: 0.499
# [24, 10000] loss: 0.530
# [24, 12000] loss: 0.553
# Accuracy: 59 % epoch of test 24
# Accuracy: 85 % epoch of train 24
# [25,  2000] loss: 0.426
# [25,  4000] loss: 0.474
# [25,  6000] loss: 0.462
# [25,  8000] loss: 0.485
# [25, 10000] loss: 0.515
# [25, 12000] loss: 0.530
# Accuracy: 59 % epoch of test 25
# Accuracy: 83 % epoch of train 25
# [26,  2000] loss: 0.411
# [26,  4000] loss: 0.429
# [26,  6000] loss: 0.506
# [26,  8000] loss: 0.495
# [26, 10000] loss: 0.521
# [26, 12000] loss: 0.547
# Accuracy: 58 % epoch of test 26
# Accuracy: 85 % epoch of train 26
# [27,  2000] loss: 0.409
# [27,  4000] loss: 0.462
# [27,  6000] loss: 0.494
# [27,  8000] loss: 0.506
# [27, 10000] loss: 0.569
# [27, 12000] loss: 0.508
# Accuracy: 58 % epoch of test 27
# Accuracy: 84 % epoch of train 27
# [28,  2000] loss: 0.430
# [28,  4000] loss: 0.468
# [28,  6000] loss: 0.496
# [28,  8000] loss: 0.485
# [28, 10000] loss: 0.538
# [28, 12000] loss: 0.533
# Accuracy: 58 % epoch of test 28
# Accuracy: 86 % epoch of train 28
# [29,  2000] loss: 0.419
# [29,  4000] loss: 0.454
# [29,  6000] loss: 0.501
# [29,  8000] loss: 0.507
# [29, 10000] loss: 0.520
# [29, 12000] loss: 0.532
# Accuracy: 59 % epoch of test 29
# Accuracy: 85 % epoch of train 29
# [30,  2000] loss: 0.394
# [30,  4000] loss: 0.463
# [30,  6000] loss: 0.505
# [30,  8000] loss: 0.516
# [30, 10000] loss: 0.519
# [30, 12000] loss: 0.542
# Accuracy: 58 % epoch of test 30
# Accuracy: 83 % epoch of train 30
# [31,  2000] loss: 0.430
# [31,  4000] loss: 0.428
# [31,  6000] loss: 0.498
# [31,  8000] loss: 0.496
# [31, 10000] loss: 0.553
# [31, 12000] loss: 0.502
# Accuracy: 57 % epoch of test 31
# Accuracy: 79 % epoch of train 31
# [32,  2000] loss: 0.430
# [32,  4000] loss: 0.470
# [32,  6000] loss: 0.509
# [32,  8000] loss: 0.503
# [32, 10000] loss: 0.570
# [32, 12000] loss: 0.538
# Accuracy: 58 % epoch of test 32
# Accuracy: 85 % epoch of train 32
# [33,  2000] loss: 0.409
# [33,  4000] loss: 0.476
# [33,  6000] loss: 0.507
# [33,  8000] loss: 0.532
# [33, 10000] loss: 0.513
# [33, 12000] loss: 0.546
# Accuracy: 57 % epoch of test 33
# Accuracy: 84 % epoch of train 33
# [34,  2000] loss: 0.437
# [34,  4000] loss: 0.480
# [34,  6000] loss: 0.480
# [34,  8000] loss: 0.513
# [34, 10000] loss: 0.533
# [34, 12000] loss: 0.532
# Accuracy: 58 % epoch of test 34
# Accuracy: 84 % epoch of train 34
# [35,  2000] loss: 0.446
# [35,  4000] loss: 0.471
# [35,  6000] loss: 0.510
# [35,  8000] loss: 0.526
# [35, 10000] loss: 0.543
# [35, 12000] loss: 0.543
# Accuracy: 56 % epoch of test 35
# Accuracy: 77 % epoch of train 35
# [36,  2000] loss: 0.423
# [36,  4000] loss: 0.478
# [36,  6000] loss: 0.475
# [36,  8000] loss: 0.544
# [36, 10000] loss: 0.527
# [36, 12000] loss: 0.551
# Accuracy: 58 % epoch of test 36
# Accuracy: 85 % epoch of train 36
# [37,  2000] loss: 0.423
# [37,  4000] loss: 0.447
# [37,  6000] loss: 0.507
# [37,  8000] loss: 0.494
# [37, 10000] loss: 0.561
# [37, 12000] loss: 0.547
# Accuracy: 58 % epoch of test 37
# Accuracy: 84 % epoch of train 37
# [38,  2000] loss: 0.433
# [38,  4000] loss: 0.439
# [38,  6000] loss: 0.470
# [38,  8000] loss: 0.510
# [38, 10000] loss: 0.513
# [38, 12000] loss: 0.538
# Accuracy: 58 % epoch of test 38
# Accuracy: 82 % epoch of train 38
# [39,  2000] loss: 0.454
# [39,  4000] loss: 0.499
# [39,  6000] loss: 0.512
# [39,  8000] loss: 0.548
# [39, 10000] loss: 0.565
# [39, 12000] loss: 0.528
# Accuracy: 58 % epoch of test 39
# Accuracy: 83 % epoch of train 39
# [40,  2000] loss: 0.444
# [40,  4000] loss: 0.488
# [40,  6000] loss: 0.527
# [40,  8000] loss: 0.530
# [40, 10000] loss: 0.556
# [40, 12000] loss: 0.547
# Accuracy: 58 % epoch of test 40
# Accuracy: 83 % epoch of train 40
# [41,  2000] loss: 0.428
# [41,  4000] loss: 0.496
# [41,  6000] loss: 0.495
# [41,  8000] loss: 0.502
# [41, 10000] loss: 0.551
# [41, 12000] loss: 0.545
# Accuracy: 57 % epoch of test 41
# Accuracy: 82 % epoch of train 41
# [42,  2000] loss: 0.432
# [42,  4000] loss: 0.492
# [42,  6000] loss: 0.527
# [42,  8000] loss: 0.519
# [42, 10000] loss: 0.512
# [42, 12000] loss: 0.559
# Accuracy: 58 % epoch of test 42
# Accuracy: 84 % epoch of train 42
# [43,  2000] loss: 0.451
# [43,  4000] loss: 0.474
# [43,  6000] loss: 0.493
# [43,  8000] loss: 0.522
# [43, 10000] loss: 0.533
# [43, 12000] loss: 0.547
# Accuracy: 57 % epoch of test 43
# Accuracy: 81 % epoch of train 43
# [44,  2000] loss: 0.456
# [44,  4000] loss: 0.504
# [44,  6000] loss: 0.516
# [44,  8000] loss: 0.552
# [44, 10000] loss: 0.544
# [44, 12000] loss: 0.533
# Accuracy: 57 % epoch of test 44
# Accuracy: 82 % epoch of train 44
# [45,  2000] loss: 0.448
# [45,  4000] loss: 0.470
# [45,  6000] loss: 0.528
# [45,  8000] loss: 0.509
# [45, 10000] loss: 0.588
# [45, 12000] loss: 0.557
# Accuracy: 58 % epoch of test 45
# Accuracy: 86 % epoch of train 45
# [46,  2000] loss: 0.449
# [46,  4000] loss: 0.500
# [46,  6000] loss: 0.487
# [46,  8000] loss: 0.524
# [46, 10000] loss: 0.553
# [46, 12000] loss: 0.603
# Accuracy: 57 % epoch of test 46
# Accuracy: 80 % epoch of train 46
# [47,  2000] loss: 0.442
# [47,  4000] loss: 0.526
# [47,  6000] loss: 0.545
# [47,  8000] loss: 0.520
# [47, 10000] loss: 0.543
# [47, 12000] loss: 0.590
# Accuracy: 59 % epoch of test 47
# Accuracy: 86 % epoch of train 47
# [48,  2000] loss: 0.456
# [48,  4000] loss: 0.513
# [48,  6000] loss: 0.509
# [48,  8000] loss: 0.530
# [48, 10000] loss: 0.555
# [48, 12000] loss: 0.563
# Accuracy: 58 % epoch of test 48
# Accuracy: 82 % epoch of train 48
# [49,  2000] loss: 0.422
# [49,  4000] loss: 0.486
# [49,  6000] loss: 0.578
# [49,  8000] loss: 0.541
# [49, 10000] loss: 0.552
# [49, 12000] loss: 0.594
# Accuracy: 58 % epoch of test 49
# Accuracy: 85 % epoch of train 49
# [50,  2000] loss: 0.487
# [50,  4000] loss: 0.490
# [50,  6000] loss: 0.561
# [50,  8000] loss: 0.549
# [50, 10000] loss: 0.583
# [50, 12000] loss: 0.591
# Accuracy: 58 % epoch of test 50
# Accuracy: 86 % epoch of train 50
# Finished Training

# %%
PATH = './cifar_net.pth'
torch.save(net.state_dict(), PATH)

# %%
net = Net()
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 64 %
# Accuracy of   car : 73 %
# Accuracy of  bird : 43 %
# Accuracy of   cat : 43 %
# Accuracy of  deer : 56 %
# Accuracy of   dog : 53 %
# Accuracy of  frog : 62 %
# Accuracy of horse : 65 %
# Accuracy of  ship : 77 %
# Accuracy of truck : 66 %

# %%
print("Accuracy Train:")
print('\n'.join(map(str, epochfunctrain)))
print('\n'+'[epoch,accuracy]:')
for x in range(len(epochfunctrain)): 
    print ('\n'+'['+str(x+1)+','+ str(epochfunctrain[x])+']')
# Out:
# Accuracy Train:
# 65.32
# 65.64
# 70.464
# 72.784
# 74.06
# 76.272
# 77.664
# 78.784
# 79.28
# 78.716
# 77.686
# 79.998
# 80.864
# 82.696
# 78.908
# 80.318
# 84.034
# 84.908
# 84.49
# 84.632
# 84.76
# 80.866
# 85.464
# 81.7
# 84.078
# 84.37
# 85.264
# 84.346
# 85.444
# 85.614
# 86.092
# 86.404
# 85.59
# 85.66
# 73.776
# 85.816
# 81.444
# 85.916
# 87.156
# 86.128
# 84.65
# 85.304
# 87.012
# 85.202
# 83.668
# 85.126
# 84.478
# 86.222
# 85.7
# 83.25
# 79.818
# 85.996
# 84.298
# 84.576
# 77.58
# 85.086
# 84.782
# 82.644
# 83.672
# 83.782
# 82.758
# 84.028
# 81.866
# 82.256
# 86.096
# 80.748
# 86.61
# 82.78
# 85.124
# 86.006
#
# [epoch,accuracy]:
#
# [1,65.32]
#
# [2,65.64]
#
# [3,70.464]
#
# [4,72.784]
#
# [5,74.06]
#
# [6,76.272]
#
# [7,77.664]
#
# [8,78.784]
#
# [9,79.28]
#
# [10,78.716]
#
# [11,77.686]
#
# [12,79.998]
#
# [13,80.864]
#
# [14,82.696]
#
# [15,78.908]
#
# [16,80.318]
#
# [17,84.034]
#
# [18,84.908]
#
# [19,84.49]
#
# [20,84.632]
#
# [21,84.76]
#
# [22,80.866]
#
# [23,85.464]
#
# [24,81.7]
#
# [25,84.078]
#
# [26,84.37]
#
# [27,85.264]
#
# [28,84.346]
#
# [29,85.444]
#
# [30,85.614]
#
# [31,86.092]
#
# [32,86.404]
#
# [33,85.59]
#
# [34,85.66]
#
# [35,73.776]
#
# [36,85.816]
#
# [37,81.444]
#
# [38,85.916]
#
# [39,87.156]
#
# [40,86.128]
#
# [41,84.65]
#
# [42,85.304]
#
# [43,87.012]
#
# [44,85.202]
#
# [45,83.668]
#
# [46,85.126]
#
# [47,84.478]
#
# [48,86.222]
#
# [49,85.7]
#
# [50,83.25]
#
# [51,79.818]
#
# [52,85.996]
#
# [53,84.298]
#
# [54,84.576]
#
# [55,77.58]
#
# [56,85.086]
#
# [57,84.782]
#
# [58,82.644]
#
# [59,83.672]
#
# [60,83.782]
#
# [61,82.758]
#
# [62,84.028]
#
# [63,81.866]
#
# [64,82.256]
#
# [65,86.096]
#
# [66,80.748]
#
# [67,86.61]
#
# [68,82.78]
#
# [69,85.124]
#
# [70,86.006]

# %%
print("Accuracy Test:")
print('\n'.join(map(str, epochfunctest)))
print('\n'+'[epoch,accuracy]:')
for x in range(len(epochfunctest)): 
    print ('\n'+'['+str(x+1)+','+ str(epochfunctest[x])+']')
# Out:
# Accuracy Test:
# 61.0
# 60.76
# 63.63
# 63.59
# 64.38
# 64.31
# 64.9
# 64.49
# 63.46
# 62.29
# 60.83
# 62.55
# 62.8
# 63.11
# 60.9
# 61.02
# 62.02
# 62.58
# 62.32
# 62.05
# 61.48
# 59.12
# 61.12
# 59.78
# 60.26
# 59.58
# 59.86
# 60.5
# 60.45
# 59.97
# 60.0
# 60.74
# 60.22
# 60.1
# 54.67
# 59.88
# 57.67
# 58.86
# 60.63
# 59.57
# 58.15
# 59.17
# 59.58
# 59.6
# 59.23
# 58.72
# 58.23
# 58.81
# 59.62
# 58.89
# 57.02
# 58.95
# 57.86
# 58.95
# 56.33
# 58.43
# 58.03
# 58.52
# 58.7
# 58.5
# 57.89
# 58.26
# 57.75
# 57.55
# 58.98
# 57.06
# 59.53
# 58.29
# 58.99
# 58.16
#
# [epoch,accuracy]:
#
# [1,61.0]
#
# [2,60.76]
#
# [3,63.63]
#
# [4,63.59]
#
# [5,64.38]
#
# [6,64.31]
#
# [7,64.9]
#
# [8,64.49]
#
# [9,63.46]
#
# [10,62.29]
#
# [11,60.83]
#
# [12,62.55]
#
# [13,62.8]
#
# [14,63.11]
#
# [15,60.9]
#
# [16,61.02]
#
# [17,62.02]
#
# [18,62.58]
#
# [19,62.32]
#
# [20,62.05]
#
# [21,61.48]
#
# [22,59.12]
#
# [23,61.12]
#
# [24,59.78]
#
# [25,60.26]
#
# [26,59.58]
#
# [27,59.86]
#
# [28,60.5]
#
# [29,60.45]
#
# [30,59.97]
#
# [31,60.0]
#
# [32,60.74]
#
# [33,60.22]
#
# [34,60.1]
#
# [35,54.67]
#
# [36,59.88]
#
# [37,57.67]
#
# [38,58.86]
#
# [39,60.63]
#
# [40,59.57]
#
# [41,58.15]
#
# [42,59.17]
#
# [43,59.58]
#
# [44,59.6]
#
# [45,59.23]
#
# [46,58.72]
#
# [47,58.23]
#
# [48,58.81]
#
# [49,59.62]
#
# [50,58.89]
#
# [51,57.02]
#
# [52,58.95]
#
# [53,57.86]
#
# [54,58.95]
#
# [55,56.33]
#
# [56,58.43]
#
# [57,58.03]
#
# [58,58.52]
#
# [59,58.7]
#
# [60,58.5]
#
# [61,57.89]
#
# [62,58.26]
#
# [63,57.75]
#
# [64,57.55]
#
# [65,58.98]
#
# [66,57.06]
#
# [67,59.53]
#
# [68,58.29]
#
# [69,58.99]
#
# [70,58.16]
